# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 891

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-----------------------------")

weather_response_json = []

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
city_list = []

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&q="

for city in range(len(cities)):
    print(f"Processing Record {city} | {cities[city]}")
    
    query_url = f"{url}appid={api_key}&units={units}&q={cities[city]}"
    response = requests.get(query_url)
    weather_response = response.json()
    weather_response_json.append(weather_response)
    
    try:
        city_list.append(weather_response['name'])
        cloudiness.append(weather_response['clouds']['all'])
        country.append(weather_response['sys']['country'])
        date.append(weather_response['dt'])
        humidity.append(weather_response['main']['humidity'])
        lat.append(weather_response['coord']['lat'])
        lng.append(weather_response['coord']['lon'])
        max_temp.append(weather_response['main']['temp_max'])
        wind_speed.append(weather_response['wind']['speed'])
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 | castro
# Processing Record 1 | abu samrah
# Processing Record 2 | tsihombe
# Missing field/result... skipping.
# Processing Record 3 | mataura
# Processing Record 4 | mar del plata
# Processing Record 5 | korla
# Missing field/result... skipping.
# Processing Record 6 | muroto
# Processing Record 7 | nueve de julio
# Processing Record 8 | atuona
# Processing Record 9 | tuktoyaktuk
# Processing Record 10 | jamestown
# Processing Record 11 | saint george
# Processing Record 12 | illoqqortoormiut
# Missing field/result... skipping.
# Processing Record 13 | macaboboni
# Missing field/result... skipping.
# Processing Record 14 | san patricio
# Processing Record 15 | punta arenas
# Processing Record 16 | viligili
# Missing field/result... skipping.
# Processing Record 17 | east london
# Processing Record 18 | mutis
# Processing Record 19 | qaanaaq
# Processing Record 20 | camacha
# Processing Record 21 | kapaa
# Processing Record 22 | new norfolk
# Processing Record 23 | imperial beach
# Processing Record 24 | ushuaia
# Processing Record 25 | provideniya
# Processing Record 26 | adrar
# Processing Record 27 | avarua
# Processing Record 28 | los llanos de aridane
# Processing Record 29 | vaini
# Processing Record 30 | cherskiy
# Processing Record 31 | yellowknife
# Processing Record 32 | tumannyy
# Missing field/result... skipping.
# Processing Record 33 | joshimath
# Processing Record 34 | cabo san lucas
# Processing Record 35 | brigantine
# Processing Record 36 | torbay
# Processing Record 37 | yatou
# Processing Record 38 | nadym
# Processing Record 39 | nizhneyansk
# Missing field/result... skipping.
# Processing Record 40 | mys shmidta
# Missing field/result... skipping.
# Processing Record 41 | bluff
# Processing Record 42 | saint-philippe
# Processing Record 43 | barentsburg
# Missing field/result... skipping.
# Processing Record 44 | rikitea
# Processing Record 45 | hilo
# Processing Record 46 | yabelo
# Processing Record 47 | samusu
# Missing field/result... skipping.
# Processing Record 48 | dikson
# Processing Record 49 | chitral
# Processing Record 50 | bethel
# Processing Record 51 | ocampo
# Processing Record 52 | nanortalik
# Processing Record 53 | ribeira grande
# Processing Record 54 | alice springs
# Processing Record 55 | severo-kurilsk
# Processing Record 56 | ilulissat
# Processing Record 57 | carnarvon
# Processing Record 58 | balkanabat
# Processing Record 59 | klaksvik
# Processing Record 60 | aklavik
# Processing Record 61 | norman wells
# Processing Record 62 | kavieng
# Processing Record 63 | guerrero negro
# Processing Record 64 | el carmen
# Processing Record 65 | belushya guba
# Missing field/result... skipping.
# Processing Record 66 | vaitupu
# Missing field/result... skipping.
# Processing Record 67 | uribia
# Processing Record 68 | hermanus
# Processing Record 69 | samarai
# Processing Record 70 | burns lake
# Processing Record 71 | port elizabeth
# Processing Record 72 | sola
# Processing Record 73 | avera
# Processing Record 74 | inderborskiy
# Missing field/result... skipping.
# Processing Record 75 | cowra
# Processing Record 76 | iqaluit
# Processing Record 77 | carmelo
# Processing Record 78 | albany
# Processing Record 79 | coihaique
# Processing Record 80 | batagay-alyta
# Processing Record 81 | amderma
# Missing field/result... skipping.
# Processing Record 82 | yenagoa
# Processing Record 83 | busselton
# Processing Record 84 | flinders
# Processing Record 85 | edirne
# Processing Record 86 | roald
# Processing Record 87 | taolanaro
# Missing field/result... skipping.
# Processing Record 88 | saint-joseph
# Processing Record 89 | puurmani
# Processing Record 90 | upernavik
# Processing Record 91 | marechal candido rondon
# Processing Record 92 | hirara
# Processing Record 93 | georgetown
# Processing Record 94 | butaritari
# Processing Record 95 | harnosand
# Processing Record 96 | gisborne
# Processing Record 97 | cape town
# Processing Record 98 | tiznit
# Processing Record 99 | rusape
# Processing Record 100 | tiksi
# Processing Record 101 | port alfred
# Processing Record 102 | xining
# Processing Record 103 | methoni
# Processing Record 104 | lebu
# Processing Record 105 | jiangyou
# Processing Record 106 | ambon
# Processing Record 107 | longyearbyen
# Processing Record 108 | souillac
# Processing Record 109 | kandi
# Processing Record 110 | gushi
# Processing Record 111 | villablino
# Processing Record 112 | constitucion
# Processing Record 113 | banmo
# Missing field/result... skipping.
# Processing Record 114 | el rusio
# Processing Record 115 | saint anthony
# Processing Record 116 | den helder
# Processing Record 117 | santa fe
# Processing Record 118 | grindavik
# Processing Record 119 | thompson
# Processing Record 120 | fortuna
# Processing Record 121 | hobyo
# Processing Record 122 | chokwe
# Missing field/result... skipping.
# Processing Record 123 | port pirie
# Processing Record 124 | borgarnes
# Processing Record 125 | kodiak
# Processing Record 126 | umm lajj
# Processing Record 127 | dzhusaly
# Missing field/result... skipping.
# Processing Record 128 | arraial do cabo
# Processing Record 129 | kuche
# Missing field/result... skipping.
# Processing Record 130 | deutschlandsberg
# Processing Record 131 | chapais
# Processing Record 132 | phumi samraong
# Missing field/result... skipping.
# Processing Record 133 | cascais
# Processing Record 134 | seredka
# Processing Record 135 | hami
# Processing Record 136 | ulagan
# Processing Record 137 | sorland
# Processing Record 138 | senno
# Processing Record 139 | bandipur
# Processing Record 140 | hobart
# Processing Record 141 | manta
# Processing Record 142 | asau
# Missing field/result... skipping.
# Processing Record 143 | lolua
# Missing field/result... skipping.
# Processing Record 144 | inhambane
# Processing Record 145 | puerto ayora
# Processing Record 146 | mattru
# Processing Record 147 | ponta do sol
# Processing Record 148 | chuy
# Processing Record 149 | falealupo
# Missing field/result... skipping.
# Processing Record 150 | makakilo city
# Processing Record 151 | gizo
# Processing Record 152 | russell
# Processing Record 153 | airai
# Processing Record 154 | kaeo
# Processing Record 155 | alyangula
# Processing Record 156 | kahului
# Processing Record 157 | cervo
# Processing Record 158 | saurimo
# Processing Record 159 | nueva loja
# Processing Record 160 | tabiauea
# Missing field/result... skipping.
# Processing Record 161 | muros
# Processing Record 162 | calabozo
# Processing Record 163 | martapura
# Processing Record 164 | luanda
# Processing Record 165 | atar
# Processing Record 166 | raymondville
# Processing Record 167 | katsuura
# Processing Record 168 | praia da vitoria
# Processing Record 169 | sitka
# Processing Record 170 | faanui
# Processing Record 171 | dwarka
# Processing Record 172 | kaitangata
# Processing Record 173 | ulladulla
# Processing Record 174 | mahebourg
# Processing Record 175 | yunjinghong
# Missing field/result... skipping.
# Processing Record 176 | kerrville
# Processing Record 177 | harper
# Processing Record 178 | cidreira
# Processing Record 179 | attawapiskat
# Missing field/result... skipping.
# Processing Record 180 | wlodawa
# Processing Record 181 | ahipara
# Processing Record 182 | mehamn
# Processing Record 183 | santiago
# Processing Record 184 | port lincoln
# Processing Record 185 | sovetskiy
# Processing Record 186 | kloulklubed
# Processing Record 187 | sisimiut
# Processing Record 188 | auki
# Processing Record 189 | margate
# Processing Record 190 | laguna
# Processing Record 191 | sangre grande
# Processing Record 192 | surgut
# Processing Record 193 | minggang
# Processing Record 194 | ushtobe
# Processing Record 195 | saskylakh
# Processing Record 196 | bargal
# Missing field/result... skipping.
# Processing Record 197 | maturin
# Processing Record 198 | havre-saint-pierre
# Processing Record 199 | noboribetsu
# Processing Record 200 | saint-augustin
# Processing Record 201 | esperance
# Processing Record 202 | pingzhuang
# Missing field/result... skipping.
# Processing Record 203 | tevriz
# Processing Record 204 | sun prairie
# Processing Record 205 | neuquen
# Processing Record 206 | sao filipe
# Processing Record 207 | ostrovnoy
# Processing Record 208 | vestmannaeyjar
# Processing Record 209 | tuatapere
# Processing Record 210 | tromso
# Processing Record 211 | benjamin constant
# Processing Record 212 | kurchum
# Processing Record 213 | la ronge
# Processing Record 214 | angouleme
# Processing Record 215 | canberra
# Processing Record 216 | monroe
# Processing Record 217 | lingyuan
# Processing Record 218 | mayen
# Processing Record 219 | robertson
# Processing Record 220 | chagda
# Missing field/result... skipping.
# Processing Record 221 | lorengau
# Processing Record 222 | marcona
# Missing field/result... skipping.
# Processing Record 223 | baykit
# Processing Record 224 | ballina
# Processing Record 225 | nuevo progreso
# Processing Record 226 | bingol
# Processing Record 227 | ancud
# Processing Record 228 | hamilton
# Processing Record 229 | moose factory
# Processing Record 230 | isangel
# Processing Record 231 | manokwari
# Processing Record 232 | felanitx
# Processing Record 233 | lompoc
# Processing Record 234 | pemberton
# Processing Record 235 | winthrop
# Processing Record 236 | tasiilaq
# Processing Record 237 | parabel
# Processing Record 238 | ixtapa
# Processing Record 239 | paamiut
# Processing Record 240 | faya
# Processing Record 241 | mazagao
# Processing Record 242 | caravelas
# Processing Record 243 | hithadhoo
# Processing Record 244 | fruitville
# Processing Record 245 | kattivakkam
# Processing Record 246 | ucluelet
# Processing Record 247 | batken
# Processing Record 248 | kargasok
# Processing Record 249 | buta
# Processing Record 250 | valkeala
# Processing Record 251 | riberalta
# Processing Record 252 | khatanga
# Processing Record 253 | taltal
# Processing Record 254 | waingapu
# Processing Record 255 | shingu
# Processing Record 256 | beringovskiy
# Processing Record 257 | katherine
# Processing Record 258 | alta floresta
# Processing Record 259 | bambous virieux
# Processing Record 260 | nikolskoye
# Processing Record 261 | honiara
# Processing Record 262 | oistins
# Processing Record 263 | barrow
# Processing Record 264 | aurich
# Processing Record 265 | barbar
# Missing field/result... skipping.
# Processing Record 266 | pierre
# Processing Record 267 | rajec
# Processing Record 268 | rensvik
# Processing Record 269 | hyvinkaa
# Processing Record 270 | churachandpur
# Processing Record 271 | clermont
# Processing Record 272 | clyde river
# Processing Record 273 | verkhoyansk
# Processing Record 274 | moranbah
# Processing Record 275 | namatanai
# Processing Record 276 | sioux lookout
# Processing Record 277 | narsaq
# Processing Record 278 | astana
# Processing Record 279 | arlit
# Processing Record 280 | belmonte
# Processing Record 281 | mega
# Processing Record 282 | hengshui
# Processing Record 283 | kuva
# Missing field/result... skipping.
# Processing Record 284 | bredasdorp
# Processing Record 285 | cagayan de tawi-tawi
# Missing field/result... skipping.
# Processing Record 286 | kampene
# Processing Record 287 | chaman
# Processing Record 288 | ketchikan
# Processing Record 289 | soure
# Processing Record 290 | beli manastir
# Processing Record 291 | tasbuget
# Missing field/result... skipping.
# Processing Record 292 | dakar
# Processing Record 293 | bangaon
# Processing Record 294 | narkanda
# Processing Record 295 | port blair
# Processing Record 296 | dingle
# Processing Record 297 | khandyga
# Processing Record 298 | sibu
# Processing Record 299 | griffith
# Processing Record 300 | namibe
# Processing Record 301 | pacific grove
# Processing Record 302 | mitu
# Processing Record 303 | mareeba
# Processing Record 304 | berlevag
# Processing Record 305 | pitimbu
# Processing Record 306 | ternate
# Processing Record 307 | lavrentiya
# Processing Record 308 | ukiah
# Processing Record 309 | buchanan
# Processing Record 310 | kropotkin
# Processing Record 311 | galiwinku
# Missing field/result... skipping.
# Processing Record 312 | orje
# Processing Record 313 | sao joao da barra
# Processing Record 314 | rawson
# Processing Record 315 | almendralejo
# Processing Record 316 | anadyr
# Processing Record 317 | jaca
# Processing Record 318 | port hardy
# Processing Record 319 | houma
# Processing Record 320 | lata
# Processing Record 321 | scarborough
# Processing Record 322 | lagoa
# Processing Record 323 | acapulco
# Processing Record 324 | bolshaya sosnova
# Processing Record 325 | umzimvubu
# Missing field/result... skipping.
# Processing Record 326 | goundam
# Processing Record 327 | san ignacio
# Processing Record 328 | basco
# Processing Record 329 | morehead
# Processing Record 330 | shelburne
# Processing Record 331 | torrington
# Processing Record 332 | talaya
# Processing Record 333 | victoria
# Processing Record 334 | hasaki
# Processing Record 335 | turayf
# Processing Record 336 | ko samui
# Processing Record 337 | shakawe
# Processing Record 338 | yako
# Processing Record 339 | rong kwang
# Processing Record 340 | awbari
# Processing Record 341 | huari
# Processing Record 342 | grafton
# Processing Record 343 | bayonet point
# Processing Record 344 | gladstone
# Processing Record 345 | emba
# Processing Record 346 | kirillov
# Processing Record 347 | krivodanovka
# Processing Record 348 | komsomolskiy
# Processing Record 349 | rocha
# Processing Record 350 | hofn
# Processing Record 351 | mezen
# Processing Record 352 | kununurra
# Processing Record 353 | luderitz
# Processing Record 354 | taoudenni
# Processing Record 355 | mullaitivu
# Missing field/result... skipping.
# Processing Record 356 | aquidauana
# Processing Record 357 | constantine
# Processing Record 358 | vardo
# Processing Record 359 | vagur
# Processing Record 360 | ekhabi
# Processing Record 361 | cayenne
# Processing Record 362 | goderich
# Processing Record 363 | hingorja
# Processing Record 364 | dvinskoy
# Processing Record 365 | labrea
# Missing field/result... skipping.
# Processing Record 366 | belfast
# Processing Record 367 | takoradi
# Processing Record 368 | vila velha
# Processing Record 369 | otjimbingwe
# Processing Record 370 | nizhniy tsasuchey
# Processing Record 371 | aldan
# Processing Record 372 | pestravka
# Processing Record 373 | bellevue
# Processing Record 374 | portobelo
# Processing Record 375 | kidal
# Processing Record 376 | digha
# Processing Record 377 | manzanillo
# Processing Record 378 | una
# Processing Record 379 | salmon arm
# Processing Record 380 | nishihara
# Processing Record 381 | husavik
# Processing Record 382 | mizdah
# Processing Record 383 | conde
# Processing Record 384 | san cristobal
# Processing Record 385 | rivadavia
# Processing Record 386 | nyurba
# Processing Record 387 | ouadda
# Processing Record 388 | leninskoye
# Processing Record 389 | sindou
# Processing Record 390 | puerto rico
# Processing Record 391 | esmeraldas
# Processing Record 392 | vao
# Processing Record 393 | chokurdakh
# Processing Record 394 | liverpool
# Processing Record 395 | wronki
# Processing Record 396 | aberdeen
# Processing Record 397 | carutapera
# Processing Record 398 | hualmay
# Processing Record 399 | tamiahua
# Processing Record 400 | rawannawi
# Missing field/result... skipping.
# Processing Record 401 | saleaula
# Missing field/result... skipping.
# Processing Record 402 | bengkulu
# Missing field/result... skipping.
# Processing Record 403 | yelabuga
# Processing Record 404 | atambua
# Processing Record 405 | san jose
# Processing Record 406 | maniitsoq
# Processing Record 407 | acuna
# Missing field/result... skipping.
# Processing Record 408 | acari
# Processing Record 409 | mapiripan
# Processing Record 410 | winnemucca
# Processing Record 411 | golden rock
# Missing field/result... skipping.
# Processing Record 412 | tezu
# Processing Record 413 | grand river south east
# Missing field/result... skipping.
# Processing Record 414 | aalter
# Processing Record 415 | yulara
# Processing Record 416 | port lavaca
# Processing Record 417 | ridgecrest
# Processing Record 418 | pisco
# Processing Record 419 | college
# Processing Record 420 | mandali
# Processing Record 421 | rio gallegos
# Processing Record 422 | aktau
# Processing Record 423 | san quintin
# Processing Record 424 | srednekolymsk
# Processing Record 425 | vostochnyy
# Processing Record 426 | teguldet
# Processing Record 427 | prince rupert
# Processing Record 428 | ziniare
# Processing Record 429 | hunza
# Missing field/result... skipping.
# Processing Record 430 | coquimbo
# Processing Record 431 | potosi
# Processing Record 432 | zhigansk
# Processing Record 433 | saint-francois
# Processing Record 434 | zeya
# Processing Record 435 | sirfa
# Missing field/result... skipping.
# Processing Record 436 | comodoro rivadavia
# Processing Record 437 | marsa matruh
# Processing Record 438 | brazzaville
# Processing Record 439 | bandarbeyla
# Processing Record 440 | manggar
# Processing Record 441 | raga
# Missing field/result... skipping.
# Processing Record 442 | flin flon
# Processing Record 443 | bydgoszcz
# Processing Record 444 | malwan
# Missing field/result... skipping.
# Processing Record 445 | carballo
# Processing Record 446 | acajutla
# Processing Record 447 | neiafu
# Processing Record 448 | ivdel
# Processing Record 449 | marzuq
# Processing Record 450 | ambilobe
# Processing Record 451 | gryazovets
# Processing Record 452 | yumen
# Processing Record 453 | west bay
# Processing Record 454 | melfi
# Processing Record 455 | anqing
# Processing Record 456 | gondanglegi
# Processing Record 457 | launceston
# Processing Record 458 | sibolga
# Processing Record 459 | omsukchan
# Processing Record 460 | merauke
# Processing Record 461 | bhum
# Processing Record 462 | cullman
# Processing Record 463 | talnakh
# Processing Record 464 | oktyabrskiy
# Processing Record 465 | necochea
# Processing Record 466 | rosh pinna
# Processing Record 467 | nhulunbuy
# Processing Record 468 | andros town
# Processing Record 469 | ugoofaaru
# Processing Record 470 | ryzdvyanyy
# Processing Record 471 | naze
# Processing Record 472 | miracema do tocantins
# Processing Record 473 | itarema
# Processing Record 474 | mansfield
# Processing Record 475 | klyuchi
# Processing Record 476 | vicuna
# Missing field/result... skipping.
# Processing Record 477 | alexandria
# Processing Record 478 | esna
# Processing Record 479 | roma
# Processing Record 480 | champerico
# Processing Record 481 | kefar shemaryahu
# Processing Record 482 | ondjiva
# Processing Record 483 | belle fourche
# Processing Record 484 | leningradskiy
# Processing Record 485 | saint-louis
# Processing Record 486 | grootfontein
# Processing Record 487 | aakirkeby
# Missing field/result... skipping.
# Processing Record 488 | tura
# Processing Record 489 | wattegama
# Processing Record 490 | warqla
# Missing field/result... skipping.
# Processing Record 491 | sangar
# Processing Record 492 | mandalgovi
# Processing Record 493 | dhola
# Processing Record 494 | sakassou
# Processing Record 495 | yerbogachen
# Processing Record 496 | qaqortoq
# Processing Record 497 | araouane
# Processing Record 498 | kodinsk
# Processing Record 499 | iberia
# Processing Record 500 | moerai
# Processing Record 501 | saint-pierre
# Processing Record 502 | omboue
# Processing Record 503 | tilichiki
# Processing Record 504 | mimongo
# Processing Record 505 | olinda
# Processing Record 506 | cabedelo
# Processing Record 507 | ayan
# Processing Record 508 | sarangani
# Processing Record 509 | iquique
# Processing Record 510 | borovoy
# Processing Record 511 | benguela
# Processing Record 512 | umm kaddadah
# Processing Record 513 | buraydah
# Processing Record 514 | sur
# Processing Record 515 | kabompo
# Processing Record 516 | evensk
# Processing Record 517 | woodstock
# Processing Record 518 | buariki
# Missing field/result... skipping.
# Processing Record 519 | andenes
# Missing field/result... skipping.
# Processing Record 520 | richards bay
# Processing Record 521 | soyo
# Processing Record 522 | balod
# Processing Record 523 | portland
# Processing Record 524 | puerto penasco
# Processing Record 525 | murdochville
# Processing Record 526 | khormuj
# Missing field/result... skipping.
# Processing Record 527 | maroua
# Processing Record 528 | ravar
# Processing Record 529 | one hundred mile house
# Missing field/result... skipping.
# Processing Record 530 | whitehorse
# Processing Record 531 | abu jubayhah
# Missing field/result... skipping.
# Processing Record 532 | armacao dos buzios
# Missing field/result... skipping.
# Processing Record 533 | codigoro
# Processing Record 534 | marystown
# Processing Record 535 | udachnyy
# Processing Record 536 | ayios matthaios
# Missing field/result... skipping.
# Processing Record 537 | punta alta
# Processing Record 538 | zhovtneve
# Missing field/result... skipping.
# Processing Record 539 | codrington
# Processing Record 540 | sentyabrskiy
# Missing field/result... skipping.
# Processing Record 541 | maceio
# Processing Record 542 | rio grande
# Processing Record 543 | high level
# Processing Record 544 | santa luzia
# Processing Record 545 | bereda
# Processing Record 546 | znamenskoye
# Processing Record 547 | kungurtug
# Processing Record 548 | pakxan
# Processing Record 549 | shache
# Processing Record 550 | de aar
# Processing Record 551 | aranos
# Processing Record 552 | broken hill
# Processing Record 553 | bagan
# Processing Record 554 | kruisfontein
# Processing Record 555 | port hedland
# Processing Record 556 | wagar
# Processing Record 557 | atikokan
# Processing Record 558 | beloha
# Processing Record 559 | padang
# Processing Record 560 | doctor pedro p. pena
# Missing field/result... skipping.
# Processing Record 561 | port macquarie
# Processing Record 562 | lamesa
# Processing Record 563 | izazi
# Processing Record 564 | ruatoria
# Missing field/result... skipping.
# Processing Record 565 | los zacatones
# Processing Record 566 | pevek
# Processing Record 567 | zhanatas
# Missing field/result... skipping.
# Processing Record 568 | puerto colombia
# Processing Record 569 | porto walter
# Processing Record 570 | la poza
# Processing Record 571 | nome
# Processing Record 572 | vila franca do campo
# Processing Record 573 | pangnirtung
# Processing Record 574 | mincivan
# Processing Record 575 | aripuana
# Processing Record 576 | san policarpo
# Processing Record 577 | latung
# Processing Record 578 | nemuro
# Processing Record 579 | pimenta bueno
# Processing Record 580 | okha
# Processing Record 581 | shihezi
# Processing Record 582 | henties bay
# Processing Record 583 | axim
# Processing Record 584 | sorvag
# Missing field/result... skipping.
# Processing Record 585 | tutoia
# Processing Record 586 | te anau
# Processing Record 587 | svetlogorsk
# Processing Record 588 | usinsk
# Processing Record 589 | storsteinnes
# Processing Record 590 | agadir
# Processing Record 591 | hammerfest
# Processing Record 592 | kuala selangor
# Processing Record 593 | sinnamary
# Processing Record 594 | uruacu
# Processing Record 595 | sao felix do xingu
# Processing Record 596 | rosario do sul
# Processing Record 597 | haibowan
# Missing field/result... skipping.
# Processing Record 598 | dzialdowo
# Processing Record 599 | kulhudhuffushi
# Processing Record 600 | lasa
# Processing Record 601 | huinan
# Processing Record 602 | mirnyy
# Processing Record 603 | kawalu
# Processing Record 604 | pinotepa nacional
# Missing field/result... skipping.
# Processing Record 605 | namwala
# Processing Record 606 | aleksandrovskoye
# Processing Record 607 | auch
# Processing Record 608 | kasongo-lunda
# Processing Record 609 | tongren
# Processing Record 610 | chifeng
# Processing Record 611 | ocosingo
# Processing Record 612 | upington
# Processing Record 613 | inirida
# Processing Record 614 | junction city
# Processing Record 615 | shimoda
# Processing Record 616 | bainbridge
# Processing Record 617 | broome
# Processing Record 618 | cam pha
# Missing field/result... skipping.
# Processing Record 619 | maarianhamina
# Missing field/result... skipping.
# Processing Record 620 | lichinga
# Processing Record 621 | shieli
# Processing Record 622 | tigzirt
# Processing Record 623 | tabou
# Processing Record 624 | katangli
# Processing Record 625 | fomboni
# Processing Record 626 | fiumicino
# Processing Record 627 | bonthe
# Processing Record 628 | palembang
# Processing Record 629 | carayao
# Processing Record 630 | shakiso
# Processing Record 631 | vaitape
# Processing Record 632 | upata
# Processing Record 633 | thomaston
# Processing Record 634 | anloga
# Processing Record 635 | lhuntshi
# Missing field/result... skipping.
# Processing Record 636 | tombouctou
# Processing Record 637 | araceli
# Processing Record 638 | opuwo
# Processing Record 639 | concepcion
# Processing Record 640 | barawe
# Missing field/result... skipping.
# Processing Record 641 | rodopolis
# Processing Record 642 | asheboro
# Processing Record 643 | cedar city
# Processing Record 644 | hemnesberget
# Processing Record 645 | kendari
# Processing Record 646 | kuytun
# Processing Record 647 | pervomayskoye
# Processing Record 648 | dunedin
# Processing Record 649 | kismayo
# Missing field/result... skipping.
# Processing Record 650 | westport
# Processing Record 651 | tastur
# Processing Record 652 | paducah
# Processing Record 653 | mount gambier
# Processing Record 654 | fort nelson
# Processing Record 655 | masuda
# Processing Record 656 | akyab
# Missing field/result... skipping.
# Processing Record 657 | deh rawud
# Missing field/result... skipping.
# Processing Record 658 | huancavelica
# Processing Record 659 | tres lagoas
# Missing field/result... skipping.
# Processing Record 660 | bilma
# Processing Record 661 | kalabo
# Processing Record 662 | jalu
# Processing Record 663 | bathsheba
# Processing Record 664 | mackay
# Processing Record 665 | brufut
# Processing Record 666 | naryan-mar
# Processing Record 667 | yeppoon
# Processing Record 668 | cayambe
# Processing Record 669 | san luis
# Processing Record 670 | kisangani
# Processing Record 671 | lakatoro
# Processing Record 672 | salalah
# Processing Record 673 | cagsiay
# Processing Record 674 | burica
# Missing field/result... skipping.
# Processing Record 675 | dali
# Processing Record 676 | glenwood springs
# Processing Record 677 | dolbeau
# Missing field/result... skipping.
# Processing Record 678 | babanusah
# Missing field/result... skipping.
# Processing Record 679 | general roca
# Processing Record 680 | khonuu
# Missing field/result... skipping.
# Processing Record 681 | the valley
# Processing Record 682 | diamantino
# Processing Record 683 | tarancon
# Processing Record 684 | cairns
# Processing Record 685 | ahmadpur sial
# Processing Record 686 | geraldton
# Processing Record 687 | aksarka
# Processing Record 688 | coahuayana
# Processing Record 689 | dawson creek
# Processing Record 690 | biak
# Processing Record 691 | rancho mirage
# Processing Record 692 | tarudant
# Missing field/result... skipping.
# Processing Record 693 | karaton
# Processing Record 694 | ejido
# Processing Record 695 | abdanan
# Processing Record 696 | quatre cocos
# Processing Record 697 | changji
# Processing Record 698 | tolga
# Processing Record 699 | nana
# Processing Record 700 | lima
# Processing Record 701 | mutoko
# Processing Record 702 | marsh harbour
# Processing Record 703 | san andres
# Processing Record 704 | santa maria
# Processing Record 705 | mount isa
# Processing Record 706 | marawi
# Processing Record 707 | sicamous
# Processing Record 708 | mabaruma
# Processing Record 709 | karauzyak
# Missing field/result... skipping.
# Processing Record 710 | port-gentil
# Processing Record 711 | touros
# Processing Record 712 | nantucket
# Processing Record 713 | nador
# Processing Record 714 | saldanha
# Processing Record 715 | rovaniemi
# Processing Record 716 | tahe
# Processing Record 717 | genhe
# Processing Record 718 | jombang
# Processing Record 719 | darnah
# Processing Record 720 | kalmunai
# Processing Record 721 | havelock
# Processing Record 722 | jijiga
# Processing Record 723 | kalaleh
# Processing Record 724 | lufilufi
# Processing Record 725 | karachi
# Processing Record 726 | clyde
# Processing Record 727 | boende
# Processing Record 728 | northam
# Processing Record 729 | sete
# Processing Record 730 | turukhansk
# Processing Record 731 | yar-sale
# Processing Record 732 | vanimo
# Processing Record 733 | montivilliers
# Processing Record 734 | mahibadhoo
# Processing Record 735 | bakchar
# Processing Record 736 | sorong
# Processing Record 737 | zyryanovsk
# Processing Record 738 | jieshi
# Processing Record 739 | marienburg
# Processing Record 740 | sambava
# Processing Record 741 | nelson bay
# Processing Record 742 | svecha
# Processing Record 743 | peruibe
# Processing Record 744 | kuttanallur
# Missing field/result... skipping.
# Processing Record 745 | grand gaube
# Processing Record 746 | kalmar
# Processing Record 747 | uvalde
# Processing Record 748 | cockburn harbour
# Missing field/result... skipping.
# Processing Record 749 | tawkar
# Missing field/result... skipping.
# Processing Record 750 | canutama
# Processing Record 751 | dhaulpur
# Processing Record 752 | oeiras do para
# Processing Record 753 | kamenka
# Processing Record 754 | asayita
# Missing field/result... skipping.
# Processing Record 755 | conakry
# Processing Record 756 | beisfjord
# Processing Record 757 | bow island
# Processing Record 758 | poum
# Processing Record 759 | newport
# Processing Record 760 | kjopsvik
# Processing Record 761 | ballarat
# Processing Record 762 | mangai
# Processing Record 763 | camocim
# Processing Record 764 | bac can
# Missing field/result... skipping.
# Processing Record 765 | santo augusto
# Processing Record 766 | del rio
# Processing Record 767 | diego de almagro
# Processing Record 768 | tosya
# Processing Record 769 | guerrero
# Processing Record 770 | bundaberg
# Processing Record 771 | yazykovo
# Processing Record 772 | nikolayevsk-na-amure
# Processing Record 773 | uvinza
# Processing Record 774 | chissamba
# Missing field/result... skipping.
# Processing Record 775 | louisbourg
# Missing field/result... skipping.
# Processing Record 776 | huilong
# Processing Record 777 | mubi
# Processing Record 778 | hikari
# Processing Record 779 | balkhash
# Processing Record 780 | barra patuca
# Processing Record 781 | sredniy ikorets
# Processing Record 782 | lensk
# Processing Record 783 | afsin
# Processing Record 784 | ambulu
# Processing Record 785 | novo aripuana
# Processing Record 786 | colinas
# Processing Record 787 | acarau
# Missing field/result... skipping.
# Processing Record 788 | kysyl-syr
# Processing Record 789 | pineville
# Processing Record 790 | fairbanks
# Processing Record 791 | inuvik
# Processing Record 792 | merrill
# Processing Record 793 | sept-iles
# Processing Record 794 | paciran
# Processing Record 795 | santa cruz
# Processing Record 796 | caraquet
# Processing Record 797 | nabire
# Processing Record 798 | boden
# Processing Record 799 | palana
# Processing Record 800 | xingyi
# Processing Record 801 | cockburn town
# Processing Record 802 | chabahar
# Processing Record 803 | san francisco
# Processing Record 804 | shaunavon
# Processing Record 805 | pemangkat
# Missing field/result... skipping.
# Processing Record 806 | bonavista
# Processing Record 807 | prado
# Processing Record 808 | kutum
# Processing Record 809 | mopipi
# Processing Record 810 | sri aman
# Processing Record 811 | presidencia roque saenz pena
# Processing Record 812 | boizenburg
# Processing Record 813 | honningsvag
# Processing Record 814 | morant bay
# Processing Record 815 | malakal
# Missing field/result... skipping.
# Processing Record 816 | grand-lahou
# Processing Record 817 | newton
# Processing Record 818 | mariveles
# Processing Record 819 | boyuibe
# Processing Record 820 | marrakesh
# Processing Record 821 | cananeia
# Processing Record 822 | pabrade
# Processing Record 823 | abalak
# Processing Record 824 | vestmanna
# Processing Record 825 | bilibino
# Processing Record 826 | sivas
# Processing Record 827 | gazojak
# Processing Record 828 | atbasar
# Processing Record 829 | palabuhanratu
# Missing field/result... skipping.
# Processing Record 830 | anda
# Processing Record 831 | nuuk
# Processing Record 832 | buala
# Processing Record 833 | toktogul
# Processing Record 834 | linhares
# Processing Record 835 | berdigestyakh
# Processing Record 836 | aflu
# Missing field/result... skipping.
# Processing Record 837 | dhanera
# Processing Record 838 | qazvin
# Processing Record 839 | bambanglipuro
# Processing Record 840 | aswan
# Processing Record 841 | issia
# Processing Record 842 | tripoli
# Processing Record 843 | fare
# Processing Record 844 | pampierstad
# Processing Record 845 | yeletskiy
# Missing field/result... skipping.
# Processing Record 846 | abilene
# Processing Record 847 | kiruna
# Processing Record 848 | sheridan
# Processing Record 849 | kholodnyy
# Processing Record 850 | bolungarvik
# Missing field/result... skipping.
# Processing Record 851 | kizukuri
# Processing Record 852 | sarankhola
# Processing Record 853 | bekovo
# Processing Record 854 | barabai
# Processing Record 855 | banbury
# Processing Record 856 | lac-au-saumon
# Processing Record 857 | alofi
# Processing Record 858 | ostersund
# Processing Record 859 | krasnoselkup
# Missing field/result... skipping.
# Processing Record 860 | nizhniy baskunchak
# Processing Record 861 | cherepovets
# Processing Record 862 | zolotinka
# Missing field/result... skipping.
# Processing Record 863 | hargeysa
# Processing Record 864 | garhi khairo
# Processing Record 865 | bambari
# Processing Record 866 | sandy bay
# Processing Record 867 | quimper
# Processing Record 868 | minot
# Processing Record 869 | nassjo
# Processing Record 870 | labuhan
# Processing Record 871 | puteyets
# Processing Record 872 | deputatskiy
# Processing Record 873 | port-cartier
# Processing Record 874 | tiarei
# Processing Record 875 | eureka
# Processing Record 876 | sungairaya
# Processing Record 877 | halalo
# Missing field/result... skipping.
# Processing Record 878 | seoul
# Processing Record 879 | gasa
# Processing Record 880 | jiddah
# Missing field/result... skipping.
# Processing Record 881 | nizwa
# Processing Record 882 | benemerito de las americas
# Processing Record 883 | amurzet
# Processing Record 884 | bubaque
# Processing Record 885 | discovery bay
# Processing Record 886 | santo domingo
# Processing Record 887 | medicine hat
# Processing Record 888 | loandjili
# Processing Record 889 | kimbe
# Processing Record 890 | liuzhou

# %%
weather_response_json
# Out:
# [{'coord': {'lon': -73.76, 'lat': -42.48},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 53.6,
#    'pressure': 1008,
#    'humidity': 100,
#    'temp_min': 53.6,
#    'temp_max': 53.6},
#   'visibility': 1500,
#   'wind': {'speed': 21.92, 'deg': 340},
#   'clouds': {'all': 90},
#   'dt': 1555444800,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0043,
#    'country': 'CL',
#    'sunrise': 1555414054,
#    'sunset': 1555453305},
#   'id': 3896218,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': 37.18, 'lat': 35.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 51.89,
#    'pressure': 1010.047,
#    'humidity': 82,
#    'temp_min': 51.89,
#    'temp_max': 51.89,
#    'sea_level': 1010.047,
#    'grnd_level': 964.565},
#   'wind': {'speed': 10.92, 'deg': 245.489},
#   'clouds': {'all': 6},
#   'dt': 1555449881,
#   'sys': {'message': 0.0054,
#    'country': 'SY',
#    'sunrise': 1555469812,
#    'sunset': 1555517076},
#   'id': 172515,
#   'name': 'Abu Samrah',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 41,
#    'pressure': 1037,
#    'humidity': 97,
#    'temp_min': 41,
#    'temp_max': 41},
#   'wind': {'speed': 1.01, 'deg': 301, 'gust': 3.13},
#   'clouds': {'all': 0},
#   'dt': 1555449605,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'message': 0.0045,
#    'country': 'NZ',
#    'sunrise': 1555442546,
#    'sunset': 1555481146},
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': -67.52, 'lat': -46.43},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 64.49,
#    'pressure': 994.867,
#    'humidity': 41,
#    'temp_min': 64.49,
#    'temp_max': 64.49,
#    'sea_level': 994.867,
#    'grnd_level': 960.357},
#   'wind': {'speed': 19.53, 'deg': 255.38},
#   'clouds': {'all': 74},
#   'dt': 1555449881,
#   'sys': {'message': 0.005,
#    'country': 'AR',
#    'sunrise': 1555412871,
#    'sunset': 1555451493},
#   'id': 3863379,
#   'name': 'Mar del Plata',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 134.14, 'lat': 33.37},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 52.79,
#    'pressure': 1016.345,
#    'humidity': 69,
#    'temp_min': 52.79,
#    'temp_max': 52.79,
#    'sea_level': 1016.345,
#    'grnd_level': 981.045},
#   'wind': {'speed': 5.01, 'deg': 41.296},
#   'clouds': {'all': 100},
#   'dt': 1555449881,
#   'sys': {'message': 0.0048,
#    'country': 'JP',
#    'sunrise': 1555446692,
#    'sunset': 1555493663},
#   'id': 1856392,
#   'name': 'Muroto',
#   'cod': 200},
#  {'coord': {'lon': -68.39, 'lat': -31.67},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 83.21,
#    'pressure': 1009.855,
#    'humidity': 31,
#    'temp_min': 83.21,
#    'temp_max': 83.21,
#    'sea_level': 1009.855,
#    'grnd_level': 939.461},
#   'wind': {'speed': 5.23, 'deg': 96.733},
#   'clouds': {'all': 0},
#   'dt': 1555449881,
#   'sys': {'message': 0.005,
#    'country': 'AR',
#    'sunrise': 1555412064,
#    'sunset': 1555452717},
#   'id': 3842882,
#   'name': 'Nueve de Julio',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 82.13,
#    'pressure': 1012.507,
#    'humidity': 77,
#    'temp_min': 82.13,
#    'temp_max': 82.13,
#    'sea_level': 1012.507,
#    'grnd_level': 1012.453},
#   'wind': {'speed': 12.66, 'deg': 94.5},
#   'clouds': {'all': 77},
#   'dt': 1555449623,
#   'sys': {'message': 0.005,
#    'country': 'PF',
#    'sunrise': 1555427962,
#    'sunset': 1555470721},
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': -133.03, 'lat': 69.44},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 15.8,
#    'pressure': 1008,
#    'humidity': 66,
#    'temp_min': 15.8,
#    'temp_max': 15.8},
#   'visibility': 24140,
#   'wind': {'speed': 13.87, 'deg': 120},
#   'clouds': {'all': 20},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 942,
#    'message': 0.0064,
#    'country': 'CA',
#    'sunrise': 1555418791,
#    'sunset': 1555477012},
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77.63,
#    'pressure': 1016.115,
#    'humidity': 20,
#    'temp_min': 77.63,
#    'temp_max': 77.63,
#    'sea_level': 1016.115,
#    'grnd_level': 986.853},
#   'wind': {'speed': 17.22, 'deg': 344.105},
#   'clouds': {'all': 100},
#   'dt': 1555449786,
#   'sys': {'message': 0.0052,
#    'country': 'AU',
#    'sunrise': 1555448894,
#    'sunset': 1555489321},
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': 22.34, 'lat': 39.45},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 49.01,
#    'pressure': 1017,
#    'humidity': 87,
#    'temp_min': 48.2,
#    'temp_max': 50},
#   'visibility': 10000,
#   'wind': {'speed': 1.1, 'deg': 182.203},
#   'clouds': {'all': 40},
#   'dt': 1555444200,
#   'sys': {'type': 1,
#    'id': 6629,
#    'message': 0.004,
#    'country': 'GR',
#    'sunrise': 1555473064,
#    'sunset': 1555520946},
#   'id': 262462,
#   'name': 'Saint George',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -56.83, 'lat': -26.98},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 72.41,
#    'pressure': 1013.657,
#    'humidity': 78,
#    'temp_min': 72.41,
#    'temp_max': 72.41,
#    'sea_level': 1013.657,
#    'grnd_level': 1002.021},
#   'wind': {'speed': 7.18, 'deg': 161.853},
#   'clouds': {'all': 5},
#   'dt': 1555449882,
#   'sys': {'message': 0.0038,
#    'country': 'PY',
#    'sunrise': 1555409035,
#    'sunset': 1555450199},
#   'id': 3437029,
#   'name': 'San Patricio',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 44.49,
#    'pressure': 987,
#    'humidity': 70,
#    'temp_min': 42.01,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 31.09, 'deg': 270},
#   'clouds': {'all': 40},
#   'dt': 1555449193,
#   'sys': {'type': 1,
#    'id': 8487,
#    'message': 0.004,
#    'country': 'CL',
#    'sunrise': 1555414348,
#    'sunset': 1555451643},
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 27.91, 'lat': -33.02},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 57.29,
#    'pressure': 1022.479,
#    'humidity': 87,
#    'temp_min': 57.29,
#    'temp_max': 57.29,
#    'sea_level': 1022.479,
#    'grnd_level': 986.037},
#   'wind': {'speed': 5.28, 'deg': 268.203},
#   'rain': {'3h': 0.375},
#   'clouds': {'all': 96},
#   'dt': 1555449882,
#   'sys': {'message': 0.0042,
#    'country': 'ZA',
#    'sunrise': 1555389018,
#    'sunset': 1555429547},
#   'id': 1006984,
#   'name': 'East London',
#   'cod': 200},
#  {'coord': {'lon': -77.4, 'lat': 6.23},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.33,
#    'pressure': 1007.761,
#    'humidity': 85,
#    'temp_min': 80.33,
#    'temp_max': 80.33,
#    'sea_level': 1007.761,
#    'grnd_level': 1010.901},
#   'wind': {'speed': 9.84, 'deg': 276.477},
#   'clouds': {'all': 100},
#   'dt': 1555449882,
#   'sys': {'message': 0.0131,
#    'country': 'CO',
#    'sunrise': 1555412482,
#    'sunset': 1555456624},
#   'id': 3689325,
#   'name': 'Mutis',
#   'cod': 200},
#  {'coord': {'lon': -69.36, 'lat': 77.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': -5.18,
#    'pressure': 1013.311,
#    'humidity': 98,
#    'temp_min': -5.18,
#    'temp_max': -5.18,
#    'sea_level': 1013.311,
#    'grnd_level': 960.549},
#   'wind': {'speed': 9.44, 'deg': 297.312},
#   'clouds': {'all': 99},
#   'dt': 1555449883,
#   'sys': {'message': 0.01,
#    'country': 'GL',
#    'sunrise': 1555396532,
#    'sunset': 1555468715},
#   'id': 3831208,
#   'name': 'Qaanaaq',
#   'cod': 200},
#  {'coord': {'lon': -16.33, 'lat': 33.08},
#   'weather': [{'id': 300,
#     'main': 'Drizzle',
#     'description': 'light intensity drizzle',
#     'icon': '09n'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'},
#    {'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 59.23,
#    'pressure': 1011,
#    'humidity': 93,
#    'temp_min': 57.2,
#    'temp_max': 60.8},
#   'visibility': 5000,
#   'wind': {'speed': 18.34, 'deg': 310},
#   'clouds': {'all': 75},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 6902,
#    'message': 0.0056,
#    'country': 'PT',
#    'sunrise': 1555396466,
#    'sunset': 1555443331},
#   'id': 2270385,
#   'name': 'Camacha',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77.23,
#    'pressure': 1020,
#    'humidity': 65,
#    'temp_min': 75.99,
#    'temp_max': 78.8},
#   'visibility': 16093,
#   'wind': {'speed': 10.29, 'deg': 50},
#   'clouds': {'all': 75},
#   'dt': 1555449812,
#   'sys': {'type': 1,
#    'id': 7873,
#    'message': 0.0054,
#    'country': 'US',
#    'sunrise': 1555431389,
#    'sunset': 1555477032},
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  {'coord': {'lon': 147.06, 'lat': -42.78},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.06,
#    'pressure': 1017,
#    'humidity': 52,
#    'temp_min': 59,
#    'temp_max': 66.2},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 30},
#   'clouds': {'all': 75},
#   'dt': 1555449621,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0059,
#    'country': 'AU',
#    'sunrise': 1555447506,
#    'sunset': 1555486649},
#   'id': 2155415,
#   'name': 'New Norfolk',
#   'cod': 200},
#  {'coord': {'lon': -117.11, 'lat': 32.58},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 61.02,
#    'pressure': 1017,
#    'humidity': 63,
#    'temp_min': 55.99,
#    'temp_max': 66.2},
#   'visibility': 16093,
#   'wind': {'speed': 9.17, 'deg': 240},
#   'clouds': {'all': 90},
#   'dt': 1555449763,
#   'sys': {'type': 1,
#    'id': 5796,
#    'message': 0.01,
#    'country': 'US',
#    'sunrise': 1555420665,
#    'sunset': 1555467498},
#   'id': 5359054,
#   'name': 'Imperial Beach',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 45.14,
#    'pressure': 982,
#    'humidity': 65,
#    'temp_min': 44.6,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 8.97, 'deg': 277.53},
#   'clouds': {'all': 40},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 8303,
#    'message': 0.0093,
#    'country': 'AR',
#    'sunrise': 1555413918,
#    'sunset': 1555450825},
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -173.23, 'lat': 64.42},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 21.2,
#    'pressure': 1012,
#    'humidity': 62,
#    'temp_min': 21.2,
#    'temp_max': 21.2},
#   'visibility': 10000,
#   'wind': {'speed': 2.24},
#   'clouds': {'all': 0},
#   'dt': 1555446600,
#   'sys': {'type': 1,
#    'id': 8875,
#    'message': 0.0051,
#    'country': 'RU',
#    'sunrise': 1555516328,
#    'sunset': 1555571541},
#   'id': 4031574,
#   'name': 'Provideniya',
#   'cod': 200},
#  {'coord': {'lon': -0.29, 'lat': 27.87},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 82.4,
#    'pressure': 1015,
#    'humidity': 9,
#    'temp_min': 82.4,
#    'temp_max': 82.4},
#   'visibility': 10000,
#   'wind': {'speed': 4.38, 'deg': 44.896},
#   'clouds': {'all': 0},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 1098,
#    'message': 0.0051,
#    'country': 'DZ',
#    'sunrise': 1555392932,
#    'sunset': 1555439167},
#   'id': 2508813,
#   'name': 'Adrar',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 82.4,
#    'pressure': 1014,
#    'humidity': 88,
#    'temp_min': 82.4,
#    'temp_max': 82.4},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 20},
#   'rain': {'3h': 3.25},
#   'clouds': {'all': 100},
#   'dt': 1555446600,
#   'sys': {'type': 1,
#    'id': 7271,
#    'message': 0.0067,
#    'country': 'CK',
#    'sunrise': 1555433462,
#    'sunset': 1555475179},
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': -17.92, 'lat': 28.66},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 60.42,
#    'pressure': 1015,
#    'humidity': 72,
#    'temp_min': 57,
#    'temp_max': 64.4},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 270},
#   'clouds': {'all': 20},
#   'dt': 1555449625,
#   'sys': {'type': 1,
#    'id': 2377,
#    'message': 0.0063,
#    'country': 'ES',
#    'sunrise': 1555397115,
#    'sunset': 1555443445},
#   'id': 2514651,
#   'name': 'Los Llanos de Aridane',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 75.29,
#    'pressure': 1009.849,
#    'humidity': 91,
#    'temp_min': 75.29,
#    'temp_max': 75.29,
#    'sea_level': 1009.849,
#    'grnd_level': 1003.461},
#   'wind': {'speed': 2.13, 'deg': 43.937},
#   'clouds': {'all': 0},
#   'dt': 1555449633,
#   'sys': {'message': 0.0041,
#    'country': 'IN',
#    'sunrise': 1555461995,
#    'sunset': 1555506988},
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': 161.3, 'lat': 68.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 15.17,
#    'pressure': 1016.407,
#    'humidity': 87,
#    'temp_min': 15.17,
#    'temp_max': 15.17,
#    'sea_level': 1016.407,
#    'grnd_level': 1016.357},
#   'wind': {'speed': 7.29, 'deg': 198.229},
#   'clouds': {'all': 0},
#   'dt': 1555449884,
#   'sys': {'message': 0.0045,
#    'country': 'RU',
#    'sunrise': 1555434794,
#    'sunset': 1555492526},
#   'id': 2126199,
#   'name': 'Cherskiy',
#   'cod': 200},
#  {'coord': {'lon': -114.38, 'lat': 62.45},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 24.75,
#    'pressure': 1009,
#    'humidity': 79,
#    'temp_min': 23,
#    'temp_max': 27},
#   'visibility': 16093,
#   'wind': {'speed': 8.05, 'deg': 170},
#   'clouds': {'all': 90},
#   'dt': 1555449552,
#   'sys': {'type': 1,
#    'id': 1007,
#    'message': 0.0062,
#    'country': 'CA',
#    'sunrise': 1555416548,
#    'sunset': 1555470305},
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 79.57, 'lat': 30.57},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 43.79,
#    'pressure': 1018.763,
#    'humidity': 40,
#    'temp_min': 43.79,
#    'temp_max': 43.79,
#    'sea_level': 1018.763,
#    'grnd_level': 742.101},
#   'wind': {'speed': 4.7, 'deg': 26.882},
#   'clouds': {'all': 84},
#   'dt': 1555449884,
#   'sys': {'message': 0.0275,
#    'country': 'IN',
#    'sunrise': 1555459957,
#    'sunset': 1555506588},
#   'id': 1268814,
#   'name': 'Joshimath',
#   'cod': 200},
#  {'coord': {'lon': -109.91, 'lat': 22.89},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 75.38,
#    'pressure': 1017,
#    'humidity': 56,
#    'temp_min': 69.01,
#    'temp_max': 82},
#   'visibility': 16093,
#   'wind': {'speed': 25.28, 'deg': 270},
#   'clouds': {'all': 75},
#   'dt': 1555449609,
#   'sys': {'type': 1,
#    'id': 7151,
#    'message': 0.0053,
#    'country': 'MX',
#    'sunrise': 1555419495,
#    'sunset': 1555465213},
#   'id': 3985710,
#   'name': 'Cabo San Lucas',
#   'cod': 200},
#  {'coord': {'lon': -74.36, 'lat': 39.41},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 65.03,
#    'pressure': 1016,
#    'humidity': 29,
#    'temp_min': 62.01,
#    'temp_max': 66.99},
#   'visibility': 16093,
#   'wind': {'speed': 18.34, 'deg': 270, 'gust': 12.9},
#   'clouds': {'all': 1},
#   'dt': 1555449842,
#   'sys': {'type': 1,
#    'id': 3222,
#    'message': 0.0068,
#    'country': 'US',
#    'sunrise': 1555409939,
#    'sunset': 1555457708},
#   'id': 4500920,
#   'name': 'Brigantine',
#   'cod': 200},
#  {'coord': {'lon': -52.73, 'lat': 47.66},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 39.02,
#    'pressure': 982,
#    'humidity': 93,
#    'temp_min': 37.99,
#    'temp_max': 41},
#   'visibility': 24140,
#   'wind': {'speed': 17.22, 'deg': 230, 'gust': 10.8},
#   'clouds': {'all': 90},
#   'dt': 1555449505,
#   'sys': {'type': 1,
#    'id': 998,
#    'message': 0.0074,
#    'country': 'CA',
#    'sunrise': 1555404027,
#    'sunset': 1555453239},
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'coord': {'lon': 9.81, 'lat': 3.63},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 84.47,
#    'pressure': 1010.201,
#    'humidity': 75,
#    'temp_min': 84.47,
#    'temp_max': 84.47,
#    'sea_level': 1010.201,
#    'grnd_level': 1009.733},
#   'wind': {'speed': 10.2, 'deg': 235.145},
#   'clouds': {'all': 100},
#   'dt': 1555449884,
#   'sys': {'message': 0.0048,
#    'country': 'CM',
#    'sunrise': 1555391669,
#    'sunset': 1555435583},
#   'id': 2225940,
#   'name': 'Yatou',
#   'cod': 200},
#  {'coord': {'lon': 72.51, 'lat': 65.53},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': -6.07,
#    'pressure': 1016.379,
#    'humidity': 92,
#    'temp_min': -6.07,
#    'temp_max': -6.07,
#    'sea_level': 1016.379,
#    'grnd_level': 1013.173},
#   'wind': {'speed': 21.45, 'deg': 7.616},
#   'clouds': {'all': 100},
#   'dt': 1555449884,
#   'sys': {'message': 0.0062,
#    'country': 'RU',
#    'sunrise': 1555457176,
#    'sunset': 1555512756},
#   'id': 1498087,
#   'name': 'Nadym',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 63.95,
#    'pressure': 1019.981,
#    'humidity': 81,
#    'temp_min': 63.95,
#    'temp_max': 63.95,
#    'sea_level': 1019.981,
#    'grnd_level': 994.757},
#   'wind': {'speed': 9.28, 'deg': 130.529},
#   'clouds': {'all': 0},
#   'dt': 1555449885,
#   'sys': {'message': 0.0049,
#    'country': 'AU',
#    'sunrise': 1555445858,
#    'sunset': 1555487332},
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': -73.48, 'lat': 45.36},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 46.98,
#    'pressure': 1013,
#    'humidity': 45,
#    'temp_min': 44.6,
#    'temp_max': 48.99},
#   'visibility': 14484,
#   'wind': {'speed': 12.75, 'deg': 320, 'gust': 8.7},
#   'clouds': {'all': 90},
#   'dt': 1555449794,
#   'sys': {'type': 1,
#    'id': 820,
#    'message': 0.0064,
#    'country': 'CA',
#    'sunrise': 1555409226,
#    'sunset': 1555457998},
#   'id': 6138908,
#   'name': 'Saint-Philippe',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77.45,
#    'pressure': 1015.027,
#    'humidity': 84,
#    'temp_min': 77.45,
#    'temp_max': 77.45,
#    'sea_level': 1015.027,
#    'grnd_level': 1014.773},
#   'wind': {'speed': 13.04, 'deg': 118.311},
#   'clouds': {'all': 82},
#   'dt': 1555449623,
#   'sys': {'message': 0.005,
#    'country': 'PF',
#    'sunrise': 1555427599,
#    'sunset': 1555469135},
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': -155.08, 'lat': 19.71},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 74.41,
#    'pressure': 1019,
#    'humidity': 65,
#    'temp_min': 70,
#    'temp_max': 78.8},
#   'visibility': 16093,
#   'wind': {'speed': 5.82},
#   'clouds': {'all': 75},
#   'dt': 1555449857,
#   'sys': {'type': 1,
#    'id': 7881,
#    'message': 0.0163,
#    'country': 'US',
#    'sunrise': 1555430493,
#    'sunset': 1555475893},
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'coord': {'lon': 38.09, 'lat': 4.89},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 62.87,
#    'pressure': 1015.611,
#    'humidity': 90,
#    'temp_min': 62.87,
#    'temp_max': 62.87,
#    'sea_level': 1015.611,
#    'grnd_level': 836.885},
#   'wind': {'speed': 8.48, 'deg': 92.635},
#   'rain': {'3h': 4.688},
#   'clouds': {'all': 51},
#   'dt': 1555449885,
#   'sys': {'message': 0.0046,
#    'country': 'ET',
#    'sunrise': 1555471208,
#    'sunset': 1555515244},
#   'id': 326036,
#   'name': 'Yabelo',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 80.55, 'lat': 73.51},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': -12.56,
#    'pressure': 1021.965,
#    'humidity': 100,
#    'temp_min': -12.56,
#    'temp_max': -12.56,
#    'sea_level': 1021.965,
#    'grnd_level': 1021.669},
#   'wind': {'speed': 3.71, 'deg': 22.652},
#   'clouds': {'all': 51},
#   'dt': 1555449885,
#   'sys': {'message': 0.0064,
#    'country': 'RU',
#    'sunrise': 1555451421,
#    'sunset': 1555514653},
#   'id': 1507390,
#   'name': 'Dikson',
#   'cod': 200},
#  {'coord': {'lon': 71.79, 'lat': 35.85},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 20.75,
#    'pressure': 1017.663,
#    'humidity': 81,
#    'temp_min': 20.75,
#    'temp_max': 20.75,
#    'sea_level': 1017.663,
#    'grnd_level': 643.621},
#   'wind': {'speed': 2.1, 'deg': 12.972},
#   'clouds': {'all': 100},
#   'dt': 1555449885,
#   'sys': {'message': 0.0042,
#    'country': 'PK',
#    'sunrise': 1555461475,
#    'sunset': 1555508803},
#   'id': 1181065,
#   'name': 'Chitral',
#   'cod': 200},
#  {'coord': {'lon': -161.76, 'lat': 60.79},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 23.45,
#    'pressure': 1007,
#    'humidity': 58,
#    'temp_min': 21.2,
#    'temp_max': 24.8},
#   'visibility': 16093,
#   'wind': {'speed': 14.99, 'deg': 340},
#   'clouds': {'all': 90},
#   'dt': 1555448160,
#   'sys': {'type': 1,
#    'id': 7640,
#    'message': 0.0057,
#    'country': 'US',
#    'sunrise': 1555428258,
#    'sunset': 1555481334},
#   'id': 5880568,
#   'name': 'Bethel',
#   'cod': 200},
#  {'coord': {'lon': 123.37, 'lat': 13.56},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77.27,
#    'pressure': 1011.395,
#    'humidity': 87,
#    'temp_min': 77.27,
#    'temp_max': 77.27,
#    'sea_level': 1011.395,
#    'grnd_level': 1007.061},
#   'wind': {'speed': 3.76, 'deg': 89.455},
#   'clouds': {'all': 66},
#   'dt': 1555449886,
#   'sys': {'message': 0.0071,
#    'country': 'PH',
#    'sunrise': 1555450353,
#    'sunset': 1555495171},
#   'id': 1697332,
#   'name': 'Ocampo',
#   'cod': 200},
#  {'coord': {'lon': -45.24, 'lat': 60.14},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 35.15,
#    'pressure': 1005.401,
#    'humidity': 79,
#    'temp_min': 35.15,
#    'temp_max': 35.15,
#    'sea_level': 1005.401,
#    'grnd_level': 1002.037},
#   'wind': {'speed': 5.48, 'deg': 307.137},
#   'clouds': {'all': 64},
#   'dt': 1555449886,
#   'sys': {'message': 0.0139,
#    'country': 'GL',
#    'sunrise': 1555400483,
#    'sunset': 1555453189},
#   'id': 3421765,
#   'name': 'Nanortalik',
#   'cod': 200},
#  {'coord': {'lon': -28.7, 'lat': 38.52},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 57.2,
#    'pressure': 1013,
#    'humidity': 62,
#    'temp_min': 57.2,
#    'temp_max': 57.2},
#   'visibility': 10000,
#   'wind': {'speed': 17.22, 'deg': 310},
#   'clouds': {'all': 40},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 6883,
#    'message': 0.0054,
#    'country': 'PT',
#    'sunrise': 1555399058,
#    'sunset': 1555446675},
#   'id': 3372707,
#   'name': 'Ribeira Grande',
#   'cod': 200},
#  {'coord': {'lon': 133.88, 'lat': -23.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 60.8,
#    'pressure': 1018,
#    'humidity': 44,
#    'temp_min': 60.8,
#    'temp_max': 60.8},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 290},
#   'clouds': {'all': 6},
#   'dt': 1555446600,
#   'sys': {'type': 1,
#    'id': 9483,
#    'message': 0.0045,
#    'country': 'AU',
#    'sunrise': 1555449510,
#    'sunset': 1555490969},
#   'id': 2077895,
#   'name': 'Alice Springs',
#   'cod': 200},
#  {'coord': {'lon': 156.12, 'lat': 50.68},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 35.15,
#    'pressure': 1006.097,
#    'humidity': 88,
#    'temp_min': 35.15,
#    'temp_max': 35.15,
#    'sea_level': 1006.097,
#    'grnd_level': 1005.845},
#   'wind': {'speed': 41.03, 'deg': 99.998},
#   'clouds': {'all': 100},
#   'dt': 1555449886,
#   'sys': {'message': 0.006,
#    'country': 'RU',
#    'sunrise': 1555439922,
#    'sunset': 1555489884},
#   'id': 2121385,
#   'name': 'Severo-Kurilsk',
#   'cod': 200},
#  {'coord': {'lon': -51.1, 'lat': 69.22},
#   'weather': [{'id': 620,
#     'main': 'Snow',
#     'description': 'light shower snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 17.6,
#    'pressure': 1013,
#    'humidity': 72,
#    'temp_min': 17.6,
#    'temp_max': 17.6},
#   'visibility': 6000,
#   'wind': {'speed': 6.93, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1555447800,
#   'sys': {'type': 1,
#    'id': 165,
#    'message': 0.0052,
#    'country': 'GL',
#    'sunrise': 1555399288,
#    'sunset': 1555457195},
#   'id': 3423146,
#   'name': 'Ilulissat',
#   'cod': 200},
#  {'coord': {'lon': 22.13, 'lat': -30.97},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 61.61,
#    'pressure': 1016.879,
#    'humidity': 24,
#    'temp_min': 61.61,
#    'temp_max': 61.61,
#    'sea_level': 1016.879,
#    'grnd_level': 870.405},
#   'wind': {'speed': 8.03, 'deg': 123.779},
#   'clouds': {'all': 100},
#   'dt': 1555449887,
#   'sys': {'message': 0.0072,
#    'country': 'ZA',
#    'sunrise': 1555390290,
#    'sunset': 1555431049},
#   'id': 1014034,
#   'name': 'Carnarvon',
#   'cod': 200},
#  {'coord': {'lon': 54.36, 'lat': 39.51},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 74.75,
#    'pressure': 1005.131,
#    'humidity': 28,
#    'temp_min': 74.75,
#    'temp_max': 74.75,
#    'sea_level': 1005.131,
#    'grnd_level': 1007.205},
#   'wind': {'speed': 20.8, 'deg': 100.559},
#   'clouds': {'all': 100},
#   'dt': 1555449887,
#   'sys': {'message': 0.005,
#    'country': 'TM',
#    'sunrise': 1555465382,
#    'sunset': 1555513261},
#   'id': 161616,
#   'name': 'Balkanabat',
#   'cod': 200},
#  {'coord': {'lon': -6.59, 'lat': 62.23},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 44.6,
#    'pressure': 1023,
#    'humidity': 87,
#    'temp_min': 44.6,
#    'temp_max': 44.6},
#   'wind': {'speed': 18.34, 'deg': 130},
#   'clouds': {'all': 57},
#   'dt': 1555449600,
#   'sys': {'type': 1,
#    'id': 1596,
#    'message': 0.0042,
#    'country': 'FO',
#    'sunrise': 1555390787,
#    'sunset': 1555444335},
#   'id': 2618795,
#   'name': 'Klaksvik',
#   'cod': 200},
#  {'coord': {'lon': -135.01, 'lat': 68.22},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 24.8,
#    'pressure': 1006,
#    'humidity': 68,
#    'temp_min': 24.8,
#    'temp_max': 24.8},
#   'visibility': 24140,
#   'wind': {'speed': 6.93, 'deg': 150},
#   'clouds': {'all': 75},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 821,
#    'message': 0.0077,
#    'country': 'CA',
#    'sunrise': 1555419767,
#    'sunset': 1555476987},
#   'id': 5882953,
#   'name': 'Aklavik',
#   'cod': 200},
#  {'coord': {'lon': -126.83, 'lat': 65.28},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 28.4,
#    'pressure': 1005,
#    'humidity': 58,
#    'temp_min': 28.4,
#    'temp_max': 28.4},
#   'visibility': 48279,
#   'wind': {'speed': 13.87, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 951,
#    'message': 0.0051,
#    'country': 'CA',
#    'sunrise': 1555418793,
#    'sunset': 1555474035},
#   'id': 6089245,
#   'name': 'Norman Wells',
#   'cod': 200},
#  {'coord': {'lon': 150.8, 'lat': -2.57},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 82.13,
#    'pressure': 1010.013,
#    'humidity': 76,
#    'temp_min': 82.13,
#    'temp_max': 82.13,
#    'sea_level': 1010.013,
#    'grnd_level': 1009.733},
#   'wind': {'speed': 4.18, 'deg': 257.544},
#   'rain': {'3h': 6.562},
#   'clouds': {'all': 100},
#   'dt': 1555449647,
#   'sys': {'message': 0.0051,
#    'country': 'PG',
#    'sunrise': 1555444488,
#    'sunset': 1555487871},
#   'id': 2094342,
#   'name': 'Kavieng',
#   'cod': 200},
#  {'coord': {'lon': -114.04, 'lat': 27.97},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 62.69,
#    'pressure': 1016.141,
#    'humidity': 74,
#    'temp_min': 62.69,
#    'temp_max': 62.69,
#    'sea_level': 1016.141,
#    'grnd_level': 1016.709},
#   'wind': {'speed': 12.06, 'deg': 321.604},
#   'clouds': {'all': 0},
#   'dt': 1555449722,
#   'sys': {'message': 0.0046,
#    'country': 'MX',
#    'sunrise': 1555420207,
#    'sunset': 1555466483},
#   'id': 4021858,
#   'name': 'Guerrero Negro',
#   'cod': 200},
#  {'coord': {'lon': -65.26, 'lat': -24.39},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 71.17,
#    'pressure': 1018,
#    'humidity': 82,
#    'temp_min': 68,
#    'temp_max': 73.4},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 50},
#   'clouds': {'all': 40},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 8267,
#    'message': 0.005,
#    'country': 'AR',
#    'sunrise': 1555410927,
#    'sunset': 1555452352},
#   'id': 3842190,
#   'name': 'El Carmen',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -72.27, 'lat': 11.71},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 91.85,
#    'pressure': 1009.403,
#    'humidity': 41,
#    'temp_min': 91.85,
#    'temp_max': 91.85,
#    'sea_level': 1009.403,
#    'grnd_level': 1004.421},
#   'wind': {'speed': 14.81, 'deg': 80.203},
#   'clouds': {'all': 91},
#   'dt': 1555449889,
#   'sys': {'message': 0.0045,
#    'country': 'CO',
#    'sunrise': 1555411007,
#    'sunset': 1555455636},
#   'id': 3666409,
#   'name': 'Uribia',
#   'cod': 200},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 56.79,
#    'pressure': 1017,
#    'humidity': 92,
#    'temp_min': 54,
#    'temp_max': 59},
#   'wind': {'speed': 17, 'deg': 108.199},
#   'clouds': {'all': 100},
#   'dt': 1555449397,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'message': 0.0045,
#    'country': 'ZA',
#    'sunrise': 1555391182,
#    'sunset': 1555431544},
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': 150.67, 'lat': -10.62},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 74.21,
#    'pressure': 1011.601,
#    'humidity': 90,
#    'temp_min': 74.21,
#    'temp_max': 74.21,
#    'sea_level': 1011.601,
#    'grnd_level': 989.301},
#   'wind': {'speed': 4.32, 'deg': 160.258},
#   'rain': {'3h': 0.25},
#   'clouds': {'all': 73},
#   'dt': 1555449889,
#   'sys': {'message': 0.0042,
#    'country': 'PG',
#    'sunrise': 1555444870,
#    'sunset': 1555487552},
#   'id': 2132606,
#   'name': 'Samarai',
#   'cod': 200},
#  {'coord': {'lon': -125.76, 'lat': 54.23},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 42.35,
#    'pressure': 1004.831,
#    'humidity': 58,
#    'temp_min': 42.35,
#    'temp_max': 42.35,
#    'sea_level': 1004.831,
#    'grnd_level': 887.109},
#   'wind': {'speed': 12.55, 'deg': 177.435},
#   'clouds': {'all': 100},
#   'dt': 1555449889,
#   'sys': {'message': 0.0131,
#    'country': 'CA',
#    'sunrise': 1555420746,
#    'sunset': 1555471568},
#   'id': 5911745,
#   'name': 'Burns Lake',
#   'cod': 200},
#  {'coord': {'lon': -74.98, 'lat': 39.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 64.71,
#    'pressure': 1017,
#    'humidity': 34,
#    'temp_min': 62.01,
#    'temp_max': 66.99},
#   'visibility': 16093,
#   'wind': {'speed': 11.41, 'deg': 250, 'gust': 10.3},
#   'clouds': {'all': 1},
#   'dt': 1555449822,
#   'sys': {'type': 1,
#    'id': 4902,
#    'message': 0.0076,
#    'country': 'US',
#    'sunrise': 1555410095,
#    'sunset': 1555457849},
#   'id': 4501427,
#   'name': 'Port Elizabeth',
#   'cod': 200},
#  {'coord': {'lon': 5.65, 'lat': 58.89},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 42.03,
#    'pressure': 1031,
#    'humidity': 56,
#    'temp_min': 39,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 100},
#   'clouds': {'all': 0},
#   'dt': 1555449620,
#   'sys': {'type': 1,
#    'id': 1680,
#    'message': 0.0059,
#    'country': 'NO',
#    'sunrise': 1555388528,
#    'sunset': 1555440720},
#   'id': 3137942,
#   'name': 'Sola',
#   'cod': 200},
#  {'coord': {'lon': -82.53, 'lat': 33.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 76.06,
#    'pressure': 1022,
#    'humidity': 29,
#    'temp_min': 73.4,
#    'temp_max': 78.01},
#   'visibility': 16093,
#   'wind': {'speed': 5.82, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1555449721,
#   'sys': {'type': 1,
#    'id': 2827,
#    'message': 0.0046,
#    'country': 'US',
#    'sunrise': 1555412333,
#    'sunset': 1555459234},
#   'id': 4231997,
#   'name': 'Avera',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 148.69, 'lat': -33.84},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 51.01,
#    'pressure': 1029,
#    'humidity': 88,
#    'temp_min': 51.01,
#    'temp_max': 51.01},
#   'wind': {'speed': 1.01, 'deg': 106, 'gust': 4.92},
#   'clouds': {'all': 0},
#   'dt': 1555448498,
#   'sys': {'type': 3,
#    'id': 2011235,
#    'message': 0.0052,
#    'country': 'AU',
#    'sunrise': 1555446509,
#    'sunset': 1555486863},
#   'id': 2170139,
#   'name': 'Cowra',
#   'cod': 200},
#  {'coord': {'lon': -68.52, 'lat': 63.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 8.28,
#    'pressure': 1018,
#    'humidity': 60,
#    'temp_min': 8.01,
#    'temp_max': 8.6},
#   'visibility': 48279,
#   'wind': {'speed': 16.11, 'deg': 320},
#   'clouds': {'all': 5},
#   'dt': 1555449764,
#   'sys': {'type': 1,
#    'id': 797,
#    'message': 0.0049,
#    'country': 'CA',
#    'sunrise': 1555405251,
#    'sunset': 1555459593},
#   'id': 5983720,
#   'name': 'Iqaluit',
#   'cod': 200},
#  {'coord': {'lon': -58.28, 'lat': -34},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 68.68,
#    'pressure': 1019,
#    'humidity': 56,
#    'temp_min': 66.99,
#    'temp_max': 71.6},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 50},
#   'clouds': {'all': 0},
#   'dt': 1555449355,
#   'sys': {'type': 1,
#    'id': 8232,
#    'message': 0.0046,
#    'country': 'UY',
#    'sunrise': 1555409772,
#    'sunset': 1555450157},
#   'id': 3443341,
#   'name': 'Carmelo',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 52.81,
#    'pressure': 1014,
#    'humidity': 24,
#    'temp_min': 46.99,
#    'temp_max': 57.99},
#   'visibility': 16093,
#   'wind': {'speed': 19.46, 'deg': 290, 'gust': 15.9},
#   'clouds': {'all': 75},
#   'dt': 1555449662,
#   'sys': {'type': 1,
#    'id': 3273,
#    'message': 0.0075,
#    'country': 'US',
#    'sunrise': 1555409532,
#    'sunset': 1555457822},
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -72.07, 'lat': -45.58},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 53.49,
#    'pressure': 1002,
#    'humidity': 87,
#    'temp_min': 51.8,
#    'temp_max': 55.4},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 200},
#   'clouds': {'all': 90},
#   'dt': 1555444800,
#   'sys': {'type': 1,
#    'id': 8491,
#    'message': 0.0056,
#    'country': 'CL',
#    'sunrise': 1555413892,
#    'sunset': 1555452655},
#   'id': 3894426,
#   'name': 'Coihaique',
#   'cod': 200},
#  {'coord': {'lon': 130.41, 'lat': 67.8},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': -0.32,
#    'pressure': 1013.221,
#    'humidity': 93,
#    'temp_min': -0.32,
#    'temp_max': -0.32,
#    'sea_level': 1013.221,
#    'grnd_level': 896.805},
#   'wind': {'speed': 5.61, 'deg': 356.37},
#   'clouds': {'all': 97},
#   'dt': 1555449890,
#   'sys': {'message': 0.0046,
#    'country': 'RU',
#    'sunrise': 1555442556,
#    'sunset': 1555499589},
#   'id': 2027042,
#   'name': 'Batagay-Alyta',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 6.26, 'lat': 4.92},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 78.53,
#    'pressure': 1010.563,
#    'humidity': 89,
#    'temp_min': 78.53,
#    'temp_max': 78.53,
#    'sea_level': 1010.563,
#    'grnd_level': 995.973},
#   'wind': {'speed': 4.83, 'deg': 204.948},
#   'clouds': {'all': 100},
#   'dt': 1555449891,
#   'sys': {'message': 0.0043,
#    'country': 'NG',
#    'sunrise': 1555392465,
#    'sunset': 1555436490},
#   'id': 2318123,
#   'name': 'Yenagoa',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 45.3,
#    'pressure': 1013,
#    'humidity': 64,
#    'temp_min': 44.01,
#    'temp_max': 46.99},
#   'wind': {'speed': 8.3, 'deg': 181.995},
#   'rain': {'3h': 0.062},
#   'clouds': {'all': 100},
#   'dt': 1555449669,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'message': 0.0068,
#    'country': 'AU',
#    'sunrise': 1555454502,
#    'sunset': 1555494870},
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': 150.85, 'lat': -34.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 56.66,
#    'pressure': 1025,
#    'humidity': 100,
#    'temp_min': 55.4,
#    'temp_max': 57.99},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1555449606,
#   'sys': {'type': 1,
#    'id': 9594,
#    'message': 0.0047,
#    'country': 'AU',
#    'sunrise': 1555446035,
#    'sunset': 1555486300},
#   'id': 6255012,
#   'name': 'Flinders',
#   'cod': 200},
#  {'coord': {'lon': 26.56, 'lat': 41.68},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 42.53,
#    'pressure': 1017.983,
#    'humidity': 76,
#    'temp_min': 42.53,
#    'temp_max': 42.53,
#    'sea_level': 1017.983,
#    'grnd_level': 988.789},
#   'wind': {'speed': 7.11, 'deg': 160.148},
#   'clouds': {'all': 2},
#   'dt': 1555449891,
#   'sys': {'message': 0.0049,
#    'country': 'TR',
#    'sunrise': 1555471871,
#    'sunset': 1555520114},
#   'id': 747712,
#   'name': 'Edirne',
#   'cod': 200},
#  {'coord': {'lon': 6.12, 'lat': 62.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 39.97,
#    'pressure': 1031,
#    'humidity': 70,
#    'temp_min': 37.99,
#    'temp_max': 42.8},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 80},
#   'clouds': {'all': 0},
#   'dt': 1555449604,
#   'sys': {'type': 1,
#    'id': 1602,
#    'message': 0.0053,
#    'country': 'NO',
#    'sunrise': 1555387664,
#    'sunset': 1555441359},
#   'id': 3141667,
#   'name': 'Roald',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 6.97, 'lat': 43.56},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 49.23,
#    'pressure': 1020,
#    'humidity': 87,
#    'temp_min': 43,
#    'temp_max': 55.4},
#   'visibility': 10000,
#   'wind': {'speed': 3.36},
#   'clouds': {'all': 0},
#   'dt': 1555449744,
#   'sys': {'type': 1,
#    'id': 6507,
#    'message': 0.0066,
#    'country': 'FR',
#    'sunrise': 1555390103,
#    'sunset': 1555438512},
#   'id': 3037456,
#   'name': 'Saint-Joseph',
#   'cod': 200},
#  {'coord': {'lon': 26.29, 'lat': 58.57},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 42.24,
#    'pressure': 1032,
#    'humidity': 91,
#    'temp_min': 39.99,
#    'temp_max': 44.01},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 40},
#   'clouds': {'all': 0},
#   'dt': 1555449616,
#   'sys': {'type': 1,
#    'id': 1335,
#    'message': 0.0058,
#    'country': 'EE',
#    'sunrise': 1555469875,
#    'sunset': 1555522240},
#   'id': 793956,
#   'name': 'Puurmani',
#   'cod': 200},
#  {'coord': {'lon': -56.15, 'lat': 72.79},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 7.97,
#    'pressure': 1013.575,
#    'humidity': 93,
#    'temp_min': 7.97,
#    'temp_max': 7.97,
#    'sea_level': 1013.575,
#    'grnd_level': 1013.189},
#   'wind': {'speed': 6.55, 'deg': 357.085},
#   'clouds': {'all': 99},
#   'dt': 1555449658,
#   'sys': {'message': 0.0037,
#    'country': 'GL',
#    'sunrise': 1555398595,
#    'sunset': 1555460312},
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  {'coord': {'lon': -54.06, 'lat': -24.56},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.51,
#    'pressure': 1010.799,
#    'humidity': 65,
#    'temp_min': 80.51,
#    'temp_max': 80.51,
#    'sea_level': 1010.799,
#    'grnd_level': 976.341},
#   'wind': {'speed': 2.62, 'deg': 182.411},
#   'clouds': {'all': 52},
#   'dt': 1555449621,
#   'sys': {'message': 0.005,
#    'country': 'BR',
#    'sunrise': 1555408247,
#    'sunset': 1555449657},
#   'id': 3457772,
#   'name': 'Marechal Candido Rondon',
#   'cod': 200},
#  {'coord': {'lon': 125.28, 'lat': 24.8},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 72.77,
#    'pressure': 1011.255,
#    'humidity': 82,
#    'temp_min': 72.77,
#    'temp_max': 72.77,
#    'sea_level': 1011.255,
#    'grnd_level': 1011.045},
#   'wind': {'speed': 22.12, 'deg': 344.46},
#   'clouds': {'all': 17},
#   'dt': 1555449892,
#   'sys': {'message': 0.0046,
#    'country': 'JP',
#    'sunrise': 1555449329,
#    'sunset': 1555495278},
#   'id': 1862505,
#   'name': 'Hirara',
#   'cod': 200},
#  {'coord': {'lon': -58.16, 'lat': 6.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 85.19,
#    'pressure': 1011,
#    'humidity': 74,
#    'temp_min': 84.2,
#    'temp_max': 86},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 50},
#   'clouds': {'all': 75},
#   'dt': 1555444800,
#   'sys': {'type': 1,
#    'id': 8776,
#    'message': 0.0053,
#    'country': 'GY',
#    'sunrise': 1555407841,
#    'sunset': 1555452031},
#   'id': 3378644,
#   'name': 'Georgetown',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 83.03,
#    'pressure': 1010.861,
#    'humidity': 82,
#    'temp_min': 83.03,
#    'temp_max': 83.03,
#    'sea_level': 1010.861,
#    'grnd_level': 1010.949},
#   'wind': {'speed': 18.68, 'deg': 51.976},
#   'rain': {'3h': 0.125},
#   'clouds': {'all': 100},
#   'dt': 1555449892,
#   'sys': {'message': 0.0046,
#    'country': 'KI',
#    'sunrise': 1555438967,
#    'sunset': 1555482839},
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': 17.94, 'lat': 62.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 32.25,
#    'pressure': 1036,
#    'humidity': 80,
#    'temp_min': 30.2,
#    'temp_max': 34},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1555449358,
#   'sys': {'type': 1,
#    'id': 1767,
#    'message': 0.0049,
#    'country': 'SE',
#    'sunrise': 1555384822,
#    'sunset': 1555438528},
#   'id': 2707684,
#   'name': 'Harnosand',
#   'cod': 200},
#  {'coord': {'lon': 178.02, 'lat': -38.66},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 55.99,
#    'pressure': 1034,
#    'humidity': 92,
#    'temp_min': 55.99,
#    'temp_max': 55.99},
#   'wind': {'speed': 11.01, 'deg': 240, 'gust': 8.49},
#   'rain': {'3h': 0.188},
#   'clouds': {'all': 97},
#   'dt': 1555449602,
#   'sys': {'type': 3,
#    'id': 2011018,
#    'message': 0.0083,
#    'country': 'NZ',
#    'sunrise': 1555439773,
#    'sunset': 1555479523},
# ...
#    'humidity': 57,
#    'temp_min': 54.41,
#    'temp_max': 54.41,
#    'sea_level': 1013.983,
#    'grnd_level': 1011.237},
#   'wind': {'speed': 19.06, 'deg': 59.881},
#   'clouds': {'all': 100},
#   'dt': 1555450012,
#   'sys': {'message': 0.0041,
#    'country': 'RU',
#    'sunrise': 1555466392,
#    'sunset': 1555515865},
#   'id': 520798,
#   'name': 'Nizhniy Baskunchak',
#   'cod': 200},
#  {'coord': {'lon': 37.92, 'lat': 59.13},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 30.11,
#    'pressure': 1036.495,
#    'humidity': 94,
#    'temp_min': 30.11,
#    'temp_max': 30.11,
#    'sea_level': 1036.495,
#    'grnd_level': 1014.229},
#   'wind': {'speed': 4.59, 'deg': 47.076},
#   'clouds': {'all': 0},
#   'dt': 1555449849,
#   'sys': {'message': 0.0049,
#    'country': 'RU',
#    'sunrise': 1555466985,
#    'sunset': 1555519548},
#   'id': 569223,
#   'name': 'Cherepovets',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 44.06, 'lat': 9.56},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 73.85,
#    'pressure': 1013.413,
#    'humidity': 64,
#    'temp_min': 73.85,
#    'temp_max': 73.85,
#    'sea_level': 1013.413,
#    'grnd_level': 868.085},
#   'wind': {'speed': 6.26, 'deg': 202.852},
#   'rain': {'3h': 3.25},
#   'clouds': {'all': 100},
#   'dt': 1555450013,
#   'sys': {'message': 0.0052,
#    'country': 'SO',
#    'sunrise': 1555469565,
#    'sunset': 1555514021},
#   'id': 57289,
#   'name': 'Hargeysa',
#   'cod': 200},
#  {'coord': {'lon': 67.98, 'lat': 28.06},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.31,
#    'pressure': 1009.285,
#    'humidity': 37,
#    'temp_min': 73.31,
#    'temp_max': 73.31,
#    'sea_level': 1009.285,
#    'grnd_level': 984.133},
#   'wind': {'speed': 2.26, 'deg': 270.908},
#   'clouds': {'all': 0},
#   'dt': 1555450013,
#   'sys': {'message': 0.0051,
#    'country': 'PK',
#    'sunrise': 1555462887,
#    'sunset': 1555509220},
#   'id': 1178858,
#   'name': 'Garhi Khairo',
#   'cod': 200},
#  {'coord': {'lon': 20.68, 'lat': 5.77},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 83.57,
#    'pressure': 1008.761,
#    'humidity': 51,
#    'temp_min': 83.57,
#    'temp_max': 83.57,
#    'sea_level': 1008.761,
#    'grnd_level': 952.949},
#   'wind': {'speed': 3.22, 'deg': 231.626},
#   'clouds': {'all': 56},
#   'dt': 1555450013,
#   'sys': {'message': 0.0043,
#    'country': 'CF',
#    'sunrise': 1555388969,
#    'sunset': 1555433066},
#   'id': 240604,
#   'name': 'Bambari',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.9},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.85,
#    'pressure': 1017,
#    'humidity': 52,
#    'temp_min': 59,
#    'temp_max': 66.2},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 30},
#   'clouds': {'all': 75},
#   'dt': 1555449974,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0068,
#    'country': 'AU',
#    'sunrise': 1555447450,
#    'sunset': 1555486575},
#   'id': 2206089,
#   'name': 'Sandy Bay',
#   'cod': 200},
#  {'coord': {'lon': -4.1, 'lat': 48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 50.13,
#    'pressure': 1018,
#    'humidity': 93,
#    'temp_min': 48,
#    'temp_max': 53.01},
#   'visibility': 6000,
#   'wind': {'speed': 7.74, 'deg': 140.309},
#   'clouds': {'all': 90},
#   'dt': 1555449492,
#   'sys': {'type': 1,
#    'id': 6568,
#    'message': 0.0053,
#    'country': 'FR',
#    'sunrise': 1555392337,
#    'sunset': 1555441591},
#   'id': 2984701,
#   'name': 'Quimper',
#   'cod': 200},
#  {'coord': {'lon': -101.3, 'lat': 48.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 62.04,
#    'pressure': 1011,
#    'humidity': 18,
#    'temp_min': 60.8,
#    'temp_max': 63},
#   'visibility': 16093,
#   'wind': {'speed': 3.89, 'deg': 69.617},
#   'clouds': {'all': 1},
#   'dt': 1555449958,
#   'sys': {'type': 1,
#    'id': 4955,
#    'message': 0.0062,
#    'country': 'US',
#    'sunrise': 1555415610,
#    'sunset': 1555464966},
#   'id': 5690532,
#   'name': 'Minot',
#   'cod': 200},
#  {'coord': {'lon': 14.7, 'lat': 57.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 39.67,
#    'pressure': 1032,
#    'humidity': 48,
#    'temp_min': 39.2,
#    'temp_max': 39.99},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 100},
#   'clouds': {'all': 0},
#   'dt': 1555449307,
#   'sys': {'type': 1,
#    'id': 1749,
#    'message': 0.0048,
#    'country': 'SE',
#    'sunrise': 1555386574,
#    'sunset': 1555438330},
#   'id': 2690170,
#   'name': 'Nassjo',
#   'cod': 200},
#  {'coord': {'lon': 115.51, 'lat': -2.54},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 75.83,
#    'pressure': 1009.953,
#    'humidity': 85,
#    'temp_min': 75.83,
#    'temp_max': 75.83,
#    'sea_level': 1009.953,
#    'grnd_level': 997.605},
#   'wind': {'speed': 2.64, 'deg': 109.983},
#   'clouds': {'all': 46},
#   'dt': 1555449727,
#   'sys': {'message': 0.0211,
#    'country': 'ID',
#    'sunrise': 1555452956,
#    'sunset': 1555496340},
#   'id': 1641899,
#   'name': 'Labuhan',
#   'cod': 200},
#  {'coord': {'lon': 57.09, 'lat': 65.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 2.03,
#    'pressure': 1033.857,
#    'humidity': 94,
#    'temp_min': 2.03,
#    'temp_max': 2.03,
#    'sea_level': 1033.857,
#    'grnd_level': 1025.813},
#   'wind': {'speed': 5.03, 'deg': 342.2},
#   'clouds': {'all': 1},
#   'dt': 1555450014,
#   'sys': {'message': 0.0056,
#    'country': 'RU',
#    'sunrise': 1555460975,
#    'sunset': 1555516358},
#   'id': 503772,
#   'name': 'Puteyets',
#   'cod': 200},
#  {'coord': {'lon': 139.9, 'lat': 69.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 1.49,
#    'pressure': 1014.677,
#    'humidity': 82,
#    'temp_min': 1.49,
#    'temp_max': 1.49,
#    'sea_level': 1014.677,
#    'grnd_level': 946.053},
#   'wind': {'speed': 3.15, 'deg': 100.822},
#   'clouds': {'all': 1},
#   'dt': 1555450014,
#   'sys': {'message': 0.005,
#    'country': 'RU',
#    'sunrise': 1555439680,
#    'sunset': 1555497910},
#   'id': 2028164,
#   'name': 'Deputatskiy',
#   'cod': 200},
#  {'coord': {'lon': -66.88, 'lat': 50.03},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 39.63,
#    'pressure': 1002,
#    'humidity': 51,
#    'temp_min': 39.2,
#    'temp_max': 39.99},
#   'visibility': 48279,
#   'wind': {'speed': 20.8, 'deg': 350, 'gust': 15.4},
#   'clouds': {'all': 90},
#   'dt': 1555449817,
#   'sys': {'type': 1,
#    'id': 1013,
#    'message': 0.0043,
#    'country': 'CA',
#    'sunrise': 1555407164,
#    'sunset': 1555456893},
#   'id': 6111696,
#   'name': 'Port-Cartier',
#   'cod': 200},
#  {'coord': {'lon': -149.33, 'lat': -17.53},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 88.43,
#    'pressure': 1014,
#    'humidity': 62,
#    'temp_min': 87.8,
#    'temp_max': 89.01},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 240},
#   'clouds': {'all': 20},
#   'dt': 1555449188,
#   'sys': {'type': 1,
#    'id': 7318,
#    'message': 0.0046,
#    'country': 'PF',
#    'sunrise': 1555430780,
#    'sunset': 1555472846},
#   'id': 4033356,
#   'name': 'Tiarei',
#   'cod': 200},
#  {'coord': {'lon': -124.16, 'lat': 40.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 56.35,
#    'pressure': 1021,
#    'humidity': 76,
#    'temp_min': 51.8,
#    'temp_max': 59},
#   'visibility': 16093,
#   'wind': {'speed': 9.17, 'deg': 310},
#   'clouds': {'all': 75},
#   'dt': 1555449906,
#   'sys': {'type': 1,
#    'id': 3217,
#    'message': 0.0051,
#    'country': 'US',
#    'sunrise': 1555421770,
#    'sunset': 1555469777},
#   'id': 5563397,
#   'name': 'Eureka',
#   'cod': 200},
#  {'coord': {'lon': 108.9, 'lat': 0.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 85.37,
#    'pressure': 1009.581,
#    'humidity': 70,
#    'temp_min': 85.37,
#    'temp_max': 85.37,
#    'sea_level': 1009.581,
#    'grnd_level': 1009.477},
#   'wind': {'speed': 4.92, 'deg': 339.005},
#   'clouds': {'all': 100},
#   'dt': 1555450014,
#   'sys': {'message': 0.0043,
#    'country': 'ID',
#    'sunrise': 1555454401,
#    'sunset': 1555498067},
#   'id': 1625908,
#   'name': 'Sungairaya',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 126.98, 'lat': 37.57},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 42.51,
#    'pressure': 1014,
#    'humidity': 70,
#    'temp_min': 37.4,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 2.24, 'deg': 10},
#   'clouds': {'all': 75},
#   'dt': 1555447800,
#   'sys': {'type': 1,
#    'id': 5509,
#    'message': 0.0067,
#    'country': 'KR',
#    'sunrise': 1555448118,
#    'sunset': 1555495673},
#   'id': 1835848,
#   'name': 'Seoul',
#   'cod': 200},
#  {'coord': {'lon': 89.73, 'lat': 27.91},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 28.13,
#    'pressure': 1018.363,
#    'humidity': 90,
#    'temp_min': 28.13,
#    'temp_max': 28.13,
#    'sea_level': 1018.363,
#    'grnd_level': 580.901},
#   'wind': {'speed': 2.66, 'deg': 160.819},
#   'clouds': {'all': 98},
#   'dt': 1555450015,
#   'sys': {'message': 0.0041,
#    'country': 'BT',
#    'sunrise': 1555457679,
#    'sunset': 1555503989},
#   'id': 1252578,
#   'name': 'Gasa',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 57.53, 'lat': 22.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.31,
#    'pressure': 1011.543,
#    'humidity': 32,
#    'temp_min': 73.31,
#    'temp_max': 73.31,
#    'sea_level': 1011.543,
#    'grnd_level': 908.117},
#   'wind': {'speed': 8.03, 'deg': 149.739},
#   'clouds': {'all': 0},
#   'dt': 1555450015,
#   'sys': {'message': 0.0049,
#    'country': 'OM',
#    'sunrise': 1555465680,
#    'sunset': 1555511442},
#   'id': 286987,
#   'name': 'Nizwa',
#   'cod': 200},
#  {'coord': {'lon': -90.64, 'lat': 16.52},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 90.23,
#    'pressure': 1012.809,
#    'humidity': 46,
#    'temp_min': 90.23,
#    'temp_max': 90.23,
#    'sea_level': 1012.809,
#    'grnd_level': 973.109},
#   'wind': {'speed': 5.86, 'deg': 90.743},
#   'clouds': {'all': 100},
#   'dt': 1555450015,
#   'sys': {'message': 0.0039,
#    'country': 'MX',
#    'sunrise': 1555415191,
#    'sunset': 1555460269},
#   'id': 3816362,
#   'name': 'Benemerito de las Americas',
#   'cod': 200},
#  {'coord': {'lon': 131.09, 'lat': 47.69},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 38.21,
#    'pressure': 1006.285,
#    'humidity': 40,
#    'temp_min': 38.21,
#    'temp_max': 38.21,
#    'sea_level': 1006.285,
#    'grnd_level': 980.773},
#   'wind': {'speed': 3.8, 'deg': 359.02},
#   'clouds': {'all': 58},
#   'dt': 1555450015,
#   'sys': {'message': 0.0053,
#    'country': 'CN',
#    'sunrise': 1555446252,
#    'sunset': 1555495567},
#   'id': 2027740,
#   'name': 'Amurzet',
#   'cod': 200},
#  {'coord': {'lon': -15.83, 'lat': 11.28},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 79.07,
#    'pressure': 1009.573,
#    'humidity': 69,
#    'temp_min': 79.07,
#    'temp_max': 79.07,
#    'sea_level': 1009.573,
#    'grnd_level': 1009.269},
#   'wind': {'speed': 22.64, 'deg': 290.815},
#   'clouds': {'all': 0},
#   'dt': 1555450015,
#   'sys': {'message': 0.0043,
#    'country': 'GW',
#    'sunrise': 1555397486,
#    'sunset': 1555442071},
#   'id': 2374583,
#   'name': 'Bubaque',
#   'cod': 200},
#  {'coord': {'lon': -77.4, 'lat': 18.46},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.2,
#    'pressure': 1013,
#    'humidity': 74,
#    'temp_min': 84.2,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 80},
#   'clouds': {'all': 20},
#   'dt': 1555448400,
#   'sys': {'type': 1,
#    'id': 7107,
#    'message': 0.0044,
#    'country': 'JM',
#    'sunrise': 1555411921,
#    'sunset': 1555457185},
#   'id': 3490716,
#   'name': 'Discovery Bay',
#   'cod': 200},
#  {'coord': {'lon': -69.94, 'lat': 18.48},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.33,
#    'pressure': 1015,
#    'humidity': 62,
#    'temp_min': 82.99,
#    'temp_max': 86},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 180},
#   'clouds': {'all': 20},
#   'dt': 1555449210,
#   'sys': {'type': 1,
#    'id': 7052,
#    'message': 0.0042,
#    'country': 'DO',
#    'sunrise': 1555410130,
#    'sunset': 1555455395},
#   'id': 3492908,
#   'name': 'Santo Domingo',
#   'cod': 200},
#  {'coord': {'lon': -110.68, 'lat': 50.04},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 57.02,
#    'pressure': 1009,
#    'humidity': 24,
#    'temp_min': 55,
#    'temp_max': 57.99},
#   'visibility': 48279,
#   'wind': {'speed': 3.36},
#   'clouds': {'all': 90},
#   'dt': 1555449951,
#   'sys': {'type': 1,
#    'id': 978,
#    'message': 0.0051,
#    'country': 'CA',
#    'sunrise': 1555417660,
#    'sunset': 1555467418},
#   'id': 6071618,
#   'name': 'Medicine Hat',
#   'cod': 200},
#  {'coord': {'lon': 11.87, 'lat': -4.77},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 82.85,
#    'pressure': 1011.031,
#    'humidity': 81,
#    'temp_min': 82.85,
#    'temp_max': 82.85,
#    'sea_level': 1011.031,
#    'grnd_level': 1011.013},
#   'wind': {'speed': 4.41, 'deg': 245.27},
#   'clouds': {'all': 100},
#   'dt': 1555449915,
#   'sys': {'message': 0.0063,
#    'country': 'CG',
#    'sunrise': 1555391531,
#    'sunset': 1555434732},
#   'id': 2258378,
#   'name': 'Loandjili',
#   'cod': 200},
#  {'coord': {'lon': 150.15, 'lat': -5.56},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 76.91,
#    'pressure': 1010.373,
#    'humidity': 88,
#    'temp_min': 76.91,
#    'temp_max': 76.91,
#    'sea_level': 1010.373,
#    'grnd_level': 990.981},
#   'wind': {'speed': 2.33, 'deg': 148.065},
#   'clouds': {'all': 76},
#   'dt': 1555450017,
#   'sys': {'message': 0.0043,
#    'country': 'PG',
#    'sunrise': 1555444774,
#    'sunset': 1555487898},
#   'id': 2093967,
#   'name': 'Kimbe',
#   'cod': 200},
#  {'coord': {'lon': 109.41, 'lat': 24.32},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 63.59,
#    'pressure': 1011.953,
#    'humidity': 69,
#    'temp_min': 63.59,
#    'temp_max': 63.59,
#    'sea_level': 1011.953,
#    'grnd_level': 980.229},
#   'wind': {'speed': 1.61, 'deg': 290.94},
#   'clouds': {'all': 0},
#   'dt': 1555450017,
#   'sys': {'message': 0.0044,
#    'country': 'CN',
#    'sunrise': 1555453161,
#    'sunset': 1555499062},
#   'id': 1803300,
#   'name': 'Liuzhou',
#   'cod': 200}]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(len(city_list))
print(len(cloudiness))
print(len(country))
print(len(date))
print(len(humidity))
print(len(lat))
print(len(lng))
print(len(max_temp))
print(len(wind_speed))
# Out:
# 793
# 793
# 793
# 793
# 793
# 793
# 793
# 793
# 793

# %%
weather_dict = {
    "City": city_list,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Castro          90      CL  1555444800       100 -42.48  -73.76
# 1     Abu Samrah           6      SY  1555449881        82  35.30   37.18
# 2        Mataura           0      NZ  1555449605        97 -46.19  168.86
# 3  Mar del Plata          74      AR  1555449881        41 -46.43  -67.52
# 4         Muroto         100      JP  1555449881        69  33.37  134.14
#
#    Max Temp  Wind Speed
# 0     53.60       21.92
# 1     51.89       10.92
# 2     41.00        1.01
# 3     64.49       19.53
# 4     52.79        5.01

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (04/15/2018)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Lat_vs_temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (04/15/2018)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Images/lat_vs_humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (04/15/2018)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Images/lat_vs_cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (04/15/2018)")
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Images/lat_vs_wind.png")

# Show plot
plt.show()
