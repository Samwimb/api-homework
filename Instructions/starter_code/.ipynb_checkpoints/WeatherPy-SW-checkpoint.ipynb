# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
import os

now = dt.datetime.today()
strformat = now.strftime("%Y-%m-%d")

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
#lat_range = (-90, 90)
#lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-----------------------------")

weather_response_json = []

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
city_list = []
counter = 1

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&q="


# div = 50
# lim = len(cities) // div
# samples = [cities[(i * div):(i * div + div)] for i in range(0, lim)]
#print(samples.index('citygroup'))
#for citygroup in samples:
#    print((samples.index(citygroup)))
#for city in range(len(cities))
# for citygroup in samples:


sets = 1
for index, city in enumerate(cities):

    #print(f"Processing Record {counter} in {samples.index(citygroup)} | {city}")
    
    print(f"Processing Record {index+1} in  set {sets} | {city}")
    query_url = f"{url}appid={api_key}&units={units}&q={city}"
    response = requests.get(query_url)
    weather_response = response.json()
    weather_response_json.append(weather_response)
    #counter = counter + 1
    if ((index+1) % 50) == 0:
        #time.sleep(3)
        sets = sets + 1
        #counter = 1

    try:
        city_list.append(weather_response['name'])
        cloudiness.append(weather_response['clouds']['all'])
        country.append(weather_response['sys']['country'])
        date.append(weather_response['dt'])
        humidity.append(weather_response['main']['humidity'])
        lat.append(weather_response['coord']['lat'])
        lng.append(weather_response['coord']['lon'])
        max_temp.append(weather_response['main']['temp_max'])
        wind_speed.append(weather_response['wind']['speed'])
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 in  set 1 | hervey bay
# Processing Record 2 in  set 1 | sur
# Processing Record 3 in  set 1 | arman
# Processing Record 4 in  set 1 | puno
# Processing Record 5 in  set 1 | pevek
# Processing Record 6 in  set 1 | albany
# Processing Record 7 in  set 1 | mindelo
# Processing Record 8 in  set 1 | severodvinsk
# Processing Record 9 in  set 1 | sorvag
# Missing field/result... skipping.
# Processing Record 10 in  set 1 | tambacounda
# Processing Record 11 in  set 1 | rikitea
# Processing Record 12 in  set 1 | lavrentiya
# Processing Record 13 in  set 1 | tsihombe
# Missing field/result... skipping.
# Processing Record 14 in  set 1 | eureka
# Processing Record 15 in  set 1 | puerto madryn
# Processing Record 16 in  set 1 | llanes
# Processing Record 17 in  set 1 | mar del plata
# Processing Record 18 in  set 1 | smithers
# Processing Record 19 in  set 1 | geraldton
# Processing Record 20 in  set 1 | hobart
# Processing Record 21 in  set 1 | yorosso
# Processing Record 22 in  set 1 | butaritari
# Processing Record 23 in  set 1 | torbay
# Processing Record 24 in  set 1 | cayenne
# Processing Record 25 in  set 1 | ketchenery
# Missing field/result... skipping.
# Processing Record 26 in  set 1 | ushuaia
# Processing Record 27 in  set 1 | nome
# Processing Record 28 in  set 1 | bredasdorp
# Processing Record 29 in  set 1 | formoso do araguaia
# Missing field/result... skipping.
# Processing Record 30 in  set 1 | illoqqortoormiut
# Missing field/result... skipping.
# Processing Record 31 in  set 1 | belushya guba
# Missing field/result... skipping.
# Processing Record 32 in  set 1 | leshukonskoye
# Processing Record 33 in  set 1 | kargasok
# Processing Record 34 in  set 1 | margate
# Processing Record 35 in  set 1 | busselton
# Processing Record 36 in  set 1 | upernavik
# Processing Record 37 in  set 1 | fez
# Processing Record 38 in  set 1 | cape town
# Processing Record 39 in  set 1 | hermanus
# Processing Record 40 in  set 1 | lebu
# Processing Record 41 in  set 1 | lompoc
# Processing Record 42 in  set 1 | kangaatsiaq
# Processing Record 43 in  set 1 | airai
# Processing Record 44 in  set 1 | port elizabeth
# Processing Record 45 in  set 1 | sorland
# Processing Record 46 in  set 1 | salinopolis
# Processing Record 47 in  set 1 | nikolskoye
# Processing Record 48 in  set 1 | saleaula
# Missing field/result... skipping.
# Processing Record 49 in  set 1 | lolua
# Missing field/result... skipping.
# Processing Record 50 in  set 1 | arraial do cabo
# Processing Record 51 in  set 2 | avarua
# Processing Record 52 in  set 2 | vila velha
# Processing Record 53 in  set 2 | hilo
# Processing Record 54 in  set 2 | cidreira
# Processing Record 55 in  set 2 | paracuru
# Processing Record 56 in  set 2 | carnarvon
# Processing Record 57 in  set 2 | olafsvik
# Missing field/result... skipping.
# Processing Record 58 in  set 2 | vaini
# Processing Record 59 in  set 2 | saint-augustin
# Processing Record 60 in  set 2 | chokurdakh
# Processing Record 61 in  set 2 | taolanaro
# Missing field/result... skipping.
# Processing Record 62 in  set 2 | poum
# Processing Record 63 in  set 2 | padang
# Processing Record 64 in  set 2 | pochutla
# Processing Record 65 in  set 2 | castro
# Processing Record 66 in  set 2 | kayes
# Processing Record 67 in  set 2 | luderitz
# Processing Record 68 in  set 2 | aflu
# Missing field/result... skipping.
# Processing Record 69 in  set 2 | ponta do sol
# Processing Record 70 in  set 2 | qaanaaq
# Processing Record 71 in  set 2 | ostrovnoy
# Processing Record 72 in  set 2 | stephenville
# Processing Record 73 in  set 2 | fort nelson
# Processing Record 74 in  set 2 | lasa
# Processing Record 75 in  set 2 | kegayli
# Missing field/result... skipping.
# Processing Record 76 in  set 2 | plunge
# Processing Record 77 in  set 2 | kendari
# Processing Record 78 in  set 2 | puerto ayora
# Processing Record 79 in  set 2 | vardo
# Processing Record 80 in  set 2 | ancud
# Processing Record 81 in  set 2 | balabac
# Processing Record 82 in  set 2 | peleduy
# Processing Record 83 in  set 2 | kununurra
# Processing Record 84 in  set 2 | bethel
# Processing Record 85 in  set 2 | rajauri
# Missing field/result... skipping.
# Processing Record 86 in  set 2 | ambulu
# Processing Record 87 in  set 2 | saint-philippe
# Processing Record 88 in  set 2 | punta arenas
# Processing Record 89 in  set 2 | chumikan
# Processing Record 90 in  set 2 | bluff
# Processing Record 91 in  set 2 | bethanien
# Processing Record 92 in  set 2 | atuona
# Processing Record 93 in  set 2 | yellowknife
# Processing Record 94 in  set 2 | camacha
# Processing Record 95 in  set 2 | bulembu
# Processing Record 96 in  set 2 | cockburn town
# Processing Record 97 in  set 2 | almaznyy
# Processing Record 98 in  set 2 | honningsvag
# Processing Record 99 in  set 2 | kutum
# Processing Record 100 in  set 2 | coquimbo
# Processing Record 101 in  set 3 | rovaniemi
# Processing Record 102 in  set 3 | vila franca do campo
# Processing Record 103 in  set 3 | saint-michel-des-saints
# Processing Record 104 in  set 3 | manggar
# Processing Record 105 in  set 3 | east london
# Processing Record 106 in  set 3 | crateus
# Processing Record 107 in  set 3 | port alfred
# Processing Record 108 in  set 3 | asfi
# Missing field/result... skipping.
# Processing Record 109 in  set 3 | havoysund
# Processing Record 110 in  set 3 | guerrero negro
# Processing Record 111 in  set 3 | ranong
# Processing Record 112 in  set 3 | belleville
# Processing Record 113 in  set 3 | georgetown
# Processing Record 114 in  set 3 | wattegama
# Processing Record 115 in  set 3 | ahipara
# Processing Record 116 in  set 3 | cefalu
# Processing Record 117 in  set 3 | khatanga
# Processing Record 118 in  set 3 | padre paraiso
# Processing Record 119 in  set 3 | guantanamo
# Processing Record 120 in  set 3 | bandarbeyla
# Processing Record 121 in  set 3 | anadyr
# Processing Record 122 in  set 3 | mishelevka
# Processing Record 123 in  set 3 | tual
# Processing Record 124 in  set 3 | new norfolk
# Processing Record 125 in  set 3 | itaituba
# Processing Record 126 in  set 3 | zeya
# Processing Record 127 in  set 3 | kodiak
# Processing Record 128 in  set 3 | kaitangata
# Processing Record 129 in  set 3 | samusu
# Missing field/result... skipping.
# Processing Record 130 in  set 3 | jamestown
# Processing Record 131 in  set 3 | cabo san lucas
# Processing Record 132 in  set 3 | mecca
# Processing Record 133 in  set 3 | oranjemund
# Processing Record 134 in  set 3 | port-gentil
# Processing Record 135 in  set 3 | tiksi
# Processing Record 136 in  set 3 | kavieng
# Processing Record 137 in  set 3 | pundaguitan
# Processing Record 138 in  set 3 | mataura
# Processing Record 139 in  set 3 | kapit
# Processing Record 140 in  set 3 | kavaratti
# Processing Record 141 in  set 3 | general roca
# Processing Record 142 in  set 3 | flin flon
# Processing Record 143 in  set 3 | belaya gora
# Processing Record 144 in  set 3 | hasaki
# Processing Record 145 in  set 3 | san cristobal
# Processing Record 146 in  set 3 | tevaitoa
# Processing Record 147 in  set 3 | mattru
# Processing Record 148 in  set 3 | port blair
# Processing Record 149 in  set 3 | strezhevoy
# Processing Record 150 in  set 3 | te anau
# Processing Record 151 in  set 4 | grand gaube
# Processing Record 152 in  set 4 | san patricio
# Processing Record 153 in  set 4 | tuktoyaktuk
# Processing Record 154 in  set 4 | sarangani
# Processing Record 155 in  set 4 | esna
# Processing Record 156 in  set 4 | attawapiskat
# Missing field/result... skipping.
# Processing Record 157 in  set 4 | nabire
# Processing Record 158 in  set 4 | mont-de-marsan
# Processing Record 159 in  set 4 | faanui
# Processing Record 160 in  set 4 | sitka
# Processing Record 161 in  set 4 | brae
# Processing Record 162 in  set 4 | binga
# Processing Record 163 in  set 4 | el vigia
# Processing Record 164 in  set 4 | vao
# Processing Record 165 in  set 4 | bengkulu
# Missing field/result... skipping.
# Processing Record 166 in  set 4 | dunedin
# Processing Record 167 in  set 4 | rocha
# Processing Record 168 in  set 4 | north myrtle beach
# Processing Record 169 in  set 4 | ornskoldsvik
# Processing Record 170 in  set 4 | sabratah
# Processing Record 171 in  set 4 | wajima
# Processing Record 172 in  set 4 | jussara
# Processing Record 173 in  set 4 | nanortalik
# Processing Record 174 in  set 4 | srednekolymsk
# Processing Record 175 in  set 4 | dukat
# Processing Record 176 in  set 4 | kedrovyy
# Processing Record 177 in  set 4 | masuguru
# Processing Record 178 in  set 4 | marzuq
# Processing Record 179 in  set 4 | qui nhon
# Missing field/result... skipping.
# Processing Record 180 in  set 4 | marcona
# Missing field/result... skipping.
# Processing Record 181 in  set 4 | frederikshavn
# Processing Record 182 in  set 4 | los llanos de aridane
# Processing Record 183 in  set 4 | estreito
# Processing Record 184 in  set 4 | azul
# Processing Record 185 in  set 4 | grand river south east
# Missing field/result... skipping.
# Processing Record 186 in  set 4 | souillac
# Processing Record 187 in  set 4 | makakilo city
# Processing Record 188 in  set 4 | san alberto
# Processing Record 189 in  set 4 | tofield
# Processing Record 190 in  set 4 | freeport
# Processing Record 191 in  set 4 | oktyabrskiy
# Processing Record 192 in  set 4 | klaksvik
# Processing Record 193 in  set 4 | cabedelo
# Processing Record 194 in  set 4 | tura
# Processing Record 195 in  set 4 | barrow
# Processing Record 196 in  set 4 | iqaluit
# Processing Record 197 in  set 4 | chuy
# Processing Record 198 in  set 4 | veraval
# Processing Record 199 in  set 4 | benavente
# Processing Record 200 in  set 4 | ilulissat
# Processing Record 201 in  set 5 | mount gambier
# Processing Record 202 in  set 5 | cesky krumlov
# Processing Record 203 in  set 5 | christchurch
# Processing Record 204 in  set 5 | nacozari
# Processing Record 205 in  set 5 | sisimiut
# Processing Record 206 in  set 5 | dharchula
# Processing Record 207 in  set 5 | tiznit
# Processing Record 208 in  set 5 | victoria
# Processing Record 209 in  set 5 | saint-pierre
# Processing Record 210 in  set 5 | berlevag
# Processing Record 211 in  set 5 | beloha
# Processing Record 212 in  set 5 | prince rupert
# Processing Record 213 in  set 5 | anaconda
# Processing Record 214 in  set 5 | port shepstone
# Processing Record 215 in  set 5 | neepawa
# Processing Record 216 in  set 5 | clyde river
# Processing Record 217 in  set 5 | belmonte
# Processing Record 218 in  set 5 | hamilton
# Processing Record 219 in  set 5 | larsnes
# Processing Record 220 in  set 5 | port hardy
# Processing Record 221 in  set 5 | thompson
# Processing Record 222 in  set 5 | rio grande city
# Processing Record 223 in  set 5 | high level
# Processing Record 224 in  set 5 | saskylakh
# Processing Record 225 in  set 5 | esperance
# Processing Record 226 in  set 5 | kostomuksha
# Processing Record 227 in  set 5 | pontianak
# Processing Record 228 in  set 5 | ribeira grande
# Processing Record 229 in  set 5 | port moresby
# Processing Record 230 in  set 5 | dubbo
# Processing Record 231 in  set 5 | mokhsogollokh
# Processing Record 232 in  set 5 | manaure
# Processing Record 233 in  set 5 | meulaboh
# Processing Record 234 in  set 5 | labuan
# Processing Record 235 in  set 5 | acarau
# Missing field/result... skipping.
# Processing Record 236 in  set 5 | talnakh
# Processing Record 237 in  set 5 | dingle
# Processing Record 238 in  set 5 | homer
# Processing Record 239 in  set 5 | kaeo
# Processing Record 240 in  set 5 | bermeo
# Processing Record 241 in  set 5 | kapaa
# Processing Record 242 in  set 5 | dankov
# Processing Record 243 in  set 5 | araouane
# Processing Record 244 in  set 5 | springfield
# Processing Record 245 in  set 5 | sant pere de ribes
# Processing Record 246 in  set 5 | salalah
# Processing Record 247 in  set 5 | norman wells
# Processing Record 248 in  set 5 | grindavik
# Processing Record 249 in  set 5 | pitkyaranta
# Processing Record 250 in  set 5 | beringovskiy
# Processing Record 251 in  set 6 | tuatapere
# Processing Record 252 in  set 6 | saldanha
# Processing Record 253 in  set 6 | tasiilaq
# Processing Record 254 in  set 6 | guilin
# Processing Record 255 in  set 6 | bonthe
# Processing Record 256 in  set 6 | hithadhoo
# Processing Record 257 in  set 6 | leningradskiy
# Processing Record 258 in  set 6 | lorengau
# Processing Record 259 in  set 6 | broken hill
# Processing Record 260 in  set 6 | lethem
# Processing Record 261 in  set 6 | usinsk
# Processing Record 262 in  set 6 | turukhansk
# Processing Record 263 in  set 6 | watertown
# Processing Record 264 in  set 6 | semnan
# Processing Record 265 in  set 6 | nizhneyansk
# Missing field/result... skipping.
# Processing Record 266 in  set 6 | hendek
# Processing Record 267 in  set 6 | severo-kurilsk
# Processing Record 268 in  set 6 | mahebourg
# Processing Record 269 in  set 6 | port hueneme
# Processing Record 270 in  set 6 | hay river
# Processing Record 271 in  set 6 | careiro da varzea
# Processing Record 272 in  set 6 | bambous virieux
# Processing Record 273 in  set 6 | novotalitsy
# Missing field/result... skipping.
# Processing Record 274 in  set 6 | flinders
# Processing Record 275 in  set 6 | aklavik
# Processing Record 276 in  set 6 | vinh
# Processing Record 277 in  set 6 | asyut
# Processing Record 278 in  set 6 | provideniya
# Processing Record 279 in  set 6 | moranbah
# Processing Record 280 in  set 6 | churapcha
# Processing Record 281 in  set 6 | itarema
# Processing Record 282 in  set 6 | carballo
# Processing Record 283 in  set 6 | dikson
# Processing Record 284 in  set 6 | toowoomba
# Processing Record 285 in  set 6 | torrington
# Processing Record 286 in  set 6 | sabha
# Processing Record 287 in  set 6 | effingham
# Processing Record 288 in  set 6 | ondorhaan
# Missing field/result... skipping.
# Processing Record 289 in  set 6 | cobh
# Processing Record 290 in  set 6 | eenhana
# Processing Record 291 in  set 6 | malwan
# Missing field/result... skipping.
# Processing Record 292 in  set 6 | jiroft
# Missing field/result... skipping.
# Processing Record 293 in  set 6 | kettering
# Processing Record 294 in  set 6 | bogatyye saby
# Processing Record 295 in  set 6 | yulara
# Processing Record 296 in  set 6 | soma
# Processing Record 297 in  set 6 | ponta delgada
# Processing Record 298 in  set 6 | beyneu
# Processing Record 299 in  set 6 | longlac
# Missing field/result... skipping.
# Processing Record 300 in  set 6 | bathsheba
# Processing Record 301 in  set 7 | cherskiy
# Processing Record 302 in  set 7 | namibe
# Processing Record 303 in  set 7 | rungata
# Missing field/result... skipping.
# Processing Record 304 in  set 7 | levice
# Processing Record 305 in  set 7 | liminangcong
# Missing field/result... skipping.
# Processing Record 306 in  set 7 | la ronge
# Processing Record 307 in  set 7 | kud
# Processing Record 308 in  set 7 | mount vernon
# Processing Record 309 in  set 7 | fortuna
# Processing Record 310 in  set 7 | maputo
# Processing Record 311 in  set 7 | raga
# Missing field/result... skipping.
# Processing Record 312 in  set 7 | tautira
# Processing Record 313 in  set 7 | raudeberg
# Processing Record 314 in  set 7 | ileza
# Processing Record 315 in  set 7 | kahului
# Processing Record 316 in  set 7 | heerenveen
# Processing Record 317 in  set 7 | kolokani
# Processing Record 318 in  set 7 | lac du bonnet
# Processing Record 319 in  set 7 | yanan
# Missing field/result... skipping.
# Processing Record 320 in  set 7 | rockhampton
# Processing Record 321 in  set 7 | labutta
# Missing field/result... skipping.
# Processing Record 322 in  set 7 | pachino
# Processing Record 323 in  set 7 | pareora
# Processing Record 324 in  set 7 | celestun
# Processing Record 325 in  set 7 | tatawin
# Missing field/result... skipping.
# Processing Record 326 in  set 7 | khawhai
# Processing Record 327 in  set 7 | saint-leu
# Processing Record 328 in  set 7 | douglas
# Processing Record 329 in  set 7 | piacabucu
# Processing Record 330 in  set 7 | basco
# Processing Record 331 in  set 7 | haibowan
# Missing field/result... skipping.
# Processing Record 332 in  set 7 | coihaique
# Processing Record 333 in  set 7 | solnechnyy
# Processing Record 334 in  set 7 | severo-yeniseyskiy
# Processing Record 335 in  set 7 | barcelos
# Processing Record 336 in  set 7 | kieta
# Processing Record 337 in  set 7 | guadalupe y calvo
# Processing Record 338 in  set 7 | caravelas
# Processing Record 339 in  set 7 | bolshoy tsaryn
# Missing field/result... skipping.
# Processing Record 340 in  set 7 | longyearbyen
# Processing Record 341 in  set 7 | vostok
# Processing Record 342 in  set 7 | shubarshi
# Processing Record 343 in  set 7 | chokwe
# Missing field/result... skipping.
# Processing Record 344 in  set 7 | marawi
# Processing Record 345 in  set 7 | rock springs
# Processing Record 346 in  set 7 | oistins
# Processing Record 347 in  set 7 | mys shmidta
# Missing field/result... skipping.
# Processing Record 348 in  set 7 | wajir
# Processing Record 349 in  set 7 | nuuk
# Processing Record 350 in  set 7 | karamea
# Missing field/result... skipping.
# Processing Record 351 in  set 8 | comodoro rivadavia
# Processing Record 352 in  set 8 | juneau
# Processing Record 353 in  set 8 | jijiga
# Processing Record 354 in  set 8 | naze
# Processing Record 355 in  set 8 | pangody
# Processing Record 356 in  set 8 | kerteh
# Missing field/result... skipping.
# Processing Record 357 in  set 8 | tilichiki
# Processing Record 358 in  set 8 | urdzhar
# Missing field/result... skipping.
# Processing Record 359 in  set 8 | katsuura
# Processing Record 360 in  set 8 | plettenberg bay
# Processing Record 361 in  set 8 | hammonton
# Processing Record 362 in  set 8 | napier
# Processing Record 363 in  set 8 | yarim
# Processing Record 364 in  set 8 | copiapo
# Processing Record 365 in  set 8 | praia
# Processing Record 366 in  set 8 | tecoanapa
# Processing Record 367 in  set 8 | kalnibolotskaya
# Processing Record 368 in  set 8 | dasoguz
# Processing Record 369 in  set 8 | bougouni
# Processing Record 370 in  set 8 | bemidji
# Processing Record 371 in  set 8 | sao joao da barra
# Processing Record 372 in  set 8 | touros
# Processing Record 373 in  set 8 | marsa matruh
# Processing Record 374 in  set 8 | panama city
# Processing Record 375 in  set 8 | contai
# Processing Record 376 in  set 8 | dauphin
# Processing Record 377 in  set 8 | miquelon
# Processing Record 378 in  set 8 | cankuzo
# Processing Record 379 in  set 8 | kunya
# Processing Record 380 in  set 8 | jianhu
# Processing Record 381 in  set 8 | oksovskiy
# Processing Record 382 in  set 8 | bure
# Processing Record 383 in  set 8 | lima
# Processing Record 384 in  set 8 | albanel
# Processing Record 385 in  set 8 | bani
# Processing Record 386 in  set 8 | kumta
# Processing Record 387 in  set 8 | avera
# Processing Record 388 in  set 8 | madaoua
# Processing Record 389 in  set 8 | alyangula
# Processing Record 390 in  set 8 | ambon
# Processing Record 391 in  set 8 | southbridge
# Processing Record 392 in  set 8 | mackay
# Processing Record 393 in  set 8 | coihueco
# Processing Record 394 in  set 8 | chaochou
# Missing field/result... skipping.
# Processing Record 395 in  set 8 | nurota
# Processing Record 396 in  set 8 | derzhavinsk
# Processing Record 397 in  set 8 | mazamari
# Processing Record 398 in  set 8 | el tigre
# Processing Record 399 in  set 8 | san rafael
# Processing Record 400 in  set 8 | kotelnikovo
# Processing Record 401 in  set 9 | tumannyy
# Missing field/result... skipping.
# Processing Record 402 in  set 9 | ruatoria
# Missing field/result... skipping.
# Processing Record 403 in  set 9 | coahuayana
# Processing Record 404 in  set 9 | manicore
# Processing Record 405 in  set 9 | alta floresta
# Processing Record 406 in  set 9 | kisangani
# Processing Record 407 in  set 9 | humaita
# Processing Record 408 in  set 9 | bonfim
# Processing Record 409 in  set 9 | shenavan
# Processing Record 410 in  set 9 | paramirim
# Processing Record 411 in  set 9 | eden
# Processing Record 412 in  set 9 | thunder bay
# Processing Record 413 in  set 9 | bacuit
# Missing field/result... skipping.
# Processing Record 414 in  set 9 | kitimat
# Processing Record 415 in  set 9 | dehui
# Processing Record 416 in  set 9 | cairns
# Processing Record 417 in  set 9 | palabuhanratu
# Missing field/result... skipping.
# Processing Record 418 in  set 9 | hofn
# Processing Record 419 in  set 9 | baker city
# Processing Record 420 in  set 9 | choma
# Processing Record 421 in  set 9 | digha
# Processing Record 422 in  set 9 | borkenes
# Processing Record 423 in  set 9 | leninogorsk
# Processing Record 424 in  set 9 | lucea
# Processing Record 425 in  set 9 | esso
# Processing Record 426 in  set 9 | barentsburg
# Missing field/result... skipping.
# Processing Record 427 in  set 9 | kijang
# Processing Record 428 in  set 9 | biu
# Processing Record 429 in  set 9 | cassilandia
# Processing Record 430 in  set 9 | kamenka
# Processing Record 431 in  set 9 | bubaque
# Processing Record 432 in  set 9 | andenes
# Missing field/result... skipping.
# Processing Record 433 in  set 9 | kloulklubed
# Processing Record 434 in  set 9 | bessonovka
# Processing Record 435 in  set 9 | biak
# Processing Record 436 in  set 9 | baykit
# Processing Record 437 in  set 9 | tucurui
# Processing Record 438 in  set 9 | soria
# Processing Record 439 in  set 9 | qunduz
# Missing field/result... skipping.
# Processing Record 440 in  set 9 | paamiut
# Processing Record 441 in  set 9 | jablonne v podjestedi
# Processing Record 442 in  set 9 | myrtle beach
# Processing Record 443 in  set 9 | pangnirtung
# Processing Record 444 in  set 9 | kanniyakumari
# Processing Record 445 in  set 9 | san quintin
# Processing Record 446 in  set 9 | back mountain
# Processing Record 447 in  set 9 | sao jose da coroa grande
# Processing Record 448 in  set 9 | majene
# Processing Record 449 in  set 9 | juegang
# Processing Record 450 in  set 9 | samarai
# Processing Record 451 in  set 10 | kargil
# Processing Record 452 in  set 10 | wangkui
# Processing Record 453 in  set 10 | ibra
# Processing Record 454 in  set 10 | lake havasu city
# Processing Record 455 in  set 10 | monrovia
# Processing Record 456 in  set 10 | kardla
# Processing Record 457 in  set 10 | zhezkazgan
# Processing Record 458 in  set 10 | narsaq
# Processing Record 459 in  set 10 | markova
# Processing Record 460 in  set 10 | yei
# Missing field/result... skipping.
# Processing Record 461 in  set 10 | tukrah
# Missing field/result... skipping.
# Processing Record 462 in  set 10 | vaitupu
# Missing field/result... skipping.
# Processing Record 463 in  set 10 | ukiah
# Processing Record 464 in  set 10 | maniitsoq
# Processing Record 465 in  set 10 | parksville
# Processing Record 466 in  set 10 | macau
# Processing Record 467 in  set 10 | boca do acre
# Processing Record 468 in  set 10 | velikie luki
# Missing field/result... skipping.
# Processing Record 469 in  set 10 | puerto colombia
# Processing Record 470 in  set 10 | pointe-noire
# Processing Record 471 in  set 10 | marsh harbour
# Processing Record 472 in  set 10 | matara
# Processing Record 473 in  set 10 | bartica
# Processing Record 474 in  set 10 | goderich
# Processing Record 475 in  set 10 | korla
# Missing field/result... skipping.
# Processing Record 476 in  set 10 | ulladulla
# Processing Record 477 in  set 10 | skelleftea
# Processing Record 478 in  set 10 | hongjiang
# Processing Record 479 in  set 10 | mitu
# Processing Record 480 in  set 10 | antofagasta
# Processing Record 481 in  set 10 | trzebnica
# Processing Record 482 in  set 10 | hovd
# Processing Record 483 in  set 10 | umba
# Processing Record 484 in  set 10 | saint anthony
# Processing Record 485 in  set 10 | petropavlovsk-kamchatskiy
# Processing Record 486 in  set 10 | kholtoson
# Processing Record 487 in  set 10 | kropotkin
# Processing Record 488 in  set 10 | podgornoye
# Processing Record 489 in  set 10 | skjervoy
# Processing Record 490 in  set 10 | quatre cocos
# Processing Record 491 in  set 10 | mnogovershinnyy
# Processing Record 492 in  set 10 | vallenar
# Processing Record 493 in  set 10 | bisira
# Processing Record 494 in  set 10 | codrington
# Processing Record 495 in  set 10 | hambantota
# Processing Record 496 in  set 10 | zyryanka
# Processing Record 497 in  set 10 | kautokeino
# Processing Record 498 in  set 10 | maceio
# Processing Record 499 in  set 10 | bilma
# Processing Record 500 in  set 10 | tagusao
# Processing Record 501 in  set 11 | richards bay
# Processing Record 502 in  set 11 | ambunti
# Processing Record 503 in  set 11 | tabiauea
# Missing field/result... skipping.
# Processing Record 504 in  set 11 | louisbourg
# Missing field/result... skipping.
# Processing Record 505 in  set 11 | niono
# Processing Record 506 in  set 11 | buariki
# Missing field/result... skipping.
# Processing Record 507 in  set 11 | vilyuysk
# Processing Record 508 in  set 11 | kruisfontein
# Processing Record 509 in  set 11 | ahuimanu
# Processing Record 510 in  set 11 | karratha
# Processing Record 511 in  set 11 | vredendal
# Processing Record 512 in  set 11 | muroto
# Processing Record 513 in  set 11 | whitehorse
# Processing Record 514 in  set 11 | denpasar
# Processing Record 515 in  set 11 | key west
# Processing Record 516 in  set 11 | sedelnikovo
# Missing field/result... skipping.
# Processing Record 517 in  set 11 | candolim
# Processing Record 518 in  set 11 | samalaeulu
# Missing field/result... skipping.
# Processing Record 519 in  set 11 | elliot
# Processing Record 520 in  set 11 | mersing
# Processing Record 521 in  set 11 | yeppoon
# Processing Record 522 in  set 11 | temaraia
# Missing field/result... skipping.
# Processing Record 523 in  set 11 | madera
# Processing Record 524 in  set 11 | havre-saint-pierre
# Processing Record 525 in  set 11 | port keats
# Processing Record 526 in  set 11 | wanning
# Processing Record 527 in  set 11 | napasar
# Processing Record 528 in  set 11 | taoudenni
# Processing Record 529 in  set 11 | tabou
# Processing Record 530 in  set 11 | urumqi
# Missing field/result... skipping.
# Processing Record 531 in  set 11 | gwadar
# Processing Record 532 in  set 11 | egvekinot
# Processing Record 533 in  set 11 | yusva
# Missing field/result... skipping.
# Processing Record 534 in  set 11 | singaraja
# Processing Record 535 in  set 11 | fuerte olimpo
# Processing Record 536 in  set 11 | nong han
# Processing Record 537 in  set 11 | natal
# Processing Record 538 in  set 11 | la libertad
# Processing Record 539 in  set 11 | marilia
# Processing Record 540 in  set 11 | hukuntsi
# Processing Record 541 in  set 11 | nicoya
# Processing Record 542 in  set 11 | cheuskiny
# Missing field/result... skipping.
# Processing Record 543 in  set 11 | opuwo
# Processing Record 544 in  set 11 | borama
# Missing field/result... skipping.
# Processing Record 545 in  set 11 | alekseyevsk
# Processing Record 546 in  set 11 | botshabelo
# Processing Record 547 in  set 11 | byron bay
# Processing Record 548 in  set 11 | keti bandar
# Processing Record 549 in  set 11 | cosala
# Missing field/result... skipping.
# Processing Record 550 in  set 11 | isangel
# Processing Record 551 in  set 12 | oksfjord
# Processing Record 552 in  set 12 | fare
# Processing Record 553 in  set 12 | bilibino
# Processing Record 554 in  set 12 | sukumo
# Processing Record 555 in  set 12 | ormara
# Processing Record 556 in  set 12 | tikapur
# Processing Record 557 in  set 12 | evensk
# Processing Record 558 in  set 12 | barbar
# Missing field/result... skipping.
# Processing Record 559 in  set 12 | suntar
# Processing Record 560 in  set 12 | amderma
# Missing field/result... skipping.
# Processing Record 561 in  set 12 | omboue
# Processing Record 562 in  set 12 | monastyrshchina
# Processing Record 563 in  set 12 | tigil
# Processing Record 564 in  set 12 | portland
# Processing Record 565 in  set 12 | constitucion
# Processing Record 566 in  set 12 | tarko-sale
# Processing Record 567 in  set 12 | silvan
# Processing Record 568 in  set 12 | visby
# Processing Record 569 in  set 12 | jutai
# Processing Record 570 in  set 12 | taicheng
# Processing Record 571 in  set 12 | makhinjauri
# Processing Record 572 in  set 12 | mandera
# Processing Record 573 in  set 12 | manta
# Processing Record 574 in  set 12 | george town
# Processing Record 575 in  set 12 | kirakira
# Processing Record 576 in  set 12 | santa cruz
# Processing Record 577 in  set 12 | college
# Processing Record 578 in  set 12 | buala
# Processing Record 579 in  set 12 | kontagora
# Processing Record 580 in  set 12 | baghdad
# Processing Record 581 in  set 12 | sernur
# Processing Record 582 in  set 12 | faya
# Processing Record 583 in  set 12 | port lincoln
# Processing Record 584 in  set 12 | oussouye
# Processing Record 585 in  set 12 | bobrovka
# Processing Record 586 in  set 12 | necochea
# Processing Record 587 in  set 12 | pringsewu
# Processing Record 588 in  set 12 | cartagena del chaira
# Processing Record 589 in  set 12 | pangai
# Processing Record 590 in  set 12 | jurm
# Processing Record 591 in  set 12 | shebunino
# Processing Record 592 in  set 12 | westport
# Processing Record 593 in  set 12 | sola
# Processing Record 594 in  set 12 | bolungarvik
# Missing field/result... skipping.
# Processing Record 595 in  set 12 | the valley
# Processing Record 596 in  set 12 | kuryk
# Processing Record 597 in  set 12 | canon city
# Processing Record 598 in  set 12 | ugoofaaru
# Processing Record 599 in  set 12 | parry sound
# Processing Record 600 in  set 12 | saint george
# Processing Record 601 in  set 13 | ligayan
# Processing Record 602 in  set 13 | chicama
# Processing Record 603 in  set 13 | seoul
# Processing Record 604 in  set 13 | rundu
# Processing Record 605 in  set 13 | masallatah
# Processing Record 606 in  set 13 | lisala
# Processing Record 607 in  set 13 | sundargarh
# Processing Record 608 in  set 13 | barreirinha
# Processing Record 609 in  set 13 | sernovodsk
# Processing Record 610 in  set 13 | gat
# Processing Record 611 in  set 13 | talakan
# Processing Record 612 in  set 13 | shenkursk
# Processing Record 613 in  set 13 | princeton
# Processing Record 614 in  set 13 | oslo
# Processing Record 615 in  set 13 | rapid valley
# Processing Record 616 in  set 13 | kamaishi
# Processing Record 617 in  set 13 | pasni
# Processing Record 618 in  set 13 | verkhnyaya inta
# Processing Record 619 in  set 13 | somerset west
# Processing Record 620 in  set 13 | pietersburg
# Missing field/result... skipping.
# Processing Record 621 in  set 13 | ferme-neuve
# Processing Record 622 in  set 13 | livingston
# Processing Record 623 in  set 13 | tekkali
# Processing Record 624 in  set 13 | pointe michel
# Processing Record 625 in  set 13 | mobaye
# Processing Record 626 in  set 13 | kajaani
# Processing Record 627 in  set 13 | bingen
# Processing Record 628 in  set 13 | wencheng
# Processing Record 629 in  set 13 | sorochinsk
# Processing Record 630 in  set 13 | santa fe
# Processing Record 631 in  set 13 | vazante
# Processing Record 632 in  set 13 | marquette
# Processing Record 633 in  set 13 | kawalu
# Processing Record 634 in  set 13 | rio grande
# Processing Record 635 in  set 13 | yerbogachen
# Processing Record 636 in  set 13 | bella union
# Processing Record 637 in  set 13 | manokwari
# Processing Record 638 in  set 13 | sentyabrskiy
# Missing field/result... skipping.
# Processing Record 639 in  set 13 | alice springs
# Processing Record 640 in  set 13 | ketchikan
# Processing Record 641 in  set 13 | chapleau
# Processing Record 642 in  set 13 | alakurtti
# Processing Record 643 in  set 13 | zaraza
# Processing Record 644 in  set 13 | kongolo
# Processing Record 645 in  set 13 | svetlogorsk
# Processing Record 646 in  set 13 | ampanihy
# Processing Record 647 in  set 13 | broome
# Processing Record 648 in  set 13 | namatanai
# Processing Record 649 in  set 13 | lukulu
# Processing Record 650 in  set 13 | bobonong
# Missing field/result... skipping.
# Processing Record 651 in  set 14 | chernyshevskiy
# Processing Record 652 in  set 14 | matane
# Processing Record 653 in  set 14 | mackenzie
# Processing Record 654 in  set 14 | bereda
# Processing Record 655 in  set 14 | chimore
# Processing Record 656 in  set 14 | huarmey
# Processing Record 657 in  set 14 | jacareacanga
# Processing Record 658 in  set 14 | wajid
# Processing Record 659 in  set 14 | huangnihe
# Processing Record 660 in  set 14 | bantry
# Missing field/result... skipping.
# Processing Record 661 in  set 14 | sabzevar
# Processing Record 662 in  set 14 | vestmannaeyjar
# Processing Record 663 in  set 14 | zachagansk
# Missing field/result... skipping.
# Processing Record 664 in  set 14 | verkhniy rohachyk
# Processing Record 665 in  set 14 | conceicao do araguaia
# Processing Record 666 in  set 14 | waingapu
# Processing Record 667 in  set 14 | kingston
# Processing Record 668 in  set 14 | andarab
# Missing field/result... skipping.
# Processing Record 669 in  set 14 | agropoli
# Processing Record 670 in  set 14 | toliary
# Missing field/result... skipping.
# Processing Record 671 in  set 14 | tufanganj
# Processing Record 672 in  set 14 | galiakot
# Processing Record 673 in  set 14 | margherita
# Processing Record 674 in  set 14 | hami
# Processing Record 675 in  set 14 | suluova
# Processing Record 676 in  set 14 | zurrieq
# Processing Record 677 in  set 14 | menomonie
# Processing Record 678 in  set 14 | kilindoni
# Processing Record 679 in  set 14 | gigmoto
# Processing Record 680 in  set 14 | coos bay
# Processing Record 681 in  set 14 | fairview
# Processing Record 682 in  set 14 | geaca
# Processing Record 683 in  set 14 | sakhon nakhon
# Missing field/result... skipping.
# Processing Record 684 in  set 14 | fayetteville
# Processing Record 685 in  set 14 | izumo
# Processing Record 686 in  set 14 | aykhal
# Processing Record 687 in  set 14 | imeni poliny osipenko
# Processing Record 688 in  set 14 | jesup
# Processing Record 689 in  set 14 | hit
# Processing Record 690 in  set 14 | cap malheureux
# Processing Record 691 in  set 14 | linhares
# Processing Record 692 in  set 14 | asau
# Missing field/result... skipping.
# Processing Record 693 in  set 14 | herbrechtingen
# Processing Record 694 in  set 14 | khandyga
# Processing Record 695 in  set 14 | culebra
# Processing Record 696 in  set 14 | alpena
# Processing Record 697 in  set 14 | sokolo
# Processing Record 698 in  set 14 | kadykchan
# Missing field/result... skipping.
# Processing Record 699 in  set 14 | alghero
# Processing Record 700 in  set 14 | daugai
# Processing Record 701 in  set 15 | warri
# Processing Record 702 in  set 15 | xinqing
# Processing Record 703 in  set 15 | waipawa
# Processing Record 704 in  set 15 | port hedland
# Processing Record 705 in  set 15 | patnagarh
# Processing Record 706 in  set 15 | burns lake
# Processing Record 707 in  set 15 | nemuro
# Processing Record 708 in  set 15 | hazorasp
# Processing Record 709 in  set 15 | krasnoselkup
# Missing field/result... skipping.
# Processing Record 710 in  set 15 | alofi
# Processing Record 711 in  set 15 | senador jose porfirio
# Processing Record 712 in  set 15 | nizwa
# Processing Record 713 in  set 15 | armacao dos buzios
# Missing field/result... skipping.
# Processing Record 714 in  set 15 | guderup
# Processing Record 715 in  set 15 | liwale
# Processing Record 716 in  set 15 | vomp
# Processing Record 717 in  set 15 | yatou
# Processing Record 718 in  set 15 | la rioja
# Processing Record 719 in  set 15 | gurgan
# Missing field/result... skipping.
# Processing Record 720 in  set 15 | mitsamiouli
# Processing Record 721 in  set 15 | olinda
# Processing Record 722 in  set 15 | cabra
# Processing Record 723 in  set 15 | kingsville
# Processing Record 724 in  set 15 | kati
# Processing Record 725 in  set 15 | safaga
# Missing field/result... skipping.
# Processing Record 726 in  set 15 | juba
# Processing Record 727 in  set 15 | pierre
# Processing Record 728 in  set 15 | udachnyy
# Processing Record 729 in  set 15 | roald
# Processing Record 730 in  set 15 | viedma
# Processing Record 731 in  set 15 | rolim de moura
# Missing field/result... skipping.
# Processing Record 732 in  set 15 | baghmara
# Processing Record 733 in  set 15 | balkhash
# Processing Record 734 in  set 15 | nosy varika
# Processing Record 735 in  set 15 | akdepe
# Processing Record 736 in  set 15 | cuamba
# Processing Record 737 in  set 15 | sainte-marie
# Processing Record 738 in  set 15 | eresos
# Processing Record 739 in  set 15 | north bend
# Processing Record 740 in  set 15 | dera bugti
# Processing Record 741 in  set 15 | halalo
# Missing field/result... skipping.
# Processing Record 742 in  set 15 | muravlenko
# Processing Record 743 in  set 15 | mahon
# Processing Record 744 in  set 15 | hede
# Processing Record 745 in  set 15 | khonuu
# Missing field/result... skipping.
# Processing Record 746 in  set 15 | karaul
# Missing field/result... skipping.
# Processing Record 747 in  set 15 | chara
# Processing Record 748 in  set 15 | tiszafured
# Processing Record 749 in  set 15 | palomares
# Processing Record 750 in  set 15 | lamar
# Processing Record 751 in  set 16 | moron
# Processing Record 752 in  set 16 | shingu
# Processing Record 753 in  set 16 | umzimvubu
# Missing field/result... skipping.
# Processing Record 754 in  set 16 | davila
# Processing Record 755 in  set 16 | velyka lepetykha
# Processing Record 756 in  set 16 | jining
# Processing Record 757 in  set 16 | sembakung
# Processing Record 758 in  set 16 | dalbandin
# Processing Record 759 in  set 16 | ambilobe
# Processing Record 760 in  set 16 | kanigoro
# Processing Record 761 in  set 16 | sept-iles
# Processing Record 762 in  set 16 | moundsville
# Processing Record 763 in  set 16 | shimoda
# Processing Record 764 in  set 16 | bambanglipuro
# Processing Record 765 in  set 16 | warqla
# Missing field/result... skipping.
# Processing Record 766 in  set 16 | mahajanga
# Processing Record 767 in  set 16 | nantucket

# %%
weather_response_json
# Out:
# [{'coord': {'lon': 152.85, 'lat': -25.3},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 70.5,
#    'pressure': 1017,
#    'humidity': 94,
#    'temp_min': 69.8,
#    'temp_max': 71.01},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 170},
#   'clouds': {'all': 75},
#   'dt': 1555697108,
#   'sys': {'type': 1,
#    'id': 9501,
#    'message': 0.0052,
#    'country': 'AU',
#    'sunrise': 1555704321,
#    'sunset': 1555745376},
#   'id': 2146219,
#   'name': 'Hervey Bay',
#   'cod': 200},
#  {'coord': {'lon': 59.53, 'lat': 22.57},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 86.1,
#    'pressure': 1011.135,
#    'humidity': 35,
#    'temp_min': 86.1,
#    'temp_max': 86.1,
#    'sea_level': 1011.135,
#    'grnd_level': 996.038},
#   'wind': {'speed': 7.72, 'deg': 197.042},
#   'clouds': {'all': 0},
#   'dt': 1555697937,
#   'sys': {'message': 0.0044,
#    'country': 'OM',
#    'sunrise': 1555637920,
#    'sunset': 1555683789},
#   'id': 286245,
#   'name': 'Sur',
#   'cod': 200},
#  {'coord': {'lon': 150.17, 'lat': 59.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 26.16,
#    'pressure': 1022.665,
#    'humidity': 98,
#    'temp_min': 26.16,
#    'temp_max': 26.16,
#    'sea_level': 1022.665,
#    'grnd_level': 971.846},
#   'wind': {'speed': 4.97, 'deg': 159.157},
#   'clouds': {'all': 100},
#   'dt': 1555697937,
#   'sys': {'message': 0.0042,
#    'country': 'RU',
#    'sunrise': 1555698671,
#    'sunset': 1555752311},
#   'id': 2127060,
#   'name': 'Arman',
#   'cod': 200},
#  {'coord': {'lon': -70.03, 'lat': -15.84},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 59,
#    'pressure': 1037,
#    'humidity': 47,
#    'temp_min': 59,
#    'temp_max': 59},
#   'visibility': 10000,
#   'wind': {'speed': 1.12},
#   'clouds': {'all': 75},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 8667,
#    'message': 0.0045,
#    'country': 'PE',
#    'sunrise': 1555670902,
#    'sunset': 1555712987},
#   'id': 3931276,
#   'name': 'Puno',
#   'cod': 200},
#  {'coord': {'lon': 170.27, 'lat': 69.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10.32,
#    'pressure': 1017.609,
#    'humidity': 92,
#    'temp_min': 10.32,
#    'temp_max': 10.32,
#    'sea_level': 1017.609,
#    'grnd_level': 1019.254},
#   'wind': {'speed': 14.34, 'deg': 264.494},
#   'clouds': {'all': 100},
#   'dt': 1555697937,
#   'sys': {'message': 0.0064,
#    'country': 'RU',
#    'sunrise': 1555690547,
#    'sunset': 1555750789},
#   'id': 2122090,
#   'name': 'Pevek',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 71.24,
#    'pressure': 1004,
#    'humidity': 56,
#    'temp_min': 66,
#    'temp_max': 73.99},
#   'visibility': 16093,
#   'wind': {'speed': 11.41, 'deg': 230, 'gust': 7.2},
#   'clouds': {'all': 90},
#   'dt': 1555697340,
#   'sys': {'type': 1,
#    'id': 5137,
#    'message': 0.0073,
#    'country': 'US',
#    'sunrise': 1555668446,
#    'sunset': 1555717228},
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -8.72, 'lat': 41.31},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 67.96,
#    'pressure': 1016,
#    'humidity': 64,
#    'temp_min': 64.99,
#    'temp_max': 71.6},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 340},
#   'clouds': {'all': 20},
#   'dt': 1555697825,
#   'sys': {'type': 1,
#    'id': 6900,
#    'message': 0.005,
#    'country': 'PT',
#    'sunrise': 1555652978,
#    'sunset': 1555701486},
#   'id': 2739997,
#   'name': 'Mindelo',
#   'cod': 200},
#  {'coord': {'lon': 39.82, 'lat': 64.56},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 39.2,
#    'pressure': 1023,
#    'humidity': 97,
#    'temp_min': 39.2,
#    'temp_max': 39.2},
#   'visibility': 10000,
#   'wind': {'speed': 2.24},
#   'clouds': {'all': 40},
#   'dt': 1555695000,
#   'sys': {'type': 1,
#    'id': 8922,
#    'message': 0.0049,
#    'country': 'RU',
#    'sunrise': 1555637651,
#    'sunset': 1555693517},
#   'id': 496285,
#   'name': 'Severodvinsk',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -13.67, 'lat': 13.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 109.5,
#    'pressure': 1004.397,
#    'humidity': 6,
#    'temp_min': 109.5,
#    'temp_max': 109.5,
#    'sea_level': 1004.397,
#    'grnd_level': 1000.822},
#   'wind': {'speed': 6.22, 'deg': 30.205},
#   'clouds': {'all': 0},
#   'dt': 1555697938,
#   'sys': {'message': 0.0059,
#    'country': 'SN',
#    'sunrise': 1555655950,
#    'sunset': 1555700890},
#   'id': 2244991,
#   'name': 'Tambacounda',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 78.72,
#    'pressure': 1015.125,
#    'humidity': 74,
#    'temp_min': 78.72,
#    'temp_max': 78.72,
#    'sea_level': 1015.125,
#    'grnd_level': 1015.014},
#   'wind': {'speed': 7.63, 'deg': 66.063},
#   'clouds': {'all': 16},
#   'dt': 1555697280,
#   'sys': {'message': 0.0048,
#    'country': 'PF',
#    'sunrise': 1555686871,
#    'sunset': 1555728185},
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': -170.99, 'lat': 65.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': -4.81,
#    'pressure': 1012.927,
#    'humidity': 83,
#    'temp_min': -4.81,
#    'temp_max': -4.81,
#    'sea_level': 1012.927,
#    'grnd_level': 967.702},
#   'wind': {'speed': 5.57, 'deg': 314.106},
#   'clouds': {'all': 0},
#   'dt': 1555697938,
#   'sys': {'message': 0.0053,
#    'country': 'RU',
#    'sunrise': 1555773960,
#    'sunset': 1555831157},
#   'id': 4031637,
#   'name': 'Lavrentiya',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -124.16, 'lat': 40.8},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 57.65,
#    'pressure': 1016,
#    'humidity': 93,
#    'temp_min': 53.6,
#    'temp_max': 66},
#   'visibility': 16093,
#   'wind': {'speed': 5.82, 'deg': 260},
#   'clouds': {'all': 90},
#   'dt': 1555697905,
#   'sys': {'type': 1,
#    'id': 3217,
#    'message': 0.0058,
#    'country': 'US',
#    'sunrise': 1555680700,
#    'sunset': 1555729167},
#   'id': 5563397,
#   'name': 'Eureka',
#   'cod': 200},
#  {'coord': {'lon': -65.04, 'lat': -42.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 67.56,
#    'pressure': 1010.683,
#    'humidity': 33,
#    'temp_min': 67.56,
#    'temp_max': 67.56,
#    'sea_level': 1010.683,
#    'grnd_level': 997.094},
#   'wind': {'speed': 21.07, 'deg': 225.022},
#   'clouds': {'all': 0},
#   'dt': 1555697939,
#   'sys': {'message': 0.0051,
#    'country': 'AR',
#    'sunrise': 1555671385,
#    'sunset': 1555710109},
#   'id': 3840092,
#   'name': 'Puerto Madryn',
#   'cod': 200},
#  {'coord': {'lon': -4.75, 'lat': 43.42},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 62.47,
#    'pressure': 1015,
#    'humidity': 80,
#    'temp_min': 61,
#    'temp_max': 64.99},
#   'wind': {'speed': 11.12, 'deg': 84.519},
#   'clouds': {'all': 100},
#   'dt': 1555697774,
#   'sys': {'type': 3,
#    'id': 2010396,
#    'message': 0.0041,
#    'country': 'ES',
#    'sunrise': 1555651831,
#    'sunset': 1555700728},
#   'id': 3118304,
#   'name': 'Llanes',
#   'cod': 200},
#  {'coord': {'lon': -67.52, 'lat': -46.43},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 63.6,
#    'pressure': 1011.501,
#    'humidity': 38,
#    'temp_min': 63.6,
#    'temp_max': 63.6,
#    'sea_level': 1011.501,
#    'grnd_level': 976.006},
#   'wind': {'speed': 24.05, 'deg': 196.538},
#   'clouds': {'all': 51},
#   'dt': 1555697379,
#   'sys': {'message': 0.0044,
#    'country': 'AR',
#    'sunrise': 1555672309,
#    'sunset': 1555710375},
#   'id': 3863379,
#   'name': 'Mar del Plata',
#   'cod': 200},
#  {'coord': {'lon': -127.17, 'lat': 54.78},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 41,
#    'pressure': 1013,
#    'humidity': 56,
#    'temp_min': 41,
#    'temp_max': 41},
#   'visibility': 40233,
#   'wind': {'speed': 3.36},
#   'clouds': {'all': 75},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 990,
#    'message': 0.0052,
#    'country': 'CA',
#    'sunrise': 1555679779,
#    'sunset': 1555731533},
#   'id': 6149996,
#   'name': 'Smithers',
#   'cod': 200},
#  {'coord': {'lon': -86.95, 'lat': 49.72},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 53.6,
#    'pressure': 1012,
#    'humidity': 27,
#    'temp_min': 53.6,
#    'temp_max': 53.6},
#   'visibility': 24140,
#   'wind': {'speed': 8.05, 'deg': 260},
#   'clouds': {'all': 40},
#   'dt': 1555696800,
#   'sys': {'type': 1,
#    'id': 810,
#    'message': 0.0049,
#    'country': 'CA',
#    'sunrise': 1555670850,
#    'sunset': 1555721159},
#   'id': 5960603,
#   'name': 'Geraldton',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 43.05,
#    'pressure': 1026,
#    'humidity': 93,
#    'temp_min': 39,
#    'temp_max': 46},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 330},
#   'clouds': {'all': 75},
#   'dt': 1555697294,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0057,
#    'country': 'AU',
#    'sunrise': 1555706853,
#    'sunset': 1555745493},
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': -4.78, 'lat': 12.35},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 102.66,
#    'pressure': 1004.871,
#    'humidity': 20,
#    'temp_min': 102.66,
#    'temp_max': 102.66,
#    'sea_level': 1004.871,
#    'grnd_level': 969.222},
#   'wind': {'speed': 5.5, 'deg': 154.216},
#   'clouds': {'all': 94},
#   'dt': 1555697939,
#   'sys': {'message': 0.0051,
#    'country': 'ML',
#    'sunrise': 1555653889,
#    'sunset': 1555698684},
#   'id': 2448442,
#   'name': 'Yorosso',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 83.04,
#    'pressure': 1007.399,
#    'humidity': 77,
#    'temp_min': 83.04,
#    'temp_max': 83.04,
#    'sea_level': 1007.399,
#    'grnd_level': 1007.446},
#   'wind': {'speed': 17.02, 'deg': 36.636},
#   'rain': {'3h': 6.312},
#   'clouds': {'all': 100},
#   'dt': 1555697383,
#   'sys': {'message': 0.0043,
#    'country': 'KI',
#    'sunrise': 1555698113,
#    'sunset': 1555742014},
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': -52.73, 'lat': 47.66},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 36.68,
#    'pressure': 1023,
#    'humidity': 59,
#    'temp_min': 35.01,
#    'temp_max': 39.2},
#   'visibility': 24140,
#   'wind': {'speed': 11.41, 'deg': 180, 'gust': 8.2},
#   'clouds': {'all': 90},
#   'dt': 1555697912,
#   'sys': {'type': 1,
#    'id': 554,
#    'message': 0.0062,
#    'country': 'CA',
#    'sunrise': 1555662892,
#    'sunset': 1555712694},
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'coord': {'lon': -52.33, 'lat': 4.94},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1012,
#    'humidity': 83,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 40},
#   'clouds': {'all': 98},
#   'dt': 1555695000,
#   'sys': {'type': 1,
#    'id': 8669,
#    'message': 0.0052,
#    'country': 'GF',
#    'sunrise': 1555665659,
#    'sunset': 1555709735},
#   'id': 3382160,
#   'name': 'Cayenne',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'pressure': 1002,
#    'humidity': 75,
#    'temp_min': 46.4,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 28.86, 'deg': 230, 'gust': 18},
#   'clouds': {'all': 75},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 8303,
#    'message': 0.0066,
#    'country': 'AR',
#    'sunrise': 1555673458,
#    'sunset': 1555709605},
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -94.42, 'lat': 30.04},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 70.45,
#    'pressure': 1016,
#    'humidity': 37,
#    'temp_min': 69.01,
#    'temp_max': 72},
#   'visibility': 16093,
#   'wind': {'speed': 20.8, 'deg': 310, 'gust': 13.9},
#   'clouds': {'all': 40},
#   'dt': 1555697919,
#   'sys': {'type': 1,
#    'id': 3476,
#    'message': 0.0051,
#    'country': 'US',
#    'sunrise': 1555674387,
#    'sunset': 1555721207},
#   'id': 4732862,
#   'name': 'Nome',
#   'cod': 200},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 63.79,
#    'pressure': 1011,
#    'humidity': 49,
#    'temp_min': 60.01,
#    'temp_max': 68},
#   'wind': {'speed': 9.17, 'deg': 280},
#   'clouds': {'all': 92},
#   'dt': 1555696854,
#   'sys': {'type': 1,
#    'id': 1966,
#    'message': 0.0043,
#    'country': 'ZA',
#    'sunrise': 1555650337,
#    'sunset': 1555690324},
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 45.76, 'lat': 64.9},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 33.36,
#    'pressure': 1024.857,
#    'humidity': 90,
#    'temp_min': 33.36,
#    'temp_max': 33.36,
#    'sea_level': 1024.857,
#    'grnd_level': 1015.35},
#   'wind': {'speed': 1.97, 'deg': 138.475},
#   'clouds': {'all': 98},
#   'dt': 1555697940,
#   'sys': {'message': 0.004,
#    'country': 'RU',
#    'sunrise': 1555636125,
#    'sunset': 1555692193},
#   'id': 535839,
#   'name': 'Leshukonskoye',
#   'cod': 200},
#  {'coord': {'lon': 80.87, 'lat': 59.06},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 28.14,
#    'pressure': 1014.061,
#    'humidity': 84,
#    'temp_min': 28.14,
#    'temp_max': 28.14,
#    'sea_level': 1014.061,
#    'grnd_level': 1006.87},
#   'wind': {'speed': 7.83, 'deg': 237.196},
#   'clouds': {'all': 71},
#   'dt': 1555697940,
#   'sys': {'message': 0.0052,
#    'country': 'RU',
#    'sunrise': 1555715406,
#    'sunset': 1555768836},
#   'id': 1504382,
#   'name': 'Kargasok',
#   'cod': 200},
#  {'coord': {'lon': 147.26, 'lat': -43.03},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 42.89,
#    'pressure': 1026,
#    'humidity': 93,
#    'temp_min': 39,
#    'temp_max': 46},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 330},
#   'clouds': {'all': 75},
#   'dt': 1555697834,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0052,
#    'country': 'AU',
#    'sunrise': 1555706883,
#    'sunset': 1555745496},
#   'id': 2158744,
#   'name': 'Margate',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 41.65,
#    'pressure': 1014,
#    'humidity': 98,
#    'temp_min': 41,
#    'temp_max': 43},
#   'wind': {'speed': 24.99, 'deg': 198.216},
#   'rain': {'3h': 0.376},
#   'clouds': {'all': 97},
#   'dt': 1555697276,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'message': 0.0043,
#    'country': 'AU',
#    'sunrise': 1555713837,
#    'sunset': 1555753857},
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -56.15, 'lat': 72.79},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 9.78,
#    'pressure': 1010.111,
#    'humidity': 64,
#    'temp_min': 9.78,
#    'temp_max': 9.78,
#    'sea_level': 1010.111,
#    'grnd_level': 1010.614},
#   'wind': {'speed': 6.38, 'deg': 42.368},
#   'clouds': {'all': 0},
#   'dt': 1555697380,
#   'sys': {'message': 0.0044,
#    'country': 'GL',
#    'sunrise': 1555656635,
#    'sunset': 1555720592},
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  {'coord': {'lon': -5.02, 'lat': 34.03},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 58.03,
#    'pressure': 1014,
#    'humidity': 67,
#    'temp_min': 57.2,
#    'temp_max': 59},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 360},
#   'clouds': {'all': 75},
#   'dt': 1555696800,
#   'sys': {'type': 1,
#    'id': 2390,
#    'message': 0.0055,
#    'country': 'MA',
#    'sunrise': 1555652673,
#    'sunset': 1555700016},
#   'id': 2548885,
#   'name': 'Fez',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 61.36,
#    'pressure': 1015,
#    'humidity': 93,
#    'temp_min': 60.01,
#    'temp_max': 64},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 320},
#   'clouds': {'all': 75},
#   'dt': 1555697774,
#   'sys': {'type': 1,
#    'id': 1899,
#    'message': 0.0052,
#    'country': 'ZA',
#    'sunrise': 1555650686,
#    'sunset': 1555690753},
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 60.57,
#    'pressure': 1010,
#    'humidity': 96,
#    'temp_min': 60.01,
#    'temp_max': 61},
#   'wind': {'speed': 8.01, 'deg': 303, 'gust': 6.26},
#   'clouds': {'all': 98},
#   'dt': 1555696854,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'message': 0.0047,
#    'country': 'ZA',
#    'sunrise': 1555650522,
#    'sunset': 1555690524},
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': 38.73, 'lat': 8.96},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.7,
#    'pressure': 1015.627,
#    'humidity': 67,
#    'temp_min': 62.7,
#    'temp_max': 62.7,
#    'sea_level': 1015.627,
#    'grnd_level': 769.286},
#   'wind': {'speed': 4.16, 'deg': 127.24},
#   'clouds': {'all': 73},
#   'dt': 1555697941,
#   'sys': {'message': 0.0058,
#    'country': 'ET',
#    'sunrise': 1555643617,
#    'sunset': 1555688074},
#   'id': 344979,
#   'name': 'Lebu',
#   'cod': 200},
#  {'coord': {'lon': -120.46, 'lat': 34.64},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 58.35,
#    'pressure': 1016,
#    'humidity': 100,
#    'temp_min': 51.8,
#    'temp_max': 69.01},
#   'visibility': 8047,
#   'wind': {'speed': 5.82, 'deg': 300},
#   'clouds': {'all': 90},
#   'dt': 1555697855,
#   'sys': {'type': 1,
#    'id': 6155,
#    'message': 0.0061,
#    'country': 'US',
#    'sunrise': 1555680310,
#    'sunset': 1555727781},
#   'id': 5367788,
#   'name': 'Lompoc',
#   'cod': 200},
#  {'coord': {'lon': -53.46, 'lat': 68.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 14.82,
#    'pressure': 1007.143,
#    'humidity': 72,
#    'temp_min': 14.82,
#    'temp_max': 14.82,
#    'sea_level': 1007.143,
#    'grnd_level': 1007.43},
#   'wind': {'speed': 9.46, 'deg': 37.75},
#   'clouds': {'all': 0},
#   'dt': 1555697941,
#   'sys': {'message': 0.0047,
#    'country': 'GL',
#    'sunrise': 1555658614,
#    'sunset': 1555717322},
#   'id': 3422683,
#   'name': 'Kangaatsiaq',
#   'cod': 200},
#  {'coord': {'lon': 125.41, 'lat': -8.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.86,
#    'pressure': 1009.941,
#    'humidity': 73,
#    'temp_min': 73.86,
#    'temp_max': 73.86,
#    'sea_level': 1009.941,
#    'grnd_level': 974.614},
#   'wind': {'speed': 5.91, 'deg': 142.63},
#   'clouds': {'all': 10},
#   'dt': 1555697941,
#   'sys': {'message': 0.0045,
#    'country': 'TL',
#    'sunrise': 1555710059,
#    'sunset': 1555752807},
#   'id': 1651810,
#   'name': 'Airai',
#   'cod': 200},
#  {'coord': {'lon': -74.98, 'lat': 39.31},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 74.3,
#    'pressure': 1010,
#    'humidity': 82,
#    'temp_min': 64,
#    'temp_max': 79},
#   'visibility': 16093,
#   'wind': {'speed': 16.02, 'deg': 186.256},
#   'clouds': {'all': 90},
#   'dt': 1555697923,
#   'sys': {'type': 1,
#    'id': 6276,
#    'message': 0.0063,
#    'country': 'US',
#    'sunrise': 1555669037,
#    'sunset': 1555717227},
#   'id': 4501427,
#   'name': 'Port Elizabeth',
#   'cod': 200},
#  {'coord': {'lon': 12.69, 'lat': 67.67},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 42.8,
#    'pressure': 1029,
#    'humidity': 93,
#    'temp_min': 42.8,
#    'temp_max': 42.8},
#   'visibility': 8000,
#   'wind': {'speed': 10.29, 'deg': 150},
#   'clouds': {'all': 75},
#   'dt': 1555694400,
#   'sys': {'type': 1,
#    'id': 1642,
#    'message': 0.0045,
#    'country': 'NO',
#    'sunrise': 1555643056,
#    'sunset': 1555701133},
#   'id': 3137469,
#   'name': 'Sorland',
#   'cod': 200},
#  {'coord': {'lon': -47.36, 'lat': -0.61},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 81.96,
#    'pressure': 1010.091,
#    'humidity': 80,
#    'temp_min': 81.96,
#    'temp_max': 81.96,
#    'sea_level': 1010.091,
#    'grnd_level': 1010.278},
#   'wind': {'speed': 15.95, 'deg': 44.517},
#   'rain': {'3h': 6.563},
#   'clouds': {'all': 100},
#   'dt': 1555697736,
#   'sys': {'message': 0.0042,
#    'country': 'BR',
#    'sunrise': 1555664730,
#    'sunset': 1555708279},
#   'id': 3389822,
#   'name': 'Salinopolis',
#   'cod': 200},
#  {'coord': {'lon': 30.79, 'lat': 59.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 50.36,
#    'pressure': 1028,
#    'humidity': 50,
#    'temp_min': 46,
#    'temp_max': 52},
#   'visibility': 10000,
#   'wind': {'speed': 13.42, 'deg': 310},
#   'clouds': {'all': 0},
#   'dt': 1555697737,
#   'sys': {'type': 1,
#    'id': 8926,
#    'message': 0.0051,
#    'country': 'RU',
#    'sunrise': 1555641037,
#    'sunset': 1555694465},
#   'id': 546105,
#   'name': 'Nikolskoye',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -42.02, 'lat': -22.97},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 81.54,
#    'pressure': 1013,
#    'humidity': 74,
#    'temp_min': 80.6,
#    'temp_max': 82.4},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 270},
#   'clouds': {'all': 0},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 8326,
#    'message': 0.0074,
#    'country': 'BR',
#    'sunrise': 1555664548,
#    'sunset': 1555705897},
#   'id': 3471451,
#   'name': 'Arraial do Cabo',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'pressure': 1012,
#    'humidity': 69,
#    'temp_min': 75.2,
#    'temp_max': 75.2},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 140},
#   'clouds': {'all': 98},
#   'dt': 1555695000,
#   'sys': {'type': 1,
#    'id': 7271,
#    'message': 0.0057,
#    'country': 'CK',
#    'sunrise': 1555692723,
#    'sunset': 1555734239},
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': -38.6, 'lat': -3.71},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 85.03,
#    'pressure': 1010,
#    'humidity': 70,
#    'temp_min': 82.99,
#    'temp_max': 86},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 80},
#   'clouds': {'all': 40},
#   'dt': 1555697900,
#   'sys': {'type': 1,
#    'id': 8363,
#    'message': 0.0052,
#    'country': 'BR',
#    'sunrise': 1555662774,
#    'sunset': 1555706030},
#   'id': 6320062,
#   'name': 'Vila Velha',
#   'cod': 200},
#  {'coord': {'lon': -155.08, 'lat': 19.71},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 69.85,
#    'pressure': 1019,
#    'humidity': 82,
#    'temp_min': 66.2,
#    'temp_max': 73},
#   'visibility': 16093,
#   'wind': {'speed': 5.82, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1555697909,
#   'sys': {'type': 1,
#    'id': 7881,
#    'message': 0.0065,
#    'country': 'US',
#    'sunrise': 1555689558,
#    'sunset': 1555735148},
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'coord': {'lon': -50.22, 'lat': -30.17},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 78.9,
#    'pressure': 1011.173,
#    'humidity': 51,
#    'temp_min': 78.9,
#    'temp_max': 78.9,
#    'sea_level': 1011.173,
#    'grnd_level': 1009.974},
#   'wind': {'speed': 7.31, 'deg': 262.353},
#   'clouds': {'all': 42},
#   'dt': 1555697943,
#   'sys': {'message': 0.0046,
#    'country': 'BR',
#    'sunrise': 1555666930,
#    'sunset': 1555707451},
#   'id': 3466165,
#   'name': 'Cidreira',
#   'cod': 200},
#  {'coord': {'lon': -39.03, 'lat': -3.41},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 85.12,
#    'pressure': 1010,
#    'humidity': 70,
#    'temp_min': 82.99,
#    'temp_max': 86},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 80},
#   'clouds': {'all': 40},
#   'dt': 1555697900,
#   'sys': {'type': 1,
#    'id': 8363,
#    'message': 0.0069,
#    'country': 'BR',
#    'sunrise': 1555662863,
#    'sunset': 1555706148},
#   'id': 3393115,
#   'name': 'Paracuru',
#   'cod': 200},
#  {'coord': {'lon': 22.13, 'lat': -30.97},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 69.36,
#    'pressure': 1013.129,
#    'humidity': 9,
#    'temp_min': 69.36,
#    'temp_max': 69.36,
#    'sea_level': 1013.129,
#    'grnd_level': 869.11},
#   'wind': {'speed': 12.66, 'deg': 268.431},
#   'clouds': {'all': 70},
#   'dt': 1555697943,
#   'sys': {'message': 0.0045,
#    'country': 'ZA',
#    'sunrise': 1555649607,
#    'sunset': 1555690051},
#   'id': 1014034,
#   'name': 'Carnarvon',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'pressure': 1013,
#    'humidity': 83,
#    'temp_min': 75.2,
#    'temp_max': 75.2},
#   'visibility': 6000,
#   'wind': {'speed': 5.82, 'deg': 270},
#   'clouds': {'all': 4},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 9229,
#    'message': 0.0038,
#    'country': 'IN',
#    'sunrise': 1555634720,
#    'sunset': 1555679809},
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': -0.61, 'lat': 44.83},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 70.72,
#    'pressure': 1022,
#    'humidity': 37,
#    'temp_min': 66.2,
#    'temp_max': 73.99},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 110},
#   'clouds': {'all': 0},
#   'dt': 1555697930,
#   'sys': {'type': 1,
#    'id': 6450,
#    'message': 0.0047,
#    'country': 'FR',
#    'sunrise': 1555650700,
#    'sunset': 1555699872},
#   'id': 3031582,
#   'name': 'Saint-Augustin',
#   'cod': 200},
#  {'coord': {'lon': 147.9, 'lat': 70.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 1.14,
#    'pressure': 1022.603,
#    'humidity': 84,
#    'temp_min': 1.14,
#    'temp_max': 1.14,
#    'sea_level': 1022.603,
#    'grnd_level': 1020.806},
#   'wind': {'speed': 6.71, 'deg': 207.206},
#   'clouds': {'all': 0},
#   'dt': 1555697944,
#   'sys': {'message': 0.0049,
#    'country': 'RU',
#    'sunrise': 1555695388,
#    'sunset': 1555756685},
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 20.71, 'lat': 41.28},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 57.2,
#    'pressure': 1023,
#    'humidity': 30,
#    'temp_min': 57.2,
#    'temp_max': 57.2},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 320},
#   'clouds': {'all': 40},
#   'dt': 1555695000,
#   'sys': {'type': 1,
#    'id': 7013,
#    'message': 0.0062,
#    'country': 'MK',
#    'sunrise': 1555645924,
#    'sunset': 1555694415},
#   'id': 787487,
#   'name': 'Poum',
#   'cod': 200},
#  {'coord': {'lon': 100.36, 'lat': -0.92},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 85.2,
#    'pressure': 1009.793,
#    'humidity': 73,
#    'temp_min': 85.2,
#    'temp_max': 85.2,
#    'sea_level': 1009.793,
#    'grnd_level': 1008.71},
#   'wind': {'speed': 7.63, 'deg': 325.47},
#   'rain': {'3h': 7.75},
#   'clouds': {'all': 100},
#   'dt': 1555697944,
#   'sys': {'message': 0.0064,
#    'country': 'ID',
#    'sunrise': 1555715685,
#    'sunset': 1555759203},
#   'id': 1633419,
#   'name': 'Padang',
#   'cod': 200},
#  {'coord': {'lon': -96.47, 'lat': 15.74},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 85.87,
#    'pressure': 1013,
#    'humidity': 58,
#    'temp_min': 80.6,
#    'temp_max': 91.99},
#   'visibility': 9656,
#   'wind': {'speed': 2.59, 'deg': 171.066},
#   'clouds': {'all': 40},
#   'dt': 1555697767,
#   'sys': {'type': 1,
#    'id': 7096,
#    'message': 0.0049,
#    'country': 'MX',
#    'sunrise': 1555675712,
#    'sunset': 1555720866},
#   'id': 3517970,
#   'name': 'Pochutla',
#   'cod': 200},
#  {'coord': {'lon': -73.76, 'lat': -42.48},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 55.4,
#    'pressure': 1019,
#    'humidity': 71,
#    'temp_min': 55.4,
#    'temp_max': 55.4},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 170},
#   'clouds': {'all': 20},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0047,
#    'country': 'CL',
#    'sunrise': 1555673455,
#    'sunset': 1555712224},
#   'id': 3896218,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': -11.44, 'lat': 14.44},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 110.4,
#    'pressure': 1004.437,
#    'humidity': 4,
#    'temp_min': 110.4,
#    'temp_max': 110.4,
#    'sea_level': 1004.437,
#    'grnd_level': 997.782},
#   'wind': {'speed': 6.87, 'deg': 11.658},
#   'clouds': {'all': 0},
#   'dt': 1555697944,
#   'sys': {'message': 0.0049,
#    'country': 'ML',
#    'sunrise': 1555655380,
#    'sunset': 1555700389},
#   'id': 2455518,
#   'name': 'Kayes',
#   'cod': 200},
#  {'coord': {'lon': 15.16, 'lat': -26.65},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 58.56,
#    'pressure': 1017.011,
#    'humidity': 87,
#    'temp_min': 58.56,
#    'temp_max': 58.56,
#    'sea_level': 1017.011,
#    'grnd_level': 1017.126},
#   'wind': {'speed': 13.33, 'deg': 174.993},
#   'clouds': {'all': 82},
#   'dt': 1555697944,
#   'sys': {'message': 0.0042,
#    'country': 'NA',
#    'sunrise': 1555651025,
#    'sunset': 1555691978},
#   'id': 3355672,
#   'name': 'Luderitz',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -46, 'lat': -20.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 77.1,
#    'pressure': 1013.575,
#    'humidity': 51,
#    'temp_min': 77.1,
#    'temp_max': 77.1,
#    'sea_level': 1013.575,
#    'grnd_level': 903.222},
#   'wind': {'speed': 5.86, 'deg': 245.493},
#   'clouds': {'all': 0},
#   'dt': 1555697945,
#   'sys': {'message': 0.0059,
#    'country': 'BR',
#    'sunrise': 1555665379,
#    'sunset': 1555706977},
#   'id': 3453439,
#   'name': 'Ponta do Sol',
#   'cod': 200},
#  {'coord': {'lon': -69.36, 'lat': 77.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': -12.01,
#    'pressure': 1013.407,
#    'humidity': 83,
#    'temp_min': -12.01,
#    'temp_max': -12.01,
#    'sea_level': 1013.407,
#    'grnd_level': 960.358},
#   'wind': {'speed': 3.85, 'deg': 68.353},
#   'clouds': {'all': 97},
#   'dt': 1555697374,
#   'sys': {'message': 0.0061,
#    'country': 'GL',
#    'sunrise': 1555652717,
#    'sunset': 1555730850},
#   'id': 3831208,
#   'name': 'Qaanaaq',
#   'cod': 200},
#  {'coord': {'lon': 39.51, 'lat': 68.05},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 32.82,
#    'pressure': 1026.669,
#    'humidity': 93,
#    'temp_min': 32.82,
#    'temp_max': 32.82,
#    'sea_level': 1026.669,
#    'grnd_level': 1010.47},
#   'wind': {'speed': 8.79, 'deg': 338.361},
#   'clouds': {'all': 94},
#   'dt': 1555697384,
#   'sys': {'message': 0.0047,
#    'country': 'RU',
#    'sunrise': 1555636482,
#    'sunset': 1555694835},
#   'id': 556268,
#   'name': 'Ostrovnoy',
#   'cod': 200},
#  {'coord': {'lon': -98.2, 'lat': 32.22},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 65.14,
#    'pressure': 1022,
#    'humidity': 31,
#    'temp_min': 62.6,
#    'temp_max': 66.99},
#   'visibility': 16093,
#   'wind': {'speed': 20.8, 'deg': 330, 'gust': 13.4},
#   'clouds': {'all': 1},
#   'dt': 1555697916,
#   'sys': {'type': 1,
#    'id': 5806,
#    'message': 0.0059,
#    'country': 'US',
#    'sunrise': 1555675146,
#    'sunset': 1555722262},
#   'id': 4734350,
#   'name': 'Stephenville',
#   'cod': 200},
#  {'coord': {'lon': -122.69, 'lat': 58.81},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'pressure': 1003,
#    'humidity': 29,
#    'temp_min': 50,
#    'temp_max': 50},
#   'visibility': 48279,
#   'wind': {'speed': 16.11, 'deg': 230},
#   'clouds': {'all': 40},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 986,
#    'message': 0.0045,
#    'country': 'CA',
#    'sunrise': 1555677984,
#    'sunset': 1555731178},
#   'id': 5955902,
#   'name': 'Fort Nelson',
#   'cod': 200},
#  {'coord': {'lon': 32.53, 'lat': 34.92},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 60.01,
#    'pressure': 1015,
#    'humidity': 67,
#    'temp_min': 55,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 270},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 75},
#   'dt': 1555697760,
#   'sys': {'type': 1,
#    'id': 6374,
#    'message': 0.0064,
#    'country': 'CY',
#    'sunrise': 1555643603,
#    'sunset': 1555691063},
#   'id': 146639,
#   'name': 'Lasa',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 21.84, 'lat': 55.91},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 42.8,
#    'pressure': 1032,
#    'humidity': 81,
#    'temp_min': 42.8,
#    'temp_max': 42.8},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 350},
#   'clouds': {'all': 0},
#   'dt': 1555696200,
#   'sys': {'type': 1,
#    'id': 1881,
#    'message': 0.0045,
#    'country': 'LT',
#    'sunrise': 1555643892,
#    'sunset': 1555695906},
#   'id': 595689,
#   'name': 'Plunge',
#   'cod': 200},
#  {'coord': {'lon': 122.52, 'lat': -3.99},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 75.48,
#    'pressure': 1008.975,
#    'humidity': 96,
#    'temp_min': 75.48,
#    'temp_max': 75.48,
#    'sea_level': 1008.975,
#    'grnd_level': 997.99},
#   'wind': {'speed': 2.01, 'deg': 196.12},
#   'rain': {'3h': 0.313},
#   'clouds': {'all': 50},
#   'dt': 1555697947,
#   'sys': {'message': 0.0051,
#    'country': 'ID',
#    'sunrise': 1555710514,
#    'sunset': 1555753738},
#   'id': 1640344,
#   'name': 'Kendari',
#   'cod': 200},
#  {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.29,
#    'pressure': 1012,
#    'humidity': 70,
#    'temp_min': 82,
#    'temp_max': 86},
#   'visibility': 10000,
#   'wind': {'speed': 16.11, 'deg': 120},
#   'clouds': {'all': 20},
#   'dt': 1555696879,
#   'sys': {'type': 1,
#    'id': 8521,
#    'message': 0.0056,
#    'country': 'EC',
#    'sunrise': 1555675052,
#    'sunset': 1555718588},
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  {'coord': {'lon': -77.74, 'lat': 39.62},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 69.12,
#    'pressure': 1007,
#    'humidity': 83,
#    'temp_min': 66,
#    'temp_max': 72},
#   'visibility': 8047,
#   'wind': {'speed': 8.05, 'deg': 170},
#   'rain': {'1h': 0.64},
#   'clouds': {'all': 90},
#   'dt': 1555697662,
#   'sys': {'type': 1,
#    'id': 3841,
#    'message': 0.0079,
#    'country': 'US',
#    'sunrise': 1555669673,
#    'sunset': 1555717916},
#   'id': 4372777,
#   'name': 'Vardo',
#   'cod': 200},
#  {'coord': {'lon': -73.83, 'lat': -41.87},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 55.4,
#    'pressure': 1019,
#    'humidity': 71,
#    'temp_min': 55.4,
#    'temp_max': 55.4},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 170},
#   'clouds': {'all': 20},
#   'dt': 1555693200,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.005,
#    'country': 'CL',
#    'sunrise': 1555673421,
#    'sunset': 1555712291},
#   'id': 3899695,
#   'name': 'Ancud',
#   'cod': 200},
#  {'coord': {'lon': 117.06, 'lat': 7.99},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 84.3,
#    'pressure': 1008.781,
#    'humidity': 75,
#    'temp_min': 84.3,
#    'temp_max': 84.3,
#    'sea_level': 1008.781,
#    'grnd_level': 1008.022},
#   'wind': {'speed': 10.92, 'deg': 64.17},
#   'clouds': {'all': 71},
#   'dt': 1555697948,
#   'sys': {'message': 0.0062,
#    'country': 'PH',
#    'sunrise': 1555711245,
#    'sunset': 1555755628},
#   'id': 1728675,
#   'name': 'Balabac',
#   'cod': 200},
#  {'coord': {'lon': 112.75, 'lat': 59.63},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 23.1,
#    'pressure': 1000.831,
#    'humidity': 91,
#    'temp_min': 23.1,
#    'temp_max': 23.1,
#    'sea_level': 1000.831,
#    'grnd_level': 950.358},
#   'wind': {'speed': 9.55, 'deg': 219.351},
#   'clouds': {'all': 36},
#   'dt': 1555697948,
#   'sys': {'message': 0.0045,
#    'country': 'RU',
#    'sunrise': 1555707649,
#    'sunset': 1555761292},
#   'id': 2018069,
#   'name': 'Peleduy',
#   'cod': 200},
#  {'coord': {'lon': 128.74, 'lat': -15.77},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'pressure': 1010,
#    'humidity': 88,
#    'temp_min': 73.4,
#    'temp_max': 73.4},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 360},
#   'clouds': {'all': 12},
#   'dt': 1555695000,
#   'sys': {'type': 1,
#    'id': 9587,
#    'message': 0.005,
#    'country': 'AU',
#    'sunrise': 1555709599,
#    'sunset': 1555751669},
#   'id': 2068110,
#   'name': 'Kununurra',
#   'cod': 200},
#  {'coord': {'lon': -161.76, 'lat': 60.79},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 21.25,
#    'pressure': 1006,
#    'humidity': 85,
#    'temp_min': 17.6,
#    'temp_max': 24.8},
#   'visibility': 16093,
#   'wind': {'speed': 4.7, 'deg': 290},
#   'clouds': {'all': 40},
#   'dt': 1555692960,
#   'sys': {'type': 1,
#    'id': 7640,
#    'message': 0.005,
#    'country': 'US',
#    'sunrise': 1555686915,
#    'sunset': 1555740997},
#   'id': 5880568,
#   'name': 'Bethel',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 113.61, 'lat': -8.35},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 81.96,
#    'pressure': 1010.273,
#    'humidity': 79,
#    'temp_min': 81.96,
#    'temp_max': 81.96,
#    'sea_level': 1010.273,
#    'grnd_level': 1009.67},
#   'wind': {'speed': 9.28, 'deg': 79.516},
#   'rain': {'3h': 0.75},
#   'clouds': {'all': 55},
#   'dt': 1555697951,
#   'sys': {'message': 0.0045,
#    'country': 'ID',
#    'sunrise': 1555712863,
#    'sunset': 1555755666},
#   'id': 1621313,
#   'name': 'Ambulu',
#   'cod': 200},
#  {'coord': {'lon': -73.48, 'lat': 45.36},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'},
#    {'id': 300,
#     'main': 'Drizzle',
#     'description': 'light intensity drizzle',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 46.31,
#    'pressure': 1005,
#    'humidity': 93,
#    'temp_min': 43,
#    'temp_max': 53.01},
#   'visibility': 9656,
#   'wind': {'speed': 14.99, 'deg': 40, 'gust': 9.8},
#   'rain': {'1h': 1.52},
#   'clouds': {'all': 90},
#   'dt': 1555697920,
#   'sys': {'type': 1,
#    'id': 820,
#    'message': 0.0058,
#    'country': 'CA',
#    'sunrise': 1555668114,
#    'sunset': 1555717430},
#   'id': 6138908,
#   'name': 'Saint-Philippe',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 51.4,
#    'pressure': 1007,
#    'humidity': 66,
#    'temp_min': 51.01,
#    'temp_max': 51.8},
#   'visibility': 10000,
#   'wind': {'speed': 28.86, 'deg': 230, 'gust': 19.5},
#   'clouds': {'all': 20},
#   'dt': 1555696386,
#   'sys': {'type': 1,
#    'id': 8487,
#    'message': 0.0049,
#    'country': 'CL',
#    'sunrise': 1555673864,
#    'sunset': 1555710446},
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 135.31, 'lat': 54.72},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 13.38,
#    'pressure': 1014.875,
#    'humidity': 86,
#    'temp_min': 13.38,
#    'temp_max': 13.38,
#    'sea_level': 1014.875,
#    'grnd_level': 949.83},
#   'wind': {'speed': 7.38, 'deg': 326.069},
#   'clouds': {'all': 17},
#   'dt': 1555697951,
#   'sys': {'message': 0.0042,
#    'country': 'RU',
#    'sunrise': 1555703155,
#    'sunset': 1555754960},
#   'id': 2025256,
#   'name': 'Chumikan',
#   'cod': 200},
#  {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 65.58,
#    'pressure': 1017.847,
#    'humidity': 88,
#    'temp_min': 65.58,
#    'temp_max': 65.58,
#    'sea_level': 1017.847,
#    'grnd_level': 992.646},
#   'wind': {'speed': 11.65, 'deg': 133.017},
#   'clouds': {'all': 0},
#   'dt': 1555697375,
#   'sys': {'message': 0.0046,
#    'country': 'AU',
#    'sunrise': 1555705131,
#    'sunset': 1555746379},
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 17.16, 'lat': -26.5},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 74.22,
#    'pressure': 1015.581,
#    'humidity': 11,
#    'temp_min': 74.22,
#    'temp_max': 74.22,
#    'sea_level': 1015.581,
#    'grnd_level': 887.382},
#   'wind': {'speed': 11.61, 'deg': 260.973},
#   'clouds': {'all': 94},
#   'dt': 1555697952,
#   'sys': {'message': 0.0037,
#    'country': 'NA',
#    'sunrise': 1555650536,
#    'sunset': 1555691507},
#   'id': 3358416,
#   'name': 'Bethanien',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 83.58,
#    'pressure': 1012.153,
#    'humidity': 72,
#    'temp_min': 83.58,
#    'temp_max': 83.58,
#    'sea_level': 1012.153,
#    'grnd_level': 1012.054},
#   'wind': {'speed': 10.16, 'deg': 99.442},
#   'clouds': {'all': 33},
#   'dt': 1555697382,
#   'sys': {'message': 0.0057,
#    'country': 'PF',
#    'sunrise': 1555687166,
#    'sunset': 1555729837},
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': -114.38, 'lat': 62.45},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 28.2,
#    'pressure': 1000,
#    'humidity': 79,
#    'temp_min': 28,
#    'temp_max': 28.4},
#   'visibility': 24140,
#   'wind': {'speed': 10.29, 'deg': 30},
#   'clouds': {'all': 90},
#   'dt': 1555696364,
#   'sys': {'type': 1,
#    'id': 1007,
#    'message': 0.0049,
#    'country': 'CA',
#    'sunrise': 1555675162,
#    'sunset': 1555730011},
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': -16.33, 'lat': 33.08},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 63.64,
#    'pressure': 1021,
#    'humidity': 59,
#    'temp_min': 62.6,
#    'temp_max': 64.4},
#   'visibility': 10000,
#   'wind': {'speed': 17.22, 'deg': 360},
#   'clouds': {'all': 40},
#   'dt': 1555695000,
#   'sys': {'type': 1,
#    'id': 6902,
#    'message': 0.0046,
#    'country': 'PT',
#    'sunrise': 1555655453,
#    'sunset': 1555702664},
#   'id': 2270385,
#   'name': 'Camacha',
#   'cod': 200},
#  {'coord': {'lon': 31.13, 'lat': -25.95},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 70.3,
#    'pressure': 1024,
#    'humidity': 82,
#    'temp_min': 68,
#    'temp_max': 72},
#   'wind': {'speed': 5.82, 'deg': 80},
#   'rain': {'3h': 0.812},
#   'clouds': {'all': 3},
#   'dt': 1555697784,
#   'sys': {'type': 1,
#    'id': 1937,
#    'message': 0.006,
#    'country': 'SZ',
#    'sunrise': 1555647151,
#    'sunset': 1555688188},
#   'id': 935111,
#   'name': 'Bulembu',
#   'cod': 200},
#  {'coord': {'lon': -71.14, 'lat': 21.46},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.9,
#    'pressure': 1017.027,
# ...
#    'sunrise': 1555636582,
#    'sunset': 1555685194},
#   'id': 601551,
#   'name': 'Akdepe',
#   'cod': 200},
#  {'coord': {'lon': 36.54, 'lat': -14.8},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 71.16,
#    'pressure': 1017.533,
#    'humidity': 81,
#    'temp_min': 71.16,
#    'temp_max': 71.16,
#    'sea_level': 1017.533,
#    'grnd_level': 942.422},
#   'wind': {'speed': 8.28, 'deg': 168.614},
#   'clouds': {'all': 12},
#   'dt': 1555698056,
#   'sys': {'message': 0.0043,
#    'country': 'MZ',
#    'sunrise': 1555645270,
#    'sunset': 1555687472},
#   'id': 1047660,
#   'name': 'Cuamba',
#   'cod': 200},
#  {'coord': {'lon': -71.03, 'lat': 46.45},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'},
#    {'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 46.08,
#    'pressure': 1006,
#    'humidity': 100,
#    'temp_min': 44.01,
#    'temp_max': 48},
#   'visibility': 14484,
#   'wind': {'speed': 2.24, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1555697772,
#   'sys': {'type': 1,
#    'id': 879,
#    'message': 0.0064,
#    'country': 'CA',
#    'sunrise': 1555667412,
#    'sunset': 1555716957},
#   'id': 6945989,
#   'name': 'Sainte-Marie',
#   'cod': 200},
#  {'coord': {'lon': 25.93, 'lat': 39.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 55.4,
#    'pressure': 1021,
#    'humidity': 50,
#    'temp_min': 55.4,
#    'temp_max': 55.4},
#   'visibility': 10000,
#   'wind': {'speed': 6.98, 'deg': 308.157},
#   'clouds': {'all': 0},
#   'dt': 1555696200,
#   'sys': {'type': 1,
#    'id': 6636,
#    'message': 0.0041,
#    'country': 'GR',
#    'sunrise': 1555644854,
#    'sunset': 1555692980},
#   'id': 262629,
#   'name': 'Eresos',
#   'cod': 200},
#  {'coord': {'lon': -124.22, 'lat': 43.41},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 55,
#    'pressure': 1018,
#    'humidity': 93,
#    'temp_min': 53.6,
#    'temp_max': 55.99},
#   'visibility': 12874,
#   'wind': {'speed': 6.93, 'deg': 330},
#   'clouds': {'all': 90},
#   'dt': 1555698028,
#   'sys': {'type': 1,
#    'id': 5239,
#    'message': 0.0069,
#    'country': 'US',
#    'sunrise': 1555680473,
#    'sunset': 1555729423},
#   'id': 5742974,
#   'name': 'North Bend',
#   'cod': 200},
#  {'coord': {'lon': 69.15, 'lat': 29.03},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 78.54,
#    'pressure': 1008.829,
#    'humidity': 32,
#    'temp_min': 78.54,
#    'temp_max': 78.54,
#    'sea_level': 1008.829,
#    'grnd_level': 941.19},
#   'wind': {'speed': 1.23, 'deg': 294.228},
#   'clouds': {'all': 0},
#   'dt': 1555698058,
#   'sys': {'message': 0.0041,
#    'country': 'PK',
#    'sunrise': 1555635225,
#    'sunset': 1555681867},
#   'id': 1180295,
#   'name': 'Dera Bugti',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 74.5, 'lat': 63.79},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 21.3,
#    'pressure': 1010.121,
#    'humidity': 95,
#    'temp_min': 21.3,
#    'temp_max': 21.3,
#    'sea_level': 1010.121,
#    'grnd_level': 996.326},
#   'wind': {'speed': 13.15, 'deg': 323.607},
#   'clouds': {'all': 98},
#   'dt': 1555698058,
#   'sys': {'message': 0.006,
#    'country': 'RU',
#    'sunrise': 1555629574,
#    'sunset': 1555684951},
#   'id': 1540711,
#   'name': 'Muravlenko',
#   'cod': 200},
#  {'coord': {'lon': -8.4, 'lat': 51.89},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 58.48,
#    'pressure': 1029,
#    'humidity': 77,
#    'temp_min': 57.99,
#    'temp_max': 59},
#   'visibility': 6000,
#   'wind': {'speed': 6.93, 'deg': 120},
#   'clouds': {'all': 75},
#   'dt': 1555697556,
#   'sys': {'type': 1,
#    'id': 1563,
#    'message': 0.0058,
#    'country': 'IE',
#    'sunrise': 1555651743,
#    'sunset': 1555702567},
#   'id': 2965139,
#   'name': 'Mahon',
#   'cod': 200},
#  {'coord': {'lon': 15.49, 'lat': 60.45},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 57.72,
#    'pressure': 1035,
#    'humidity': 29,
#    'temp_min': 54,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 1.12, 'deg': 140},
#   'clouds': {'all': 92},
#   'dt': 1555697793,
#   'sys': {'type': 1,
#    'id': 1789,
#    'message': 0.0048,
#    'country': 'SE',
#    'sunrise': 1555644540,
#    'sunset': 1555698305},
#   'id': 2720382,
#   'name': 'Hede',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 22.43, 'lat': 39.42},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 56.79,
#    'pressure': 1022,
#    'humidity': 76,
#    'temp_min': 53.6,
#    'temp_max': 61},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 223.305},
#   'clouds': {'all': 20},
#   'dt': 1555697599,
#   'sys': {'type': 1,
#    'id': 6629,
#    'message': 0.0045,
#    'country': 'GR',
#    'sunrise': 1555645672,
#    'sunset': 1555693842},
#   'id': 262462,
#   'name': 'Chara',
#   'cod': 200},
#  {'coord': {'lon': 20.77, 'lat': 47.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.78,
#    'pressure': 1027,
#    'humidity': 20,
#    'temp_min': 59,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 30},
#   'clouds': {'all': 0},
#   'dt': 1555695900,
#   'sys': {'type': 1,
#    'id': 6665,
#    'message': 0.0052,
#    'country': 'HU',
#    'sunrise': 1555645279,
#    'sunset': 1555695032},
#   'id': 714772,
#   'name': 'Tiszafured',
#   'cod': 200},
#  {'coord': {'lon': -5.74, 'lat': 40.39},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 52.27,
#    'pressure': 1018,
#    'humidity': 71,
#    'temp_min': 51.01,
#    'temp_max': 53.6},
#   'visibility': 10000,
#   'wind': {'speed': 19.46, 'deg': 80},
#   'clouds': {'all': 40},
#   'dt': 1555697922,
#   'sys': {'type': 1,
#    'id': 6430,
#    'message': 0.0051,
#    'country': 'ES',
#    'sunrise': 1555652344,
#    'sunset': 1555700690},
#   'id': 3128382,
#   'name': 'Palomares',
#   'cod': 200},
#  {'coord': {'lon': -102.62, 'lat': 38.09},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 63.61,
#    'pressure': 1021,
#    'humidity': 25,
#    'temp_min': 63,
#    'temp_max': 64.4},
#   'visibility': 16093,
#   'wind': {'speed': 6.93, 'deg': 290, 'gust': 7.7},
#   'clouds': {'all': 1},
#   'dt': 1555697798,
#   'sys': {'type': 1,
#    'id': 4652,
#    'message': 0.0044,
#    'country': 'US',
#    'sunrise': 1555675765,
#    'sunset': 1555723764},
#   'id': 5427957,
#   'name': 'Lamar',
#   'cod': 200},
#  {'coord': {'lon': -68.2, 'lat': 10.49},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 87.9,
#    'pressure': 1012.159,
#    'humidity': 57,
#    'temp_min': 87.9,
#    'temp_max': 87.9,
#    'sea_level': 1012.159,
#    'grnd_level': 1005.974},
#   'wind': {'speed': 7.09, 'deg': 59.796},
#   'rain': {'3h': 1.25},
#   'clouds': {'all': 95},
#   'dt': 1555698059,
#   'sys': {'message': 0.0041,
#    'country': 'VE',
#    'sunrise': 1555669197,
#    'sunset': 1555713813},
#   'id': 3631878,
#   'name': 'Moron',
#   'cod': 200},
#  {'coord': {'lon': 135.99, 'lat': 33.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 42.36,
#    'pressure': 1015.721,
#    'humidity': 84,
#    'temp_min': 42.36,
#    'temp_max': 42.36,
#    'sea_level': 1015.721,
#    'grnd_level': 939.238},
#   'wind': {'speed': 4.92, 'deg': 25.575},
#   'clouds': {'all': 0},
#   'dt': 1555698059,
#   'sys': {'message': 0.0041,
#    'country': 'JP',
#    'sunrise': 1555705209,
#    'sunset': 1555752579},
#   'id': 1847947,
#   'name': 'Shingu',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 120.58, 'lat': 18.47},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 81.78,
#    'pressure': 1009.847,
#    'humidity': 80,
#    'temp_min': 81.78,
#    'temp_max': 81.78,
#    'sea_level': 1009.847,
#    'grnd_level': 1005.91},
#   'wind': {'speed': 2.01, 'deg': 101.872},
#   'clouds': {'all': 0},
#   'dt': 1555698059,
#   'sys': {'message': 0.0042,
#    'country': 'PH',
#    'sunrise': 1555709858,
#    'sunset': 1555755326},
#   'id': 1715335,
#   'name': 'Davila',
#   'cod': 200},
#  {'coord': {'lon': 33.94, 'lat': 47.18},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 46.32,
#    'pressure': 1025.349,
#    'humidity': 51,
#    'temp_min': 46.32,
#    'temp_max': 46.32,
#    'sea_level': 1025.349,
#    'grnd_level': 1017.19},
#   'wind': {'speed': 7.63, 'deg': 57.033},
#   'clouds': {'all': 100},
#   'dt': 1555698059,
#   'sys': {'message': 0.0044,
#    'country': 'UA',
#    'sunrise': 1555642171,
#    'sunset': 1555691819},
#   'id': 690247,
#   'name': 'Velyka Lepetykha',
#   'cod': 200},
#  {'coord': {'lon': 116.58, 'lat': 35.41},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 51,
#    'pressure': 1014.057,
#    'humidity': 38,
#    'temp_min': 51,
#    'temp_max': 51,
#    'sea_level': 1014.057,
#    'grnd_level': 1010.742},
#   'wind': {'speed': 3.11, 'deg': 160.72},
#   'clouds': {'all': 29},
#   'dt': 1555698059,
#   'sys': {'message': 0.0052,
#    'country': 'CN',
#    'sunrise': 1555709738,
#    'sunset': 1555757366},
#   'id': 1805518,
#   'name': 'Jining',
#   'cod': 200},
#  {'coord': {'lon': 117.25, 'lat': 3.82},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 73.86,
#    'pressure': 1010.197,
#    'humidity': 99,
#    'temp_min': 73.86,
#    'temp_max': 73.86,
#    'sea_level': 1010.197,
#    'grnd_level': 999.926},
#   'wind': {'speed': 1.95, 'deg': 303.965},
#   'rain': {'3h': 3.563},
#   'clouds': {'all': 91},
#   'dt': 1555698060,
#   'sys': {'message': 0.0057,
#    'country': 'ID',
#    'sunrise': 1555711404,
#    'sunset': 1555755378},
#   'id': 1627877,
#   'name': 'Sembakung',
#   'cod': 200},
#  {'coord': {'lon': 64.41, 'lat': 28.9},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 81.24,
#    'pressure': 1008.923,
#    'humidity': 17,
#    'temp_min': 81.24,
#    'temp_max': 81.24,
#    'sea_level': 1008.923,
#    'grnd_level': 900.086},
#   'wind': {'speed': 3.22, 'deg': 89.403},
#   'clouds': {'all': 0},
#   'dt': 1555698060,
#   'sys': {'message': 0.0044,
#    'country': 'PK',
#    'sunrise': 1555636370,
#    'sunset': 1555682997},
#   'id': 1180729,
#   'name': 'Dalbandin',
#   'cod': 200},
#  {'coord': {'lon': 49.05, 'lat': -13.19},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 75.12,
#    'pressure': 1013.155,
#    'humidity': 90,
#    'temp_min': 75.12,
#    'temp_max': 75.12,
#    'sea_level': 1013.155,
#    'grnd_level': 1001.99},
#   'wind': {'speed': 7.34, 'deg': 91.484},
#   'clouds': {'all': 83},
#   'dt': 1555698060,
#   'sys': {'message': 0.0046,
#    'country': 'MG',
#    'sunrise': 1555642189,
#    'sunset': 1555684550},
#   'id': 1082243,
#   'name': 'Ambilobe',
#   'cod': 200},
#  {'coord': {'lon': 112.22, 'lat': -8.13},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 75.3,
#    'pressure': 1010.315,
#    'humidity': 94,
#    'temp_min': 75.3,
#    'temp_max': 75.3,
#    'sea_level': 1010.315,
#    'grnd_level': 996.038},
#   'wind': {'speed': 2.71, 'deg': 196.858},
#   'clouds': {'all': 69},
#   'dt': 1555698060,
#   'sys': {'message': 0.0045,
#    'country': 'ID',
#    'sunrise': 1555713186,
#    'sunset': 1555756010},
#   'id': 1641497,
#   'name': 'Kanigoro',
#   'cod': 200},
#  {'coord': {'lon': -66.38, 'lat': 50.2},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 40.78,
#    'pressure': 1004,
#    'humidity': 86,
#    'temp_min': 39.2,
#    'temp_max': 42.01},
#   'visibility': 48279,
#   'wind': {'speed': 8.05, 'deg': 260},
#   'rain': {'1h': 2.03},
#   'clouds': {'all': 75},
#   'dt': 1555697901,
#   'sys': {'type': 1,
#    'id': 1013,
#    'message': 0.0048,
#    'country': 'CA',
#    'sunrise': 1555665860,
#    'sunset': 1555716277},
#   'id': 6144312,
#   'name': 'Sept-Iles',
#   'cod': 200},
#  {'coord': {'lon': -80.74, 'lat': 39.92},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 64.54,
#    'pressure': 1001,
#    'humidity': 77,
#    'temp_min': 62.01,
#    'temp_max': 66.99},
#   'visibility': 14484,
#   'wind': {'speed': 10.29, 'deg': 160, 'gust': 8.7},
#   'rain': {'1h': 0.64},
#   'clouds': {'all': 90},
#   'dt': 1555697988,
#   'sys': {'type': 1,
#    'id': 4384,
#    'message': 0.0058,
#    'country': 'US',
#    'sunrise': 1555670366,
#    'sunset': 1555718662},
#   'id': 4815462,
#   'name': 'Moundsville',
#   'cod': 200},
#  {'coord': {'lon': 138.93, 'lat': 34.7},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 56.8,
#    'pressure': 1011,
#    'humidity': 85,
#    'temp_min': 52,
#    'temp_max': 61},
#   'wind': {'speed': 7.63, 'deg': 105.911},
#   'clouds': {'all': 48},
#   'dt': 1555698031,
#   'sys': {'type': 3,
#    'id': 2018188,
#    'message': 0.0048,
#    'country': 'JP',
#    'sunrise': 1555704432,
#    'sunset': 1555751945},
#   'id': 1852357,
#   'name': 'Shimoda',
#   'cod': 200},
#  {'coord': {'lon': 110.28, 'lat': -7.95},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 83.4,
#    'pressure': 1010.575,
#    'humidity': 80,
#    'temp_min': 83.4,
#    'temp_max': 83.4,
#    'sea_level': 1010.575,
#    'grnd_level': 1009.862},
#   'wind': {'speed': 14.92, 'deg': 111.682},
#   'rain': {'3h': 3.124},
#   'clouds': {'all': 100},
#   'dt': 1555698061,
#   'sys': {'message': 0.0039,
#    'country': 'ID',
#    'sunrise': 1555713643,
#    'sunset': 1555756484},
#   'id': 1650434,
#   'name': 'Bambanglipuro',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 46.32, 'lat': -15.72},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1011,
#    'humidity': 88,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 4.05, 'deg': 240.314},
#   'clouds': {'all': 20},
#   'dt': 1555696800,
#   'sys': {'type': 1,
#    'id': 2143,
#    'message': 0.0042,
#    'country': 'MG',
#    'sunrise': 1555642968,
#    'sunset': 1555685081},
#   'id': 1062663,
#   'name': 'Mahajanga',
#   'cod': 200},
#  {'coord': {'lon': -70.1, 'lat': 41.28},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 63.82,
#    'pressure': 1012,
#    'humidity': 77,
#    'temp_min': 59,
#    'temp_max': 72},
#   'visibility': 8047,
#   'wind': {'speed': 18.34, 'deg': 230, 'gust': 11.8},
#   'clouds': {'all': 90},
#   'dt': 1555697859,
#   'sys': {'type': 1,
#    'id': 4454,
#    'message': 0.006,
#    'country': 'US',
#    'sunrise': 1555667696,
#    'sunset': 1555716226},
#   'id': 4944903,
#   'name': 'Nantucket',
#   'cod': 200}]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(len(city_list))
print(len(cloudiness))
print(len(country))
print(len(date))
print(len(humidity))
print(len(lat))
print(len(lng))
print(len(max_temp))
print(len(wind_speed))
# Out:
# 680
# 680
# 680
# 680
# 680
# 680
# 680
# 680
# 680

# %%
weather_dict = {
    "City": city_list,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Hervey Bay          75      AU  1555697108        94 -25.30  152.85
# 1         Sur           0      OM  1555697937        35  22.57   59.53
# 2       Arman         100      RU  1555697937        98  59.70  150.17
# 3        Puno          75      PE  1555693200        47 -15.84  -70.03
# 4       Pevek         100      RU  1555697937        92  69.70  170.27
#
#    Max Temp  Wind Speed
# 0     71.01        8.05
# 1     86.10        7.72
# 2     26.16        4.97
# 3     59.00        1.12
# 4     10.32       14.34

# %%
outfile = "cities.csv"
outdir = '../output_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outfile)    

weather_data.to_csv(fullname, index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({strformat})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Lat_vs_temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({strformat})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/lat_vs_humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({strformat})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/lat_vs_cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({now})")
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/lat_vs_wind.png")

# Show plot
plt.show()
