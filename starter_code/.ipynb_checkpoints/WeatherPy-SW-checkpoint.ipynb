# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The weather is warmer around the equator. I thought it was slightly interesting that the cities on my list with the highest temp were all around latitude 10.
# * There does not appear to be a strong relationship between latitude and humidity.
# * There does not appear to be a strong relationship between latitude and wind speed. My dataset did contain one city with a wind speed above 40 mph.
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
import os

now = dt.datetime.today()
strformat = now.strftime("%Y-%m-%d")

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
#lat_range = (-90, 90)
#lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 780

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-----------------------------")

weather_response_json = []

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
city_list = []
counter = 1

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&q="


# div = 50
# lim = len(cities) // div
# samples = [cities[(i * div):(i * div + div)] for i in range(0, lim)]
#print(samples.index('citygroup'))
#for citygroup in samples:
#    print((samples.index(citygroup)))
#for city in range(len(cities))
# for citygroup in samples:


sets = 1
for index, city in enumerate(cities):

    #print(f"Processing Record {counter} in {samples.index(citygroup)} | {city}")
    
    print(f"Processing Record {index+1} in  set {sets} | {city}")
    query_url = f"{url}appid={api_key}&units={units}&q={city}"
    response = requests.get(query_url)
    weather_response = response.json()
    weather_response_json.append(weather_response)
    #counter = counter + 1
    if ((index+1) % 50) == 0:
        #time.sleep(3)
        sets = sets + 1
        #counter = 1

    try:
        city_list.append(weather_response['name'])
        cloudiness.append(weather_response['clouds']['all'])
        country.append(weather_response['sys']['country'])
        date.append(weather_response['dt'])
        humidity.append(weather_response['main']['humidity'])
        lat.append(weather_response['coord']['lat'])
        lng.append(weather_response['coord']['lon'])
        max_temp.append(weather_response['main']['temp_max'])
        wind_speed.append(weather_response['wind']['speed'])
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 in  set 1 | liniere
# Missing field/result... skipping.
# Processing Record 2 in  set 1 | leningradskiy
# Processing Record 3 in  set 1 | bredasdorp
# Processing Record 4 in  set 1 | puerto ayora
# Processing Record 5 in  set 1 | ayan
# Processing Record 6 in  set 1 | saint george
# Processing Record 7 in  set 1 | rensvik
# Processing Record 8 in  set 1 | ushuaia
# Processing Record 9 in  set 1 | hilo
# Processing Record 10 in  set 1 | xiongshi
# Missing field/result... skipping.
# Processing Record 11 in  set 1 | luderitz
# Processing Record 12 in  set 1 | la ronge
# Processing Record 13 in  set 1 | taolanaro
# Missing field/result... skipping.
# Processing Record 14 in  set 1 | gizo
# Processing Record 15 in  set 1 | lubao
# Processing Record 16 in  set 1 | bengkulu
# Missing field/result... skipping.
# Processing Record 17 in  set 1 | hermanus
# Processing Record 18 in  set 1 | yeppoon
# Processing Record 19 in  set 1 | rikitea
# Processing Record 20 in  set 1 | torbay
# Processing Record 21 in  set 1 | pevek
# Processing Record 22 in  set 1 | finnsnes
# Processing Record 23 in  set 1 | padang
# Processing Record 24 in  set 1 | hobart
# Processing Record 25 in  set 1 | butaritari
# Processing Record 26 in  set 1 | poim
# Processing Record 27 in  set 1 | avarua
# Processing Record 28 in  set 1 | bluff
# Processing Record 29 in  set 1 | geraldton
# Processing Record 30 in  set 1 | najran
# Processing Record 31 in  set 1 | mazagao
# Processing Record 32 in  set 1 | albany
# Processing Record 33 in  set 1 | dikson
# Processing Record 34 in  set 1 | cherskiy
# Processing Record 35 in  set 1 | mataura
# Processing Record 36 in  set 1 | severo-kurilsk
# Processing Record 37 in  set 1 | ancud
# Processing Record 38 in  set 1 | impfondo
# Processing Record 39 in  set 1 | olyka
# Processing Record 40 in  set 1 | coihaique
# Processing Record 41 in  set 1 | lembeni
# Processing Record 42 in  set 1 | charters towers
# Processing Record 43 in  set 1 | ilulissat
# Processing Record 44 in  set 1 | lompoc
# Processing Record 45 in  set 1 | punta arenas
# Processing Record 46 in  set 1 | manggar
# Processing Record 47 in  set 1 | moroto
# Processing Record 48 in  set 1 | clyde river
# Processing Record 49 in  set 1 | mahebourg
# Processing Record 50 in  set 1 | port hedland
# Processing Record 51 in  set 2 | sentyabrskiy
# Missing field/result... skipping.
# Processing Record 52 in  set 2 | carnarvon
# Processing Record 53 in  set 2 | castro
# Processing Record 54 in  set 2 | westport
# Processing Record 55 in  set 2 | anzhero-sudzhensk
# Processing Record 56 in  set 2 | kapaa
# Processing Record 57 in  set 2 | aswan
# Processing Record 58 in  set 2 | tasiilaq
# Processing Record 59 in  set 2 | busselton
# Processing Record 60 in  set 2 | yellowknife
# Processing Record 61 in  set 2 | juba
# Processing Record 62 in  set 2 | chuy
# Processing Record 63 in  set 2 | boca do acre
# Processing Record 64 in  set 2 | yermakovskoye
# Processing Record 65 in  set 2 | mys shmidta
# Missing field/result... skipping.
# Processing Record 66 in  set 2 | thompson
# Processing Record 67 in  set 2 | mar del plata
# Processing Record 68 in  set 2 | west bay
# Processing Record 69 in  set 2 | laguna
# Processing Record 70 in  set 2 | sao filipe
# Processing Record 71 in  set 2 | vestmannaeyjar
# Processing Record 72 in  set 2 | sulangan
# Processing Record 73 in  set 2 | illoqqortoormiut
# Missing field/result... skipping.
# Processing Record 74 in  set 2 | tiksi
# Processing Record 75 in  set 2 | nguiu
# Missing field/result... skipping.
# Processing Record 76 in  set 2 | marawi
# Processing Record 77 in  set 2 | rafraf
# Processing Record 78 in  set 2 | ribeira grande
# Processing Record 79 in  set 2 | hithadhoo
# Processing Record 80 in  set 2 | nikolskoye
# Processing Record 81 in  set 2 | barrow
# Processing Record 82 in  set 2 | kaitangata
# Processing Record 83 in  set 2 | saint-augustin
# Processing Record 84 in  set 2 | korla
# Missing field/result... skipping.
# Processing Record 85 in  set 2 | nishihara
# Processing Record 86 in  set 2 | saint anthony
# Processing Record 87 in  set 2 | cape town
# Processing Record 88 in  set 2 | cockburn town
# Processing Record 89 in  set 2 | carbonia
# Processing Record 90 in  set 2 | jamestown
# Processing Record 91 in  set 2 | abalak
# Processing Record 92 in  set 2 | ayagoz
# Processing Record 93 in  set 2 | vaini
# Processing Record 94 in  set 2 | ambulu
# Processing Record 95 in  set 2 | umm lajj
# Processing Record 96 in  set 2 | tochio
# Processing Record 97 in  set 2 | skelleftea
# Processing Record 98 in  set 2 | beloyarskiy
# Processing Record 99 in  set 2 | new norfolk
# Processing Record 100 in  set 2 | broome
# Processing Record 101 in  set 3 | ponta do sol
# Processing Record 102 in  set 3 | nicoya
# Processing Record 103 in  set 3 | bambous virieux
# Processing Record 104 in  set 3 | georgetown
# Processing Record 105 in  set 3 | lorengau
# Processing Record 106 in  set 3 | kununurra
# Processing Record 107 in  set 3 | atuona
# Processing Record 108 in  set 3 | coracora
# Processing Record 109 in  set 3 | richards bay
# Processing Record 110 in  set 3 | narsaq
# Processing Record 111 in  set 3 | cidreira
# Processing Record 112 in  set 3 | bolshaya chernigovka
# Missing field/result... skipping.
# Processing Record 113 in  set 3 | luangwa
# Processing Record 114 in  set 3 | tamandare
# Processing Record 115 in  set 3 | souillac
# Processing Record 116 in  set 3 | barentsburg
# Missing field/result... skipping.
# Processing Record 117 in  set 3 | mnogovershinnyy
# Processing Record 118 in  set 3 | derzhavinsk
# Processing Record 119 in  set 3 | haines junction
# Processing Record 120 in  set 3 | baykit
# Processing Record 121 in  set 3 | juneau
# Processing Record 122 in  set 3 | twentynine palms
# Processing Record 123 in  set 3 | san buenaventura
# Processing Record 124 in  set 3 | port blair
# Processing Record 125 in  set 3 | okhotsk
# Processing Record 126 in  set 3 | presidencia roque saenz pena
# Processing Record 127 in  set 3 | dolores
# Processing Record 128 in  set 3 | jaciara
# Processing Record 129 in  set 3 | marsabit
# Processing Record 130 in  set 3 | yumen
# Processing Record 131 in  set 3 | erzin
# Processing Record 132 in  set 3 | bardiyah
# Missing field/result... skipping.
# Processing Record 133 in  set 3 | namatanai
# Processing Record 134 in  set 3 | yishui
# Processing Record 135 in  set 3 | airai
# Processing Record 136 in  set 3 | kibaya
# Processing Record 137 in  set 3 | provideniya
# Processing Record 138 in  set 3 | guerrero negro
# Processing Record 139 in  set 3 | esperance
# Processing Record 140 in  set 3 | lebu
# Processing Record 141 in  set 3 | salalah
# Processing Record 142 in  set 3 | wanning
# Processing Record 143 in  set 3 | east london
# Processing Record 144 in  set 3 | samusu
# Missing field/result... skipping.
# Processing Record 145 in  set 3 | kijaba
# Missing field/result... skipping.
# Processing Record 146 in  set 3 | laranjeiras do sul
# Processing Record 147 in  set 3 | ulaanbaatar
# Processing Record 148 in  set 3 | sinnamary
# Processing Record 149 in  set 3 | patnanungan
# Processing Record 150 in  set 3 | mahina
# Processing Record 151 in  set 4 | moses lake
# Processing Record 152 in  set 4 | pathein
# Processing Record 153 in  set 4 | port huron
# Processing Record 154 in  set 4 | zonguldak
# Processing Record 155 in  set 4 | pangody
# Processing Record 156 in  set 4 | yarmouth
# Processing Record 157 in  set 4 | komsomolskiy
# Processing Record 158 in  set 4 | tonj
# Missing field/result... skipping.
# Processing Record 159 in  set 4 | port lincoln
# Processing Record 160 in  set 4 | touros
# Processing Record 161 in  set 4 | belmonte
# Processing Record 162 in  set 4 | pangnirtung
# Processing Record 163 in  set 4 | balimo
# Missing field/result... skipping.
# Processing Record 164 in  set 4 | asau
# Missing field/result... skipping.
# Processing Record 165 in  set 4 | nanortalik
# Processing Record 166 in  set 4 | provost
# Processing Record 167 in  set 4 | valparaiso
# Processing Record 168 in  set 4 | raton
# Processing Record 169 in  set 4 | bethel
# Processing Record 170 in  set 4 | domoni
# Missing field/result... skipping.
# Processing Record 171 in  set 4 | yantal
# Processing Record 172 in  set 4 | tomatlan
# Processing Record 173 in  set 4 | vila franca do campo
# Processing Record 174 in  set 4 | port elizabeth
# Processing Record 175 in  set 4 | port alfred
# Processing Record 176 in  set 4 | noumea
# Processing Record 177 in  set 4 | marienburg
# Processing Record 178 in  set 4 | zhezkazgan
# Processing Record 179 in  set 4 | mawlaik
# Processing Record 180 in  set 4 | karkaralinsk
# Missing field/result... skipping.
# Processing Record 181 in  set 4 | bambanglipuro
# Processing Record 182 in  set 4 | shaowu
# Processing Record 183 in  set 4 | pisco
# Processing Record 184 in  set 4 | puerto ayacucho
# Processing Record 185 in  set 4 | mtwara
# Processing Record 186 in  set 4 | qaanaaq
# Processing Record 187 in  set 4 | vasai
# Processing Record 188 in  set 4 | kismayo
# Missing field/result... skipping.
# Processing Record 189 in  set 4 | beyla
# Processing Record 190 in  set 4 | pimentel
# Processing Record 191 in  set 4 | san patricio
# Processing Record 192 in  set 4 | zhigansk
# Processing Record 193 in  set 4 | gwadar
# Processing Record 194 in  set 4 | iqaluit
# Processing Record 195 in  set 4 | nauta
# Processing Record 196 in  set 4 | clarence town
# Processing Record 197 in  set 4 | vila velha
# Processing Record 198 in  set 4 | ambilobe
# Processing Record 199 in  set 4 | sechura
# Processing Record 200 in  set 4 | codrington
# Processing Record 201 in  set 5 | halalo
# Missing field/result... skipping.
# Processing Record 202 in  set 5 | evensk
# Processing Record 203 in  set 5 | adrar
# Processing Record 204 in  set 5 | acapulco
# Processing Record 205 in  set 5 | krasnyy chikoy
# Processing Record 206 in  set 5 | biak
# Processing Record 207 in  set 5 | ngama
# Missing field/result... skipping.
# Processing Record 208 in  set 5 | praia da vitoria
# Processing Record 209 in  set 5 | simplicio mendes
# Processing Record 210 in  set 5 | satitoa
# Missing field/result... skipping.
# Processing Record 211 in  set 5 | lavrentiya
# Processing Record 212 in  set 5 | naze
# Processing Record 213 in  set 5 | mudanya
# Processing Record 214 in  set 5 | aksu
# Processing Record 215 in  set 5 | sioux lookout
# Processing Record 216 in  set 5 | macapa
# Processing Record 217 in  set 5 | grand-lahou
# Processing Record 218 in  set 5 | alta floresta
# Processing Record 219 in  set 5 | hede
# Processing Record 220 in  set 5 | minsk
# Processing Record 221 in  set 5 | anadyr
# Processing Record 222 in  set 5 | ranapur
# Processing Record 223 in  set 5 | oksfjord
# Processing Record 224 in  set 5 | kodiak
# Processing Record 225 in  set 5 | necochea
# Processing Record 226 in  set 5 | zaraza
# Processing Record 227 in  set 5 | chokurdakh
# Processing Record 228 in  set 5 | lensk
# Processing Record 229 in  set 5 | namibe
# Processing Record 230 in  set 5 | beloha
# Processing Record 231 in  set 5 | faanui
# Processing Record 232 in  set 5 | kangaatsiaq
# Processing Record 233 in  set 5 | morondava
# Processing Record 234 in  set 5 | saskylakh
# Processing Record 235 in  set 5 | hualmay
# Processing Record 236 in  set 5 | klaksvik
# Processing Record 237 in  set 5 | bologoye
# Processing Record 238 in  set 5 | caravelas
# Processing Record 239 in  set 5 | lodja
# Processing Record 240 in  set 5 | coquimbo
# Processing Record 241 in  set 5 | mercedes
# Processing Record 242 in  set 5 | kut chap
# Processing Record 243 in  set 5 | nome
# Processing Record 244 in  set 5 | mgandu
# Processing Record 245 in  set 5 | temba
# Processing Record 246 in  set 5 | arraial do cabo
# Processing Record 247 in  set 5 | tabiauea
# Missing field/result... skipping.
# Processing Record 248 in  set 5 | bokoro
# Missing field/result... skipping.
# Processing Record 249 in  set 5 | khonuu
# Missing field/result... skipping.
# Processing Record 250 in  set 5 | biltine
# Processing Record 251 in  set 6 | antagan
# Missing field/result... skipping.
# Processing Record 252 in  set 6 | tuggurt
# Missing field/result... skipping.
# Processing Record 253 in  set 6 | lata
# Processing Record 254 in  set 6 | cayenne
# Processing Record 255 in  set 6 | denpasar
# Processing Record 256 in  set 6 | malinovoye ozero
# Processing Record 257 in  set 6 | bilma
# Processing Record 258 in  set 6 | daru
# Processing Record 259 in  set 6 | longyearbyen
# Processing Record 260 in  set 6 | khatanga
# Processing Record 261 in  set 6 | nizhneyansk
# Missing field/result... skipping.
# Processing Record 262 in  set 6 | kepno
# Processing Record 263 in  set 6 | blagoyevo
# Processing Record 264 in  set 6 | tabas
# Processing Record 265 in  set 6 | cam ranh
# Processing Record 266 in  set 6 | chapais
# Processing Record 267 in  set 6 | gombong
# Processing Record 268 in  set 6 | dobryanka
# Processing Record 269 in  set 6 | cabo san lucas
# Processing Record 270 in  set 6 | coyah
# Processing Record 271 in  set 6 | poronaysk
# Processing Record 272 in  set 6 | saleaula
# Missing field/result... skipping.
# Processing Record 273 in  set 6 | yamada
# Processing Record 274 in  set 6 | talnakh
# Processing Record 275 in  set 6 | tagusao
# Processing Record 276 in  set 6 | manicore
# Processing Record 277 in  set 6 | ambovombe
# Processing Record 278 in  set 6 | abu dhabi
# Processing Record 279 in  set 6 | sao joao da barra
# Processing Record 280 in  set 6 | horsham
# Processing Record 281 in  set 6 | cascais
# Processing Record 282 in  set 6 | sug-aksy
# Missing field/result... skipping.
# Processing Record 283 in  set 6 | san luis
# Processing Record 284 in  set 6 | araouane
# Processing Record 285 in  set 6 | saint-philippe
# Processing Record 286 in  set 6 | auki
# Processing Record 287 in  set 6 | puro
# Processing Record 288 in  set 6 | srbobran
# Processing Record 289 in  set 6 | aldan
# Processing Record 290 in  set 6 | chatham
# Processing Record 291 in  set 6 | hasaki
# Processing Record 292 in  set 6 | victoria
# Processing Record 293 in  set 6 | sunrise manor
# Processing Record 294 in  set 6 | hay river
# Processing Record 295 in  set 6 | mayumba
# Processing Record 296 in  set 6 | husavik
# Processing Record 297 in  set 6 | dicabisagan
# Processing Record 298 in  set 6 | le moule
# Processing Record 299 in  set 6 | kostino
# Processing Record 300 in  set 6 | los llanos de aridane
# Processing Record 301 in  set 7 | kavaratti
# Processing Record 302 in  set 7 | bilibino
# Processing Record 303 in  set 7 | sarangani
# Processing Record 304 in  set 7 | noshiro
# Processing Record 305 in  set 7 | belawan
# Processing Record 306 in  set 7 | la rioja
# Processing Record 307 in  set 7 | bereda
# Processing Record 308 in  set 7 | atar
# Processing Record 309 in  set 7 | kalmunai
# Processing Record 310 in  set 7 | barabai
# Processing Record 311 in  set 7 | douentza
# Processing Record 312 in  set 7 | tommot
# Processing Record 313 in  set 7 | attawapiskat
# Missing field/result... skipping.
# Processing Record 314 in  set 7 | bantou
# Processing Record 315 in  set 7 | shingu
# Processing Record 316 in  set 7 | mrirt
# Missing field/result... skipping.
# Processing Record 317 in  set 7 | wanaka
# Processing Record 318 in  set 7 | paragominas
# Processing Record 319 in  set 7 | darnah
# Processing Record 320 in  set 7 | yulara
# Processing Record 321 in  set 7 | almaty
# Processing Record 322 in  set 7 | sakakah
# Missing field/result... skipping.
# Processing Record 323 in  set 7 | willowmore
# Processing Record 324 in  set 7 | mackay
# Processing Record 325 in  set 7 | magadan
# Processing Record 326 in  set 7 | poum
# Processing Record 327 in  set 7 | bara
# Processing Record 328 in  set 7 | hire
# Missing field/result... skipping.
# Processing Record 329 in  set 7 | horizontina
# Processing Record 330 in  set 7 | san alberto
# Processing Record 331 in  set 7 | providencia
# Processing Record 332 in  set 7 | casablanca
# Processing Record 333 in  set 7 | plettenberg bay
# Processing Record 334 in  set 7 | faya
# Processing Record 335 in  set 7 | paamiut
# Processing Record 336 in  set 7 | broken hill
# Processing Record 337 in  set 7 | yangambi
# Processing Record 338 in  set 7 | iskateley
# Processing Record 339 in  set 7 | marquette
# Processing Record 340 in  set 7 | inverness
# Processing Record 341 in  set 7 | alugan
# Processing Record 342 in  set 7 | vao
# Processing Record 343 in  set 7 | odweyne
# Missing field/result... skipping.
# Processing Record 344 in  set 7 | tateyama
# Processing Record 345 in  set 7 | camopi
# Processing Record 346 in  set 7 | dongying
# Processing Record 347 in  set 7 | lyuban
# Processing Record 348 in  set 7 | vila do maio
# Processing Record 349 in  set 7 | meybod
# Processing Record 350 in  set 7 | ijaki
# Missing field/result... skipping.
# Processing Record 351 in  set 8 | miri
# Processing Record 352 in  set 8 | tifton
# Processing Record 353 in  set 8 | hammerfest
# Processing Record 354 in  set 8 | warmbad
# Processing Record 355 in  set 8 | lockhart
# Processing Record 356 in  set 8 | puquio
# Processing Record 357 in  set 8 | norwich
# Processing Record 358 in  set 8 | rungata
# Missing field/result... skipping.
# Processing Record 359 in  set 8 | egvekinot
# Processing Record 360 in  set 8 | sholapur
# Missing field/result... skipping.
# Processing Record 361 in  set 8 | tumannyy
# Missing field/result... skipping.
# Processing Record 362 in  set 8 | nantucket
# Processing Record 363 in  set 8 | manzhouli
# Processing Record 364 in  set 8 | sur
# Processing Record 365 in  set 8 | amderma
# Missing field/result... skipping.
# Processing Record 366 in  set 8 | omboue
# Processing Record 367 in  set 8 | tecpatan
# Processing Record 368 in  set 8 | jalu
# Processing Record 369 in  set 8 | tuy hoa
# Processing Record 370 in  set 8 | gunjur
# Processing Record 371 in  set 8 | kuche
# Missing field/result... skipping.
# Processing Record 372 in  set 8 | upernavik
# Processing Record 373 in  set 8 | sataua
# Missing field/result... skipping.
# Processing Record 374 in  set 8 | hambantota
# Processing Record 375 in  set 8 | maloshuyka
# Missing field/result... skipping.
# Processing Record 376 in  set 8 | garowe
# Processing Record 377 in  set 8 | tahta
# Missing field/result... skipping.
# Processing Record 378 in  set 8 | malpe
# Processing Record 379 in  set 8 | tefe
# Processing Record 380 in  set 8 | dublin
# Processing Record 381 in  set 8 | kahului
# Processing Record 382 in  set 8 | port hawkesbury
# Processing Record 383 in  set 8 | kamenskoye
# Missing field/result... skipping.
# Processing Record 384 in  set 8 | lar
# Processing Record 385 in  set 8 | puerto escondido
# Processing Record 386 in  set 8 | victoria point
# Processing Record 387 in  set 8 | lagos
# Processing Record 388 in  set 8 | tulle
# Processing Record 389 in  set 8 | samarai
# Processing Record 390 in  set 8 | matsanga
# Missing field/result... skipping.
# Processing Record 391 in  set 8 | planadas
# Processing Record 392 in  set 8 | santa isabel do rio negro
# Processing Record 393 in  set 8 | batsfjord
# Processing Record 394 in  set 8 | bathsheba
# Processing Record 395 in  set 8 | bargal
# Missing field/result... skipping.
# Processing Record 396 in  set 8 | hukuntsi
# Processing Record 397 in  set 8 | sayyan
# Processing Record 398 in  set 8 | saint-joseph
# Processing Record 399 in  set 8 | moranbah
# Processing Record 400 in  set 8 | tuatapere
# Processing Record 401 in  set 9 | eldikan
# Missing field/result... skipping.
# Processing Record 402 in  set 9 | udachnyy
# Processing Record 403 in  set 9 | olafsvik
# Missing field/result... skipping.
# Processing Record 404 in  set 9 | yaizu
# Processing Record 405 in  set 9 | nongpoh
# Processing Record 406 in  set 9 | phan rang
# Missing field/result... skipping.
# Processing Record 407 in  set 9 | uvalde
# Processing Record 408 in  set 9 | balancan
# Missing field/result... skipping.
# Processing Record 409 in  set 9 | sukhumi
# Missing field/result... skipping.
# Processing Record 410 in  set 9 | flinders
# Processing Record 411 in  set 9 | vanino
# Processing Record 412 in  set 9 | port macquarie
# Processing Record 413 in  set 9 | tiznit
# Processing Record 414 in  set 9 | champerico
# Processing Record 415 in  set 9 | kruisfontein
# Processing Record 416 in  set 9 | jining
# Processing Record 417 in  set 9 | ahipara
# Processing Record 418 in  set 9 | ngukurr
# Missing field/result... skipping.
# Processing Record 419 in  set 9 | benjamin constant
# Processing Record 420 in  set 9 | guiyang
# Processing Record 421 in  set 9 | seymchan
# Processing Record 422 in  set 9 | ilebo
# Processing Record 423 in  set 9 | vanavara
# Processing Record 424 in  set 9 | krasnoselkup
# Missing field/result... skipping.
# Processing Record 425 in  set 9 | tsihombe
# Missing field/result... skipping.
# Processing Record 426 in  set 9 | dapaong
# Processing Record 427 in  set 9 | jiaojiang
# Missing field/result... skipping.
# Processing Record 428 in  set 9 | novo aripuana
# Processing Record 429 in  set 9 | arrecife
# Missing field/result... skipping.
# Processing Record 430 in  set 9 | methoni
# Processing Record 431 in  set 9 | giyani
# Processing Record 432 in  set 9 | belushya guba
# Missing field/result... skipping.
# Processing Record 433 in  set 9 | kavieng
# Processing Record 434 in  set 9 | shepsi
# Processing Record 435 in  set 9 | guerande
# Processing Record 436 in  set 9 | tura
# Processing Record 437 in  set 9 | marsh harbour
# Processing Record 438 in  set 9 | ust-omchug
# Processing Record 439 in  set 9 | aksarka
# Processing Record 440 in  set 9 | oranjemund
# Processing Record 441 in  set 9 | camana
# Missing field/result... skipping.
# Processing Record 442 in  set 9 | yurimaguas
# Processing Record 443 in  set 9 | ambanja
# Processing Record 444 in  set 9 | havelock
# Processing Record 445 in  set 9 | doctor juan leon mallorquin
# Processing Record 446 in  set 9 | urengoy
# Processing Record 447 in  set 9 | aloleng
# Processing Record 448 in  set 9 | viedma
# Processing Record 449 in  set 9 | maragogi
# Processing Record 450 in  set 9 | bani
# Processing Record 451 in  set 10 | bhalki
# Processing Record 452 in  set 10 | college
# Processing Record 453 in  set 10 | amapa
# Processing Record 454 in  set 10 | fortuna
# Processing Record 455 in  set 10 | begowala
# Processing Record 456 in  set 10 | kupang
# Processing Record 457 in  set 10 | shagonar
# Processing Record 458 in  set 10 | chimbote
# Processing Record 459 in  set 10 | tieli
# Processing Record 460 in  set 10 | beihai
# Processing Record 461 in  set 10 | darab
# Processing Record 462 in  set 10 | ust-kuyga
# Processing Record 463 in  set 10 | roald
# Processing Record 464 in  set 10 | sibenik
# Processing Record 465 in  set 10 | gotsu
# Processing Record 466 in  set 10 | cancun
# Processing Record 467 in  set 10 | kazalinsk
# Missing field/result... skipping.
# Processing Record 468 in  set 10 | jackson
# Processing Record 469 in  set 10 | bonthe
# Processing Record 470 in  set 10 | katherine
# Processing Record 471 in  set 10 | alaca
# Processing Record 472 in  set 10 | axim
# Processing Record 473 in  set 10 | umzimvubu
# Missing field/result... skipping.
# Processing Record 474 in  set 10 | beringovskiy
# Processing Record 475 in  set 10 | kerema
# Processing Record 476 in  set 10 | lagoa
# Processing Record 477 in  set 10 | sandakan
# Processing Record 478 in  set 10 | huilong
# Processing Record 479 in  set 10 | port hardy
# Processing Record 480 in  set 10 | haibowan
# Missing field/result... skipping.
# Processing Record 481 in  set 10 | pemangkat
# Missing field/result... skipping.
# Processing Record 482 in  set 10 | alot
# Processing Record 483 in  set 10 | buala
# Processing Record 484 in  set 10 | taltal
# Processing Record 485 in  set 10 | deniliquin
# Processing Record 486 in  set 10 | rawson
# Processing Record 487 in  set 10 | satipo
# Processing Record 488 in  set 10 | soyo
# Processing Record 489 in  set 10 | toliary
# Missing field/result... skipping.
# Processing Record 490 in  set 10 | mathbaria
# Processing Record 491 in  set 10 | dunedin
# Processing Record 492 in  set 10 | trelew
# Processing Record 493 in  set 10 | rosarito
# Processing Record 494 in  set 10 | hami
# Processing Record 495 in  set 10 | erenhot
# Processing Record 496 in  set 10 | gagra
# Processing Record 497 in  set 10 | kyren
# Processing Record 498 in  set 10 | poya
# Processing Record 499 in  set 10 | abha
# Processing Record 500 in  set 10 | borgentreich
# Processing Record 501 in  set 11 | hamilton
# Processing Record 502 in  set 11 | rafaela
# Processing Record 503 in  set 11 | douglasville
# Processing Record 504 in  set 11 | lasa
# Processing Record 505 in  set 11 | suphan buri
# Processing Record 506 in  set 11 | sinop
# Processing Record 507 in  set 11 | ilhabela
# Processing Record 508 in  set 11 | wonji
# Missing field/result... skipping.
# Processing Record 509 in  set 11 | tuktoyaktuk
# Processing Record 510 in  set 11 | okandja
# Missing field/result... skipping.
# Processing Record 511 in  set 11 | santa vitoria do palmar
# Processing Record 512 in  set 11 | puchov
# Processing Record 513 in  set 11 | zemio
# Processing Record 514 in  set 11 | makakilo city
# Processing Record 515 in  set 11 | pelhrimov
# Processing Record 516 in  set 11 | dibaya
# Missing field/result... skipping.
# Processing Record 517 in  set 11 | koutiala
# Processing Record 518 in  set 11 | belaya gora
# Processing Record 519 in  set 11 | xingyi
# Processing Record 520 in  set 11 | cangzhou
# Processing Record 521 in  set 11 | alice springs
# Processing Record 522 in  set 11 | doha
# Processing Record 523 in  set 11 | shoranur
# Processing Record 524 in  set 11 | kudahuvadhoo
# Processing Record 525 in  set 11 | dauphin
# Processing Record 526 in  set 11 | santa rosa
# Processing Record 527 in  set 11 | maryville
# Processing Record 528 in  set 11 | raudeberg
# Processing Record 529 in  set 11 | makinsk
# Processing Record 530 in  set 11 | ipixuna
# Processing Record 531 in  set 11 | phangnga
# Processing Record 532 in  set 11 | natal
# Processing Record 533 in  set 11 | batemans bay
# Processing Record 534 in  set 11 | eyl
# Processing Record 535 in  set 11 | louisbourg
# Missing field/result... skipping.
# Processing Record 536 in  set 11 | tsentralnyy
# Missing field/result... skipping.
# Processing Record 537 in  set 11 | oyem
# Processing Record 538 in  set 11 | mount isa
# Processing Record 539 in  set 11 | maceio
# Processing Record 540 in  set 11 | rengo
# Processing Record 541 in  set 11 | bergen op zoom
# Processing Record 542 in  set 11 | tianpeng
# Processing Record 543 in  set 11 | te anau
# Processing Record 544 in  set 11 | matara
# Processing Record 545 in  set 11 | lanzhou
# Processing Record 546 in  set 11 | waingapu
# Processing Record 547 in  set 11 | saint-francois
# Processing Record 548 in  set 11 | alyangula
# Processing Record 549 in  set 11 | botwood
# Processing Record 550 in  set 11 | tlahualilo
# Missing field/result... skipping.
# Processing Record 551 in  set 12 | aflu
# Missing field/result... skipping.
# Processing Record 552 in  set 12 | kalisz
# Processing Record 553 in  set 12 | westlock
# Processing Record 554 in  set 12 | klyuchi
# Processing Record 555 in  set 12 | santa ana
# Processing Record 556 in  set 12 | sterlitamak
# Processing Record 557 in  set 12 | artsvaberd
# Processing Record 558 in  set 12 | grand river south east
# Missing field/result... skipping.
# Processing Record 559 in  set 12 | bur gabo
# Missing field/result... skipping.
# Processing Record 560 in  set 12 | kalabo
# Processing Record 561 in  set 12 | golspie
# Processing Record 562 in  set 12 | saldanha
# Processing Record 563 in  set 12 | henties bay
# Processing Record 564 in  set 12 | bulaevo
# Processing Record 565 in  set 12 | tavda
# Processing Record 566 in  set 12 | farafangana
# Processing Record 567 in  set 12 | xaxim
# Processing Record 568 in  set 12 | tessalit
# Processing Record 569 in  set 12 | escondido
# Processing Record 570 in  set 12 | sambava
# Processing Record 571 in  set 12 | srikakulam
# Processing Record 572 in  set 12 | kieta
# Processing Record 573 in  set 12 | delta
# Processing Record 574 in  set 12 | warrnambool
# Processing Record 575 in  set 12 | voh
# Processing Record 576 in  set 12 | ugoofaaru
# Processing Record 577 in  set 12 | alofi
# Processing Record 578 in  set 12 | qui nhon
# Missing field/result... skipping.
# Processing Record 579 in  set 12 | bafq
# Processing Record 580 in  set 12 | chara
# Processing Record 581 in  set 12 | ninghai
# Processing Record 582 in  set 12 | teloes
# Processing Record 583 in  set 12 | bairiki
# Missing field/result... skipping.
# Processing Record 584 in  set 12 | sorland
# Processing Record 585 in  set 12 | caucaia
# Processing Record 586 in  set 12 | mullaitivu
# Missing field/result... skipping.
# Processing Record 587 in  set 12 | destin
# Processing Record 588 in  set 12 | yerbogachen
# Processing Record 589 in  set 12 | prince george
# Processing Record 590 in  set 12 | severo-yeniseyskiy
# Processing Record 591 in  set 12 | kemi
# Processing Record 592 in  set 12 | teya
# Processing Record 593 in  set 12 | pilar
# Processing Record 594 in  set 12 | vaitupu
# Missing field/result... skipping.
# Processing Record 595 in  set 12 | santa rosalia
# Processing Record 596 in  set 12 | kamenka
# Processing Record 597 in  set 12 | acajutla
# Processing Record 598 in  set 12 | boysun
# Processing Record 599 in  set 12 | bolungarvik
# Missing field/result... skipping.
# Processing Record 600 in  set 12 | vardo
# Processing Record 601 in  set 13 | labuan
# Processing Record 602 in  set 13 | fuerte olimpo
# Processing Record 603 in  set 13 | norman wells
# Processing Record 604 in  set 13 | kijang
# Processing Record 605 in  set 13 | qingdao
# Processing Record 606 in  set 13 | puerto suarez
# Processing Record 607 in  set 13 | ajdabiya
# Processing Record 608 in  set 13 | sola
# Processing Record 609 in  set 13 | skaudvile
# Processing Record 610 in  set 13 | mogwase
# Processing Record 611 in  set 13 | lahaina
# Processing Record 612 in  set 13 | robe
# Processing Record 613 in  set 13 | olinda
# Processing Record 614 in  set 13 | onega
# Processing Record 615 in  set 13 | buckeye
# Processing Record 616 in  set 13 | tiarei
# Processing Record 617 in  set 13 | vredendal
# Processing Record 618 in  set 13 | bowen
# Processing Record 619 in  set 13 | batagay-alyta
# Processing Record 620 in  set 13 | isangel
# Processing Record 621 in  set 13 | pozo colorado
# Processing Record 622 in  set 13 | kalevala
# Processing Record 623 in  set 13 | santa maria
# Processing Record 624 in  set 13 | bilaspur
# Processing Record 625 in  set 13 | ziyang
# Processing Record 626 in  set 13 | dhidhdhoo
# Processing Record 627 in  set 13 | hamburg
# Processing Record 628 in  set 13 | toulepleu
# Missing field/result... skipping.
# Processing Record 629 in  set 13 | fevralsk
# Missing field/result... skipping.
# Processing Record 630 in  set 13 | oriximina
# Processing Record 631 in  set 13 | meteti
# Processing Record 632 in  set 13 | marcona
# Missing field/result... skipping.
# Processing Record 633 in  set 13 | tabou
# Processing Record 634 in  set 13 | iquique
# Processing Record 635 in  set 13 | meadow lake
# Processing Record 636 in  set 13 | marang
# Missing field/result... skipping.
# Processing Record 637 in  set 13 | aden
# Processing Record 638 in  set 13 | ewa beach
# Processing Record 639 in  set 13 | kysyl-syr
# Processing Record 640 in  set 13 | palabuhanratu
# Missing field/result... skipping.
# Processing Record 641 in  set 13 | srednekolymsk
# Processing Record 642 in  set 13 | ostersund
# Processing Record 643 in  set 13 | kenai
# Processing Record 644 in  set 13 | seoul
# Processing Record 645 in  set 13 | bandiagara
# Processing Record 646 in  set 13 | shache
# Processing Record 647 in  set 13 | caxito
# Processing Record 648 in  set 13 | mogadishu
# Processing Record 649 in  set 13 | paracuru
# Processing Record 650 in  set 13 | cedral
# Processing Record 651 in  set 14 | agadez
# Processing Record 652 in  set 14 | chenzhou
# Processing Record 653 in  set 14 | turukhansk
# Processing Record 654 in  set 14 | hagere selam
# Processing Record 655 in  set 14 | along
# Processing Record 656 in  set 14 | smithers
# Processing Record 657 in  set 14 | gao
# Processing Record 658 in  set 14 | berlevag
# Processing Record 659 in  set 14 | grindavik
# Processing Record 660 in  set 14 | ormara
# Processing Record 661 in  set 14 | eisenerz
# Processing Record 662 in  set 14 | tapaua
# Missing field/result... skipping.
# Processing Record 663 in  set 14 | palmer
# Processing Record 664 in  set 14 | lobito
# Processing Record 665 in  set 14 | deqing
# Processing Record 666 in  set 14 | lima
# Processing Record 667 in  set 14 | san cristobal
# Processing Record 668 in  set 14 | praia
# Processing Record 669 in  set 14 | grand gaube
# Processing Record 670 in  set 14 | port shepstone
# Processing Record 671 in  set 14 | armacao dos buzios
# Missing field/result... skipping.
# Processing Record 672 in  set 14 | caborca
# Processing Record 673 in  set 14 | solhan
# Processing Record 674 in  set 14 | shirokiy
# Processing Record 675 in  set 14 | boa vista
# Processing Record 676 in  set 14 | constitucion
# Processing Record 677 in  set 14 | rocha
# Processing Record 678 in  set 14 | lanxi
# Processing Record 679 in  set 14 | aasiaat
# Processing Record 680 in  set 14 | bonavista
# Processing Record 681 in  set 14 | san ramon
# Processing Record 682 in  set 14 | lerwick
# Processing Record 683 in  set 14 | gogapur
# Processing Record 684 in  set 14 | katsuura
# Processing Record 685 in  set 14 | nanhai
# Processing Record 686 in  set 14 | beregovoy
# Processing Record 687 in  set 14 | kikerino
# Processing Record 688 in  set 14 | vanimo
# Processing Record 689 in  set 14 | jiuquan
# Processing Record 690 in  set 14 | vila
# Processing Record 691 in  set 14 | half moon bay
# Processing Record 692 in  set 14 | peniche
# Processing Record 693 in  set 14 | hit
# Processing Record 694 in  set 14 | gravelbourg
# Processing Record 695 in  set 14 | ballina
# Processing Record 696 in  set 14 | hihifo
# Missing field/result... skipping.
# Processing Record 697 in  set 14 | vrede
# Processing Record 698 in  set 14 | ambon
# Processing Record 699 in  set 14 | cicevac
# Processing Record 700 in  set 14 | chagda
# Missing field/result... skipping.
# Processing Record 701 in  set 15 | marystown
# Processing Record 702 in  set 15 | miastko
# Processing Record 703 in  set 15 | ambodifototra
# Missing field/result... skipping.
# Processing Record 704 in  set 15 | cumaribo
# Missing field/result... skipping.
# Processing Record 705 in  set 15 | burica
# Missing field/result... skipping.
# Processing Record 706 in  set 15 | port hueneme
# Processing Record 707 in  set 15 | waddan
# Processing Record 708 in  set 15 | sabirabad
# Processing Record 709 in  set 15 | marakkanam
# Processing Record 710 in  set 15 | sicamous
# Processing Record 711 in  set 15 | novobirilyussy
# Processing Record 712 in  set 15 | kattivakkam
# Processing Record 713 in  set 15 | iranshahr
# Processing Record 714 in  set 15 | kailua
# Processing Record 715 in  set 15 | deputatskiy
# Processing Record 716 in  set 15 | ekhabi
# Processing Record 717 in  set 15 | wahran
# Missing field/result... skipping.
# Processing Record 718 in  set 15 | manturovo
# Processing Record 719 in  set 15 | paka
# Processing Record 720 in  set 15 | mosquera
# Processing Record 721 in  set 15 | novikovo
# Processing Record 722 in  set 15 | ust-kamchatsk
# Missing field/result... skipping.
# Processing Record 723 in  set 15 | sorkjosen
# Missing field/result... skipping.
# Processing Record 724 in  set 15 | farmington
# Processing Record 725 in  set 15 | navalmoral de la mata
# Processing Record 726 in  set 15 | comodoro rivadavia
# Processing Record 727 in  set 15 | cairns
# Processing Record 728 in  set 15 | bayan
# Processing Record 729 in  set 15 | ortakoy
# Processing Record 730 in  set 15 | cravo norte
# Processing Record 731 in  set 15 | mackenzie
# Processing Record 732 in  set 15 | bonanza
# Processing Record 733 in  set 15 | malwan
# Missing field/result... skipping.
# Processing Record 734 in  set 15 | naryan-mar
# Processing Record 735 in  set 15 | talovaya
# Processing Record 736 in  set 15 | sorvag
# Missing field/result... skipping.
# Processing Record 737 in  set 15 | mareeba
# Processing Record 738 in  set 15 | fairbanks
# Processing Record 739 in  set 15 | nemuro
# Processing Record 740 in  set 15 | pochutla
# Processing Record 741 in  set 15 | pecos
# Processing Record 742 in  set 15 | weihai
# Processing Record 743 in  set 15 | roma
# Processing Record 744 in  set 15 | margate
# Processing Record 745 in  set 15 | tautira
# Processing Record 746 in  set 15 | seydi
# Processing Record 747 in  set 15 | carutapera
# Processing Record 748 in  set 15 | churapcha
# Processing Record 749 in  set 15 | san quintin
# Processing Record 750 in  set 15 | gambo
# Processing Record 751 in  set 16 | bikramganj
# Processing Record 752 in  set 16 | dukat
# Processing Record 753 in  set 16 | nanakuli
# Processing Record 754 in  set 16 | zhuhai
# Processing Record 755 in  set 16 | houma
# Processing Record 756 in  set 16 | sabzevar
# Processing Record 757 in  set 16 | yatou
# Processing Record 758 in  set 16 | kendari
# Processing Record 759 in  set 16 | tual
# Processing Record 760 in  set 16 | rio grande
# Processing Record 761 in  set 16 | urubicha
# Processing Record 762 in  set 16 | coari
# Processing Record 763 in  set 16 | longyan
# Processing Record 764 in  set 16 | clermont
# Processing Record 765 in  set 16 | aklavik
# Processing Record 766 in  set 16 | bosobolo
# Processing Record 767 in  set 16 | mocuba
# Processing Record 768 in  set 16 | mountain home
# Processing Record 769 in  set 16 | honiara
# Processing Record 770 in  set 16 | faranah
# Processing Record 771 in  set 16 | kondopoga
# Processing Record 772 in  set 16 | binga
# Processing Record 773 in  set 16 | balkhash
# Processing Record 774 in  set 16 | porkhov
# Processing Record 775 in  set 16 | kimbe
# Processing Record 776 in  set 16 | zapolyarnyy
# Processing Record 777 in  set 16 | izhma
# Processing Record 778 in  set 16 | lithakia
# Processing Record 779 in  set 16 | tidore
# Missing field/result... skipping.
# Processing Record 780 in  set 16 | zeya

# %%
weather_response_json
# Out:
# [{'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 178.42, 'lat': 69.38},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 51.22,
#    'pressure': 1018.05,
#    'humidity': 64,
#    'temp_min': 51.22,
#    'temp_max': 51.22,
#    'sea_level': 1018.05,
#    'grnd_level': 1013.9},
#   'wind': {'speed': 8.03, 'deg': 104.373},
#   'clouds': {'all': 51},
#   'dt': 1562607752,
#   'sys': {'message': 0.0059, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 43200,
#   'id': 2123814,
#   'name': 'Leningradskiy',
#   'cod': 200},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 64.29,
#    'pressure': 1023,
#    'humidity': 59,
#    'temp_min': 63,
#    'temp_max': 66.2},
#   'wind': {'speed': 12.75, 'deg': 340},
#   'clouds': {'all': 50},
#   'dt': 1562607763,
#   'sys': {'type': 1,
#    'id': 1966,
#    'message': 0.0065,
#    'country': 'ZA',
#    'sunrise': 1562564783,
#    'sunset': 1562600574},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 76.78,
#    'pressure': 1014,
#    'humidity': 61,
#    'temp_min': 73,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 18.34, 'deg': 160},
#   'clouds': {'all': 40},
#   'dt': 1562607788,
#   'sys': {'type': 1,
#    'id': 8521,
#    'message': 0.007,
#    'country': 'EC',
#    'sunrise': 1562587433,
#    'sunset': 1562630917},
#   'timezone': -21600,
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  {'coord': {'lon': 44.7, 'lat': 38.23},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 58.24,
#    'pressure': 1008.84,
#    'humidity': 60,
#    'temp_min': 58.24,
#    'temp_max': 58.24,
#    'sea_level': 1008.84,
#    'grnd_level': 759.01},
#   'wind': {'speed': 2.86, 'deg': 245.938},
#   'rain': {'3h': 1.124},
#   'clouds': {'all': 100},
#   'dt': 1562607817,
#   'sys': {'message': 0.007,
#    'country': 'IR',
#    'sunrise': 1562550292,
#    'sunset': 1562603227},
#   'timezone': 16200,
#   'id': 117656,
#   'name': 'Ayan',
#   'cod': 200},
#  {'coord': {'lon': 22.34, 'lat': 39.45},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 92.91,
#    'pressure': 1007,
#    'humidity': 26,
#    'temp_min': 89.6,
#    'temp_max': 95},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 70},
#   'clouds': {'all': 20},
#   'dt': 1562607566,
#   'sys': {'type': 1,
#    'id': 6629,
#    'message': 0.0067,
#    'country': 'GR',
#    'sunrise': 1562555442,
#    'sunset': 1562608811},
#   'timezone': 10800,
#   'id': 262462,
#   'name': 'Saint George',
#   'cod': 200},
#  {'coord': {'lon': 7.82, 'lat': 63.1},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 55.6,
#    'pressure': 1017,
#    'humidity': 76,
#    'temp_min': 53.6,
#    'temp_max': 57.2},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 360},
#   'clouds': {'all': 75},
#   'dt': 1562607912,
#   'sys': {'type': 1,
#    'id': 1636,
#    'message': 0.0095,
#    'country': 'NO',
#    'sunrise': 1562550002,
#    'sunset': 1562621221},
#   'timezone': 7200,
#   'id': 6453331,
#   'name': 'Rensvik',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'pressure': 1009,
#    'humidity': 65,
#    'temp_min': 46.4,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 360},
#   'clouds': {'all': 0},
#   'dt': 1562607742,
#   'sys': {'type': 1,
#    'id': 8303,
#    'message': 0.0066,
#    'country': 'AR',
#    'sunrise': 1562590454,
#    'sunset': 1562617315},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -155.08, 'lat': 19.71},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 74.62,
#    'pressure': 1015,
#    'humidity': 83,
#    'temp_min': 72,
#    'temp_max': 78.8},
#   'visibility': 4828,
#   'wind': {'speed': 4.7, 'deg': 340},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 90},
#   'dt': 1562607711,
#   'sys': {'type': 1,
#    'id': 7881,
#    'message': 0.0077,
#    'country': 'US',
#    'sunrise': 1562600836,
#    'sunset': 1562648587},
#   'timezone': -36000,
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 15.16, 'lat': -26.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 62.6,
#    'pressure': 1019,
#    'humidity': 67,
#    'temp_min': 62.6,
#    'temp_max': 62.6},
#   'wind': {'speed': 16.11, 'deg': 200},
#   'clouds': {'all': 0},
#   'dt': 1562607746,
#   'sys': {'type': 1,
#    'id': 2260,
#    'message': 0.0065,
#    'country': 'NA',
#    'sunrise': 1562564885,
#    'sunset': 1562602815},
#   'timezone': 7200,
#   'id': 3355672,
#   'name': 'Luderitz',
#   'cod': 200},
#  {'coord': {'lon': -105.3, 'lat': 55.1},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 59,
#    'pressure': 1012,
#    'humidity': 72,
#    'temp_min': 59,
#    'temp_max': 59},
#   'visibility': 24140,
#   'wind': {'speed': 9.17, 'deg': 320},
#   'clouds': {'all': 90},
#   'dt': 1562607757,
#   'sys': {'type': 1,
#    'id': 949,
#    'message': 0.0072,
#    'country': 'CA',
#    'sunrise': 1562581960,
#    'sunset': 1562643566},
#   'timezone': -21600,
#   'id': 6050066,
#   'name': 'La Ronge',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 34.94, 'lat': 31.8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 80.51,
#    'pressure': 1009,
#    'humidity': 78,
#    'temp_min': 79,
#    'temp_max': 82.99},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 290},
#   'clouds': {'all': 0},
#   'dt': 1562607794,
#   'sys': {'type': 1,
#    'id': 6845,
#    'message': 0.006,
#    'country': 'IL',
#    'sunrise': 1562553664,
#    'sunset': 1562604540},
#   'timezone': 10800,
#   'id': 6693679,
#   'name': 'Gizo',
#   'cod': 200},
#  {'coord': {'lon': 25.75, 'lat': -5.39},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 78.58,
#    'pressure': 1009.67,
#    'humidity': 27,
#    'temp_min': 78.58,
#    'temp_max': 78.58,
#    'sea_level': 1009.67,
#    'grnd_level': 935.89},
#   'wind': {'speed': 4, 'deg': 162.061},
#   'clouds': {'all': 21},
#   'dt': 1562607913,
#   'sys': {'message': 0.0069,
#    'country': 'CD',
#    'sunrise': 1562560029,
#    'sunset': 1562602587},
#   'timezone': 7200,
#   'id': 211098,
#   'name': 'Lubao',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 60.21,
#    'pressure': 1020,
#    'humidity': 72,
#    'temp_min': 57.99,
#    'temp_max': 63},
#   'wind': {'speed': 7, 'deg': 297, 'gust': 5.36},
#   'clouds': {'all': 83},
#   'dt': 1562607746,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'message': 0.0069,
#    'country': 'ZA',
#    'sunrise': 1562564958,
#    'sunset': 1562600783},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': 150.74, 'lat': -23.13},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 64.4,
#    'pressure': 1020,
#    'humidity': 82,
#    'temp_min': 64.4,
#    'temp_max': 64.4},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 90},
#   'clouds': {'all': 90},
#   'dt': 1562607776,
#   'sys': {'type': 1,
#    'id': 9499,
#    'message': 0.0185,
#    'country': 'AU',
#    'sunrise': 1562618317,
#    'sunset': 1562657115},
#   'timezone': 36000,
#   'id': 2142316,
#   'name': 'Yeppoon',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 71.2,
#    'pressure': 1016.25,
#    'humidity': 93,
#    'temp_min': 71.2,
#    'temp_max': 71.2,
#    'sea_level': 1016.25,
#    'grnd_level': 1015.69},
#   'wind': {'speed': 18.12, 'deg': 96.463},
#   'rain': {'3h': 21.062},
#   'clouds': {'all': 100},
#   'dt': 1562607745,
#   'sys': {'message': 0.0126,
#    'country': 'PF',
#    'sunrise': 1562600487,
#    'sunset': 1562639282},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': -52.73, 'lat': 47.66},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 73.81,
#    'pressure': 1005,
#    'humidity': 35,
#    'temp_min': 73.4,
#    'temp_max': 73.99},
#   'visibility': 24140,
#   'wind': {'speed': 17.22, 'deg': 280, 'gust': 10.8},
#   'clouds': {'all': 20},
#   'dt': 1562607809,
#   'sys': {'type': 1,
#    'id': 998,
#    'message': 0.0078,
#    'country': 'CA',
#    'sunrise': 1562571698,
#    'sunset': 1562628593},
#   'timezone': -9000,
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'coord': {'lon': 170.27, 'lat': 69.7},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 44.2,
#    'pressure': 1016.59,
#    'humidity': 69,
#    'temp_min': 44.2,
#    'temp_max': 44.2,
#    'sea_level': 1016.59,
#    'grnd_level': 1016.46},
#   'wind': {'speed': 2.3, 'deg': 348.832},
#   'clouds': {'all': 37},
#   'dt': 1562607749,
#   'sys': {'message': 0.0078, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 43200,
#   'id': 2122090,
#   'name': 'Pevek',
#   'cod': 200},
#  {'coord': {'lon': 17.98, 'lat': 69.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 66.49,
#    'pressure': 1016,
#    'humidity': 24,
#    'temp_min': 64,
#    'temp_max': 71.6},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 80},
#   'clouds': {'all': 0},
#   'dt': 1562607913,
#   'sys': {'type': 1,
#    'id': 1619,
#    'message': 0.0061,
#    'country': 'NO',
#    'sunrise': 0,
#    'sunset': 0},
#   'timezone': 7200,
#   'id': 3157549,
#   'name': 'Finnsnes',
#   'cod': 200},
#  {'coord': {'lon': 100.36, 'lat': -0.92},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 80.38,
#    'pressure': 1012.65,
#    'humidity': 81,
#    'temp_min': 80.38,
#    'temp_max': 80.38,
#    'sea_level': 1012.65,
#    'grnd_level': 1012.25},
#   'wind': {'speed': 16.75, 'deg': 162.119},
#   'rain': {'3h': 11.188},
#   'clouds': {'all': 100},
#   'dt': 1562607795,
#   'sys': {'message': 0.0073,
#    'country': 'ID',
#    'sunrise': 1562628084,
#    'sunset': 1562671533},
#   'timezone': 25200,
#   'id': 1633419,
#   'name': 'Padang',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 42.75,
#    'pressure': 1013,
#    'humidity': 75,
#    'temp_min': 39.99,
#    'temp_max': 45},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 340},
#   'clouds': {'all': 20},
#   'dt': 1562607762,
#   'sys': {'type': 1,
#    'id': 9545,
#    'message': 0.0068,
#    'country': 'AU',
#    'sunrise': 1562622030,
#    'sunset': 1562655040},
#   'timezone': 36000,
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 82,
#    'pressure': 1007.84,
#    'humidity': 73,
#    'temp_min': 82,
#    'temp_max': 82,
#    'sea_level': 1007.84,
#    'grnd_level': 1007.68},
#   'wind': {'speed': 5.1, 'deg': 292.371},
#   'clouds': {'all': 100},
#   'dt': 1562607752,
#   'sys': {'message': 0.0083,
#    'country': 'KI',
#    'sunrise': 1562610303,
#    'sunset': 1562654544},
#   'timezone': 43200,
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': 43.19, 'lat': 53.03},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 60.04,
#    'pressure': 1004.09,
#    'humidity': 97,
#    'temp_min': 60.04,
#    'temp_max': 60.04,
#    'sea_level': 1004.09,
#    'grnd_level': 983.79},
#   'wind': {'speed': 6.82, 'deg': 194.419},
#   'rain': {'3h': 1.876},
#   'clouds': {'all': 100},
#   'dt': 1562607914,
#   'sys': {'message': 0.007,
#    'country': 'RU',
#    'sunrise': 1562547066,
#    'sunset': 1562607178},
#   'timezone': 10800,
#   'id': 507643,
#   'name': 'Poim',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 71.6,
#    'pressure': 1015,
#    'humidity': 88,
#    'temp_min': 71.6,
#    'temp_max': 71.6},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 100},
#   'clouds': {'all': 33},
#   'dt': 1562607675,
#   'sys': {'type': 1,
#    'id': 7271,
#    'message': 0.0065,
#    'country': 'CK',
#    'sunrise': 1562606221,
#    'sunset': 1562645458},
#   'timezone': -36000,
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 55,
#    'pressure': 1021.24,
#    'humidity': 91,
#    'temp_min': 55,
#    'temp_max': 55,
#    'sea_level': 1021.24,
#    'grnd_level': 1000.67},
#   'wind': {'speed': 1.7, 'deg': 100.707},
#   'clouds': {'all': 16},
#   'dt': 1562607753,
#   'sys': {'message': 0.0072,
#    'country': 'AU',
#    'sunrise': 1562618771,
#    'sunset': 1562657463},
#   'timezone': 36000,
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': -86.95, 'lat': 49.72},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1017,
#    'humidity': 47,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 3219,
#   'wind': {'speed': 4.7, 'deg': 270},
#   'clouds': {'all': 90},
#   'dt': 1562607788,
#   'sys': {'type': 1,
#    'id': 810,
#    'message': 0.0079,
#    'country': 'CA',
#    'sunrise': 1562579359,
#    'sunset': 1562637358},
#   'timezone': -14400,
#   'id': 5960603,
#   'name': 'Geraldton',
#   'cod': 200},
#  {'coord': {'lon': 44.22, 'lat': 17.54},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 96.8,
#    'pressure': 1011,
#    'humidity': 13,
#    'temp_min': 96.8,
#    'temp_max': 96.8},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1562607914,
#   'sys': {'type': 1,
#    'id': 7421,
#    'message': 0.006,
#    'country': 'SA',
#    'sunrise': 1562553239,
#    'sunset': 1562600510},
#   'timezone': 10800,
#   'id': 103630,
#   'name': 'Najran',
#   'cod': 200},
#  {'coord': {'lon': -51.29, 'lat': -0.12},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 91.4,
#    'pressure': 1013,
#    'humidity': 55,
#    'temp_min': 91.4,
#    'temp_max': 91.4},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 50},
#   'clouds': {'all': 40},
#   'dt': 1562607914,
#   'sys': {'type': 1,
#    'id': 8415,
#    'message': 0.0056,
#    'country': 'BR',
#    'sunrise': 1562577996,
#    'sunset': 1562621603},
#   'timezone': -10800,
#   'id': 3395042,
#   'name': 'Mazagao',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 79.07,
#    'pressure': 1016,
#    'humidity': 34,
#    'temp_min': 73.99,
#    'temp_max': 84},
#   'visibility': 16093,
#   'wind': {'speed': 6.93, 'deg': 330},
#   'clouds': {'all': 20},
#   'dt': 1562607472,
#   'sys': {'type': 1,
#    'id': 3273,
#    'message': 0.0098,
#    'country': 'US',
#    'sunrise': 1562577893,
#    'sunset': 1562632488},
#   'timezone': -14400,
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': 80.55, 'lat': 73.51},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 32.32,
#    'pressure': 1005.47,
#    'humidity': 97,
#    'temp_min': 32.32,
#    'temp_max': 32.32,
#    'sea_level': 1005.47,
#    'grnd_level': 1005.02},
#   'wind': {'speed': 16.55, 'deg': 20.75},
#   'rain': {'3h': 0.125},
#   'clouds': {'all': 100},
#   'dt': 1562607752,
#   'sys': {'message': 0.0078, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 25200,
#   'id': 1507390,
#   'name': 'Dikson',
#   'cod': 200},
#  {'coord': {'lon': 161.3, 'lat': 68.75},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 64.72,
#    'pressure': 1013.9,
#    'humidity': 52,
#    'temp_min': 64.72,
#    'temp_max': 64.72,
#    'sea_level': 1013.9,
#    'grnd_level': 1013.31},
#   'wind': {'speed': 7.61, 'deg': 136.443},
#   'clouds': {'all': 75},
#   'dt': 1562607495,
#   'sys': {'message': 0.0057, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 39600,
#   'id': 2126199,
#   'name': 'Cherskiy',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 46,
#    'pressure': 1005,
#    'humidity': 89,
#    'temp_min': 46,
#    'temp_max': 46},
#   'wind': {'speed': 11.99, 'deg': 257, 'gust': 13.41},
#   'rain': {'3h': 0.312},
#   'clouds': {'all': 100},
#   'dt': 1562607454,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'message': 0.0076,
#    'country': 'NZ',
#    'sunrise': 1562617546,
#    'sunset': 1562649188},
#   'timezone': 43200,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': 156.12, 'lat': 50.68},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 41.86,
#    'pressure': 1008.5,
#    'humidity': 98,
#    'temp_min': 41.86,
#    'temp_max': 41.86,
#    'sea_level': 1008.5,
#    'grnd_level': 1008.78},
#   'wind': {'speed': 13.13, 'deg': 114.393},
#   'rain': {'3h': 0.875},
#   'clouds': {'all': 100},
#   'dt': 1562607743,
#   'sys': {'message': 0.0069,
#    'country': 'RU',
#    'sunrise': 1562607160,
#    'sunset': 1562665690},
#   'timezone': 39600,
#   'id': 2121385,
#   'name': 'Severo-Kurilsk',
#   'cod': 200},
#  {'coord': {'lon': -73.83, 'lat': -41.87},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'pressure': 1010,
#    'humidity': 93,
#    'temp_min': 50,
#    'temp_max': 50},
#   'visibility': 5000,
#   'wind': {'speed': 14.99, 'deg': 10},
#   'clouds': {'all': 90},
#   'dt': 1562607494,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0057,
#    'country': 'CL',
#    'sunrise': 1562588525,
#    'sunset': 1562621894},
#   'timezone': -14400,
#   'id': 3899695,
#   'name': 'Ancud',
#   'cod': 200},
#  {'coord': {'lon': 18.06, 'lat': 1.62},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 73.9,
#    'pressure': 1011.81,
#    'humidity': 81,
#    'temp_min': 73.9,
#    'temp_max': 73.9,
#    'sea_level': 1011.81,
#    'grnd_level': 973.29},
#   'wind': {'speed': 3.2, 'deg': 240.116},
#   'clouds': {'all': 78},
#   'dt': 1562607914,
#   'sys': {'message': 0.0054,
#    'country': 'CD',
#    'sunrise': 1562561177,
#    'sunset': 1562605131},
#   'timezone': 3600,
#   'id': 2259655,
#   'name': 'Impfondo',
#   'cod': 200},
#  {'coord': {'lon': 25.81, 'lat': 50.73},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 64,
#    'pressure': 741,
#    'humidity': 55,
#    'temp_min': 64,
#    'temp_max': 64},
#   'wind': {'speed': 11.36, 'deg': 275.622},
#   'rain': {'3h': 0.313},
#   'clouds': {'all': 66},
#   'dt': 1562607914,
#   'sys': {'type': 3,
#    'id': 2011559,
#    'message': 0.0067,
#    'country': 'UA',
#    'sunrise': 1562551984,
#    'sunset': 1562610603},
#   'timezone': 10800,
#   'id': 698502,
#   'name': 'Olyka',
#   'cod': 200},
#  {'coord': {'lon': -72.07, 'lat': -45.58},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'},
#    {'id': 711, 'main': 'Smoke', 'description': 'smoke', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 42.89,
#    'pressure': 1011,
#    'humidity': 93,
#    'temp_min': 41,
#    'temp_max': 46.4},
#   'visibility': 2000,
#   'wind': {'speed': 4.7},
#   'clouds': {'all': 90},
#   'dt': 1562607767,
#   'sys': {'type': 1,
#    'id': 8491,
#    'message': 0.0068,
#    'country': 'CL',
#    'sunrise': 1562588845,
#    'sunset': 1562620729},
#   'timezone': -14400,
#   'id': 3894426,
#   'name': 'Coihaique',
#   'cod': 200},
#  {'coord': {'lon': 37.62, 'lat': -3.78},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 71.56,
#    'pressure': 1017.02,
#    'humidity': 64,
#    'temp_min': 71.56,
#    'temp_max': 71.56,
#    'sea_level': 1017.02,
#    'grnd_level': 932.51},
#   'wind': {'speed': 12.88, 'deg': 154.904},
#   'clouds': {'all': 15},
#   'dt': 1562607915,
#   'sys': {'message': 0.0061,
#    'country': 'TZ',
#    'sunrise': 1562557019,
#    'sunset': 1562599898},
#   'timezone': 10800,
#   'id': 156025,
#   'name': 'Lembeni',
#   'cod': 200},
#  {'coord': {'lon': 146.27, 'lat': -20.07},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 61.3,
#    'pressure': 1019.27,
#    'humidity': 88,
#    'temp_min': 61.3,
#    'temp_max': 61.3,
#    'sea_level': 1019.27,
#    'grnd_level': 980.69},
#   'wind': {'speed': 7.92, 'deg': 90.68},
#   'clouds': {'all': 69},
#   'dt': 1562607684,
#   'sys': {'message': 0.0066,
#    'country': 'AU',
#    'sunrise': 1562619040,
#    'sunset': 1562658538},
#   'timezone': 36000,
#   'id': 2171722,
#   'name': 'Charters Towers',
#   'cod': 200},
#  {'coord': {'lon': -51.1, 'lat': 69.22},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 57.2,
#    'pressure': 1013,
#    'humidity': 35,
#    'temp_min': 57.2,
#    'temp_max': 57.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 350},
#   'clouds': {'all': 20},
#   'dt': 1562607546,
#   'sys': {'type': 1,
#    'id': 165,
#    'message': 0.0069,
#    'country': 'GL',
#    'sunrise': 0,
#    'sunset': 0},
#   'timezone': -7200,
#   'id': 3423146,
#   'name': 'Ilulissat',
#   'cod': 200},
#  {'coord': {'lon': -120.46, 'lat': 34.64},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 61.5,
#    'pressure': 1018,
#    'humidity': 82,
#    'temp_min': 57,
#    'temp_max': 68},
#   'visibility': 16093,
#   'wind': {'speed': 6.93, 'deg': 260},
#   'clouds': {'all': 90},
#   'dt': 1562607766,
#   'sys': {'type': 1,
#    'id': 4747,
#    'message': 0.0079,
#    'country': 'US',
#    'sunrise': 1562590543,
#    'sunset': 1562642261},
#   'timezone': -25200,
#   'id': 5367788,
#   'name': 'Lompoc',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 41,
#    'pressure': 1010,
#    'humidity': 93,
#    'temp_min': 41,
#    'temp_max': 41},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 40},
#   'clouds': {'all': 90},
#   'dt': 1562607742,
#   'sys': {'type': 1,
#    'id': 8487,
#    'message': 0.0062,
#    'country': 'CL',
#    'sunrise': 1562590530,
#    'sunset': 1562618487},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 108.27, 'lat': -2.88},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 76.24,
#    'pressure': 1010.92,
#    'humidity': 84,
#    'temp_min': 76.24,
#    'temp_max': 76.24,
#    'sea_level': 1010.92,
#    'grnd_level': 1007.98},
#   'wind': {'speed': 4.79, 'deg': 126.094},
#   'clouds': {'all': 31},
#   'dt': 1562607915,
#   'sys': {'message': 0.0073,
#    'country': 'ID',
#    'sunrise': 1562626380,
#    'sunset': 1562669440},
#   'timezone': 25200,
#   'id': 1636426,
#   'name': 'Manggar',
#   'cod': 200},
#  {'coord': {'lon': 34.66, 'lat': 2.53},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 74.62,
#    'pressure': 1012.15,
#    'humidity': 66,
#    'temp_min': 74.62,
#    'temp_max': 74.62,
#    'sea_level': 1012.15,
#    'grnd_level': 877.81},
#   'wind': {'speed': 2.26, 'deg': 215.16},
#   'clouds': {'all': 66},
#   'dt': 1562607915,
#   'sys': {'message': 0.0057,
#    'country': 'UG',
#    'sunrise': 1562557101,
#    'sunset': 1562601237},
#   'timezone': 10800,
#   'id': 229112,
#   'name': 'Moroto',
#   'cod': 200},
#  {'coord': {'lon': -68.59, 'lat': 70.47},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 53.6,
#    'pressure': 1020,
#    'humidity': 76,
#    'temp_min': 53.6,
#    'temp_max': 53.6},
#   'visibility': 40233,
#   'wind': {'speed': 8.05, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1562607785,
#   'sys': {'type': 1,
#    'id': 776,
#    'message': 0.0066,
#    'country': 'CA',
#    'sunrise': 0,
#    'sunset': 0},
#   'timezone': -14400,
#   'id': 5924351,
#   'name': 'Clyde River',
#   'cod': 200},
#  {'coord': {'lon': 57.7, 'lat': -20.41},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 71.83,
#    'pressure': 1020,
#    'humidity': 88,
#    'temp_min': 71.6,
#    'temp_max': 72},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 320},
#   'clouds': {'all': 75},
#   'dt': 1562607586,
#   'sys': {'type': 1,
#    'id': 2061,
#    'message': 0.0058,
#    'country': 'MU',
#    'sunrise': 1562553937,
#    'sunset': 1562593341},
#   'timezone': 14400,
#   'id': 934322,
#   'name': 'Mahebourg',
#   'cod': 200},
#  {'coord': {'lon': 118.58, 'lat': -20.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 59,
#    'pressure': 1018,
#    'humidity': 72,
#    'temp_min': 59,
#    'temp_max': 59},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 170},
#   'clouds': {'all': 0},
#   'dt': 1562607768,
#   'sys': {'type': 1,
#    'id': 9585,
#    'message': 0.0064,
#    'country': 'AU',
#    'sunrise': 1562625712,
#    'sunset': 1562665159},
#   'timezone': 28800,
#   'id': 2063042,
#   'name': 'Port Hedland',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 22.13, 'lat': -30.97},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 53.38,
#    'pressure': 1025,
#    'humidity': 60,
#    'temp_min': 53.38,
#    'temp_max': 53.38,
#    'sea_level': 1025,
#    'grnd_level': 878.11},
#   'wind': {'speed': 7.11, 'deg': 267.802},
#   'clouds': {'all': 0},
#   'dt': 1562607753,
#   'sys': {'message': 0.0062,
#    'country': 'ZA',
#    'sunrise': 1562563775,
#    'sunset': 1562600579},
#   'timezone': 7200,
#   'id': 1014034,
#   'name': 'Carnarvon',
#   'cod': 200},
#  {'coord': {'lon': -73.76, 'lat': -42.48},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'pressure': 1010,
#    'humidity': 93,
#    'temp_min': 50,
#    'temp_max': 50},
#   'visibility': 5000,
#   'wind': {'speed': 14.99, 'deg': 10},
#   'clouds': {'all': 90},
#   'dt': 1562607756,
#   'sys': {'type': 1,
#    'id': 8512,
#    'message': 0.0068,
#    'country': 'CL',
#    'sunrise': 1562588623,
#    'sunset': 1562621762},
#   'timezone': -14400,
#   'id': 3896218,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': -73.36, 'lat': 41.14},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 74.55,
#    'pressure': 1016,
#    'humidity': 69,
#    'temp_min': 71.01,
#    'temp_max': 79},
#   'visibility': 16093,
#   'wind': {'speed': 6.93, 'deg': 120},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 1},
#   'dt': 1562607915,
#   'sys': {'type': 1,
#    'id': 3409,
#    'message': 0.012,
#    'country': 'US',
#    'sunrise': 1562578101,
#    'sunset': 1562632092},
#   'timezone': -14400,
#   'id': 4845585,
#   'name': 'Westport',
#   'cod': 200},
#  {'coord': {'lon': 86.02, 'lat': 56.08},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 59,
#    'pressure': 1006,
#    'humidity': 82,
#    'temp_min': 59,
#    'temp_max': 59},
#   'visibility': 10000,
#   'wind': {'speed': 4.47, 'deg': 180},
#   'clouds': {'all': 0},
#   'dt': 1562607915,
#   'sys': {'type': 1,
#    'id': 8961,
#    'message': 0.0067,
#    'country': 'RU',
#    'sunrise': 1562622072,
#    'sunset': 1562684429},
#   'timezone': 25200,
#   'id': 1511494,
#   'name': 'Anzhero-Sudzhensk',
#   'cod': 200},
#  {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 79.54,
#    'pressure': 1017,
#    'humidity': 78,
#    'temp_min': 78.01,
#    'temp_max': 80.6},
#   'visibility': 16093,
#   'wind': {'speed': 16.11, 'deg': 50},
#   'clouds': {'all': 90},
#   'dt': 1562607467,
#   'sys': {'type': 1,
#    'id': 7873,
#    'message': 0.0063,
#    'country': 'US',
#    'sunrise': 1562601576,
#    'sunset': 1562649882},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  {'coord': {'lon': 32.9, 'lat': 24.09},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 91.36,
#    'pressure': 1008.06,
#    'humidity': 12,
#    'temp_min': 91.36,
#    'temp_max': 91.36,
#    'sea_level': 1008.06,
#    'grnd_level': 975.66},
#   'wind': {'speed': 10.22, 'deg': 333.099},
#   'clouds': {'all': 0},
#   'dt': 1562607813,
#   'sys': {'message': 0.0052,
#    'country': 'EG',
#    'sunrise': 1562555187,
#    'sunset': 1562603996},
#   'timezone': 7200,
#   'id': 359792,
#   'name': 'Aswan',
#   'cod': 200},
#  {'coord': {'lon': -37.64, 'lat': 65.61},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 42.8,
#    'pressure': 1019,
#    'humidity': 75,
#    'temp_min': 42.8,
#    'temp_max': 42.8},
#   'visibility': 10000,
#   'wind': {'speed': 18.34, 'deg': 80},
#   'clouds': {'all': 5},
#   'dt': 1562607747,
#   'sys': {'type': 1,
#    'id': 81,
#    'message': 0.0094,
#    'country': 'GL',
#    'sunrise': 1562557632,
#    'sunset': 1562635414},
#   'timezone': -7200,
#   'id': 3424607,
#   'name': 'Tasiilaq',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 47.26,
#    'pressure': 1016,
#    'humidity': 72,
#    'temp_min': 44.01,
#    'temp_max': 52},
#   'wind': {'speed': 15.39, 'deg': 237.632},
#   'clouds': {'all': 61},
#   'dt': 1562607475,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'message': 0.0085,
#    'country': 'AU',
#    'sunrise': 1562628168,
#    'sunset': 1562664253},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -114.38, 'lat': 62.45},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 46.69,
#    'pressure': 1013,
#    'humidity': 66,
#    'temp_min': 46,
#    'temp_max': 50},
#   'visibility': 24140,
#   'wind': {'speed': 12.75, 'deg': 290, 'gust': 8.2},
#   'clouds': {'all': 75},
#   'dt': 1562607749,
#   'sys': {'type': 1,
#    'id': 1007,
#    'message': 0.0069,
#    'country': 'CA',
#    'sunrise': 1562579959,
#    'sunset': 1562649927},
#   'timezone': -21600,
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': 26.93, 'lat': 57.82},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 59.67,
#    'pressure': 1001,
#    'humidity': 72,
#    'temp_min': 59,
#    'temp_max': 61},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 40},
#   'rain': {'3h': 0.938},
#   'clouds': {'all': 90},
#   'dt': 1562607824,
#   'sys': {'type': 1,
#    'id': 1335,
#    'message': 0.0061,
#    'country': 'EE',
#    'sunrise': 1562548988,
#    'sunset': 1562613062},
#   'timezone': 10800,
#   'id': 587450,
#   'name': 'Juba',
#   'cod': 200},
#  {'coord': {'lon': -53.46, 'lat': -33.69},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 54.82,
#    'pressure': 1024.54,
#    'humidity': 58,
#    'temp_min': 54.82,
#    'temp_max': 54.82,
#    'sea_level': 1024.54,
#    'grnd_level': 1023.05},
#   'wind': {'speed': 4.47, 'deg': 9.218},
#   'clouds': {'all': 27},
#   'dt': 1562607742,
#   'sys': {'message': 0.0058,
#    'country': 'UY',
#    'sunrise': 1562582297,
#    'sunset': 1562618344},
#   'timezone': -10800,
#   'id': 3443061,
#   'name': 'Chuy',
#   'cod': 200},
#  {'coord': {'lon': -67.39, 'lat': -8.76},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 90.64,
#    'pressure': 1015,
#    'humidity': 37,
#    'temp_min': 90.64,
#    'temp_max': 90.64,
#    'sea_level': 1015,
#    'grnd_level': 998.48},
#   'wind': {'speed': 1.74, 'deg': 114.365},
#   'clouds': {'all': 0},
#   'dt': 1562607916,
#   'sys': {'message': 0.0078,
#    'country': 'BR',
#    'sunrise': 1562582723,
#    'sunset': 1562624605},
#   'timezone': -14400,
#   'id': 3664956,
#   'name': 'Boca do Acre',
#   'cod': 200},
#  {'coord': {'lon': 92.4, 'lat': 53.28},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 61.48,
#    'pressure': 1009.62,
#    'humidity': 91,
#    'temp_min': 61.48,
#    'temp_max': 61.48,
#    'sea_level': 1009.62,
#    'grnd_level': 967.23},
#   'wind': {'speed': 3.51, 'deg': 93.351},
#   'clouds': {'all': 24},
#   'dt': 1562607916,
#   'sys': {'message': 0.0062,
#    'country': 'RU',
#    'sunrise': 1562621622,
#    'sunset': 1562681817},
#   'timezone': 25200,
#   'id': 1485904,
#   'name': 'Yermakovskoye',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -97.86, 'lat': 55.74},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 64.4,
#    'pressure': 1005,
#    'humidity': 88,
#    'temp_min': 64.4,
#    'temp_max': 64.4},
#   'visibility': 24140,
#   'wind': {'speed': 4.7, 'deg': 280},
#   'clouds': {'all': 90},
#   'dt': 1562607750,
#   'sys': {'type': 1,
#    'id': 935,
#    'message': 0.0071,
#    'country': 'CA',
#    'sunrise': 1562579912,
#    'sunset': 1562642043},
#   'timezone': -18000,
#   'id': 6165406,
#   'name': 'Thompson',
#   'cod': 200},
#  {'coord': {'lon': -67.52, 'lat': -46.43},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 49.6,
#    'pressure': 1009.41,
#    'humidity': 60,
#    'temp_min': 49.6,
#    'temp_max': 49.6,
#    'sea_level': 1009.41,
#    'grnd_level': 975.55},
#   'wind': {'speed': 11.03, 'deg': 292.388},
#   'clouds': {'all': 48},
#   'dt': 1562607749,
#   'sys': {'message': 0.0077,
#    'country': 'AR',
#    'sunrise': 1562587940,
#    'sunset': 1562619450},
#   'timezone': -10800,
#   'id': 3863379,
#   'name': 'Mar del Plata',
#   'cod': 200},
#  {'coord': {'lon': -123.21, 'lat': 49.34},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 63.63,
#    'pressure': 1016,
#    'humidity': 82,
#    'temp_min': 57.99,
#    'temp_max': 69.01},
#   'visibility': 32186,
#   'wind': {'speed': 9.17, 'deg': 220},
#   'clouds': {'all': 40},
#   'dt': 1562607916,
#   'sys': {'type': 1,
#    'id': 954,
#    'message': 0.008,
#    'country': 'CA',
#    'sunrise': 1562588174,
#    'sunset': 1562645950},
#   'timezone': -25200,
#   'id': 6173331,
#   'name': 'West Bay',
#   'cod': 200},
#  {'coord': {'lon': -88.94, 'lat': 16.17},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 90.82,
#    'pressure': 1013.69,
#    'humidity': 53,
#    'temp_min': 90.82,
#    'temp_max': 90.82,
#    'sea_level': 1013.69,
#    'grnd_level': 1008.62},
#   'wind': {'speed': 7.25, 'deg': 87.738},
#   'rain': {'3h': 0.813},
#   'clouds': {'all': 52},
#   'dt': 1562607916,
#   'sys': {'message': 0.007,
#    'country': 'BZ',
#    'sunrise': 1562585356,
#    'sunset': 1562632317},
#   'timezone': -21600,
#   'id': 3581398,
#   'name': 'Laguna',
#   'cod': 200},
#  {'coord': {'lon': -24.5, 'lat': 14.9},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 72.82,
#    'pressure': 1016.26,
#    'humidity': 79,
#    'temp_min': 72.82,
#    'temp_max': 72.82,
#    'sea_level': 1016.26,
#    'grnd_level': 1016.33},
#   'wind': {'speed': 13.87, 'deg': 23.069},
#   'clouds': {'all': 79},
#   'dt': 1562607767,
#   'sys': {'message': 0.0073,
#    'country': 'CV',
#    'sunrise': 1562570026,
#    'sunset': 1562616712},
#   'timezone': -3600,
#   'id': 3374210,
#   'name': 'Sao Filipe',
#   'cod': 200},
#  {'coord': {'lon': -20.27, 'lat': 63.44},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 51.8,
#    'pressure': 1016,
#    'humidity': 87,
#    'temp_min': 51.8,
#    'temp_max': 51.8},
#   'visibility': 10000,
#   'wind': {'speed': 26.4, 'deg': 100},
#   'clouds': {'all': 40},
#   'dt': 1562607731,
#   'sys': {'type': 1,
#    'id': 93,
#    'message': 0.0077,
#    'country': 'IS',
#    'sunrise': 1562556418,
#    'sunset': 1562628290},
#   'timezone': 0,
#   'id': 3412093,
#   'name': 'Vestmannaeyjar',
#   'cod': 200},
#  {'coord': {'lon': 123.72, 'lat': 11.14},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 82.72,
#    'pressure': 1009.84,
#    'humidity': 75,
#    'temp_min': 82.72,
#    'temp_max': 82.72,
#    'sea_level': 1009.84,
#    'grnd_level': 1009.25},
#   'wind': {'speed': 8.68, 'deg': 224.551},
#   'clouds': {'all': 100},
#   'dt': 1562607917,
#   'sys': {'message': 0.0073,
#    'country': 'PH',
#    'sunrise': 1562621262,
#    'sunset': 1562667141},
#   'timezone': 28800,
#   'id': 1685422,
#   'name': 'Sulangan',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 128.87, 'lat': 71.64},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 52.84,
#    'pressure': 999.56,
#    'humidity': 84,
#    'temp_min': 52.84,
#    'temp_max': 52.84,
#    'sea_level': 999.56,
#    'grnd_level': 988.3},
#   'wind': {'speed': 5.61, 'deg': 179.977},
#   'clouds': {'all': 83},
#   'dt': 1562607456,
#   'sys': {'message': 0.0062, 'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 32400,
#   'id': 2015306,
#   'name': 'Tiksi',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 124.29, 'lat': 8},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 75,
#    'pressure': 1011,
#    'humidity': 92,
#    'temp_min': 75,
#    'temp_max': 75},
#   'wind': {'speed': 5.99, 'deg': 203, 'gust': 4.02},
#   'rain': {'3h': 0.875},
#   'clouds': {'all': 77},
#   'dt': 1562607917,
#   'sys': {'type': 3,
#    'id': 2007154,
#    'message': 0.0051,
#    'country': 'PH',
#    'sunrise': 1562621448,
#    'sunset': 1562666681},
#   'timezone': 28800,
#   'id': 1701054,
#   'name': 'Marawi',
#   'cod': 200},
#  {'coord': {'lon': 10.18, 'lat': 37.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 95,
#    'pressure': 1012,
#    'humidity': 20,
#    'temp_min': 95,
#    'temp_max': 95},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1562607812,
#   'sys': {'type': 1,
#    'id': 1194,
#    'message': 0.006,
#    'country': 'TN',
#    'sunrise': 1562558760,
#    'sunset': 1562611330},
#   'timezone': 3600,
#   'id': 2467813,
#   'name': 'Rafraf',
#   'cod': 200},
#  {'coord': {'lon': -28.7, 'lat': 38.52},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'pressure': 1020,
#    'humidity': 73,
#    'temp_min': 73.4,
#    'temp_max': 73.4},
#   'visibility': 10000,
#   'wind': {'speed': 14.99, 'deg': 280},
#   'clouds': {'all': 20},
#   'dt': 1562607571,
#   'sys': {'type': 1,
#    'id': 6883,
#    'message': 0.009,
#    'country': 'PT',
#    'sunrise': 1562567864,
#    'sunset': 1562620890},
#   'timezone': 0,
#   'id': 3372707,
#   'name': 'Ribeira Grande',
#   'cod': 200},
#  {'coord': {'lon': 73.08, 'lat': -0.6},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 84.52,
#    'pressure': 1011.55,
#    'humidity': 78,
#    'temp_min': 84.52,
#    'temp_max': 84.52,
#    'sea_level': 1011.55,
#    'grnd_level': 1011.37},
#   'wind': {'speed': 14.18, 'deg': 141.217},
#   'rain': {'3h': 0.124},
#   'clouds': {'all': 34},
#   'dt': 1562607753,
#   'sys': {'message': 0.0073,
#    'country': 'MV',
#    'sunrise': 1562548192,
#    'sunset': 1562591704},
#   'timezone': 18000,
#   'id': 1282256,
#   'name': 'Hithadhoo',
#   'cod': 200},
#  {'coord': {'lon': 30.79, 'lat': 59.7},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 59.95,
#    'pressure': 1002,
#    'humidity': 67,
#    'temp_min': 57,
#    'temp_max': 62.01},
#   'visibility': 10000,
#   'wind': {'speed': 8.95, 'deg': 40},
#   'clouds': {'all': 75},
#   'dt': 1562607771,
#   'sys': {'type': 1,
#    'id': 8926,
#    'message': 0.0074,
#    'country': 'RU',
#    'sunrise': 1562547033,
#    'sunset': 1562613164},
#   'timezone': 10800,
#   'id': 546105,
#   'name': 'Nikolskoye',
#   'cod': 200},
#  {'coord': {'lon': -60.23, 'lat': -38.31},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 52.48,
#    'pressure': 1018.01,
#    'humidity': 59,
#    'temp_min': 52.48,
#    'temp_max': 52.48,
#    'sea_level': 1018.01,
#    'grnd_level': 1006.73},
#   'wind': {'speed': 13.35, 'deg': 327.932},
#   'clouds': {'all': 100},
#   'dt': 1562607743,
#   'sys': {'message': 0.0056,
#    'country': 'AR',
#    'sunrise': 1562584637,
#    'sunset': 1562619254},
#   'timezone': -10800,
#   'id': 3833859,
#   'name': 'Barrow',
#   'cod': 200},
#  {'coord': {'lon': 169.85, 'lat': -46.28},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 46.99,
#    'pressure': 999,
#    'humidity': 66,
#    'temp_min': 46.99,
#    'temp_max': 46.99},
#   'wind': {'speed': 15.01, 'deg': 225, 'gust': 13.41},
#   'rain': {'3h': 0.188},
#   'clouds': {'all': 100},
#   'dt': 1562607725,
#   'sys': {'type': 3,
#    'id': 2000217,
#    'message': 0.0078,
#    'country': 'NZ',
#    'sunrise': 1562617328,
#    'sunset': 1562648930},
#   'timezone': 43200,
#   'id': 2208248,
#   'name': 'Kaitangata',
#   'cod': 200},
#  {'coord': {'lon': -73.98, 'lat': 45.63},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 79.27,
#    'pressure': 1015,
#    'humidity': 50,
#    'temp_min': 75.2,
#    'temp_max': 84},
#   'visibility': 72419,
#   'wind': {'speed': 4.7, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1562607773,
#   'sys': {'type': 1,
#    'id': 861,
#    'message': 0.0127,
#    'country': 'CA',
#    'sunrise': 1562577296,
#    'sunset': 1562633195},
#   'timezone': -14400,
#   'id': 6138501,
#   'name': 'Saint-Augustin',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 139.53, 'lat': 35.74},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 66.38,
#    'pressure': 1011,
#    'humidity': 77,
#    'temp_min': 64,
#    'temp_max': 68},
#   'visibility': 16093,
#   'wind': {'speed': 4.7, 'deg': 50},
#   'clouds': {'all': 90},
#   'dt': 1562607789,
#   'sys': {'type': 1,
#    'id': 8073,
#    'message': 0.0067,
#    'country': 'JP',
#    'sunrise': 1562614379,
#    'sunset': 1562666435},
#   'timezone': 32400,
#   'id': 1850144,
#   'name': 'Nishihara',
#   'cod': 200},
#  {'coord': {'lon': -111.68, 'lat': 43.97},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 68.09,
#    'pressure': 1015,
#    'humidity': 48,
#    'temp_min': 66.2,
#    'temp_max': 70},
#   'visibility': 16093,
#   'wind': {'speed': 6.17, 'deg': 161.361},
#   'clouds': {'all': 75},
#   'dt': 1562607576,
#   'sys': {'type': 1,
#    'id': 5735,
#    'message': 0.0056,
#    'country': 'US',
#    'sunrise': 1562586722,
#    'sunset': 1562641867},
#   'timezone': -21600,
#   'id': 5606187,
#   'name': 'Saint Anthony',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 59.56,
#    'pressure': 1026,
#    'humidity': 87,
#    'temp_min': 57,
#    'temp_max': 63},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 330},
#   'clouds': {'all': 75},
#   'dt': 1562607606,
#   'sys': {'type': 1,
#    'id': 1899,
#    'message': 0.008,
#    'country': 'ZA',
#    'sunrise': 1562565083,
#    'sunset': 1562601052},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': -71.14, 'lat': 21.46},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 82.18,
#    'pressure': 1016.18,
#    'humidity': 76,
#    'temp_min': 82.18,
#    'temp_max': 82.18,
#    'sea_level': 1016.18,
#    'grnd_level': 1016.27},
#   'wind': {'speed': 16.64, 'deg': 109.738},
#   'clouds': {'all': 2},
#   'dt': 1562607747,
#   'sys': {'message': 0.0066,
#    'country': 'TC',
#    'sunrise': 1562580481,
#    'sunset': 1562628646},
#   'timezone': -14400,
#   'id': 3576994,
#   'name': 'Cockburn Town',
#   'cod': 200},
#  {'coord': {'lon': 8.53, 'lat': 39.17},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 92.88,
#    'pressure': 1011,
#    'humidity': 39,
#    'temp_min': 89.01,
#    'temp_max': 96.8},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1562607917,
#   'sys': {'type': 1,
#    'id': 6719,
#    'message': 0.0062,
#    'country': 'IT',
#    'sunrise': 1562558809,
#    'sunset': 1562612073},
#   'timezone': 7200,
#   'id': 2525362,
#   'name': 'Carbonia',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 44.56,
#    'pressure': 1025.08,
#    'humidity': 87,
#    'temp_min': 44.56,
#    'temp_max': 44.56,
# ...
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 77.77,
#    'pressure': 1017,
#    'humidity': 94,
#    'temp_min': 73.4,
#    'temp_max': 82},
#   'visibility': 16093,
#   'wind': {'speed': 3.36, 'deg': 70},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 1},
#   'dt': 1562607784,
#   'sys': {'type': 1,
#    'id': 7866,
#    'message': 0.0077,
#    'country': 'US',
#    'sunrise': 1562601377,
#    'sunset': 1562649520},
#   'timezone': -36000,
#   'id': 5851349,
#   'name': 'Nanakuli',
#   'cod': 200},
#  {'coord': {'lon': 112.04, 'lat': 40.71},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 68,
#    'pressure': 1012,
#    'humidity': 56,
#    'temp_min': 68,
#    'temp_max': 68},
#   'visibility': 10000,
#   'wind': {'speed': 8.95, 'deg': 220},
#   'clouds': {'all': 20},
#   'dt': 1562607980,
#   'sys': {'type': 1,
#    'id': 9612,
#    'message': 0.0067,
#    'country': 'CN',
#    'sunrise': 1562620107,
#    'sunset': 1562673903},
#   'timezone': 28800,
#   'id': 2052479,
#   'name': 'Zhuhai',
#   'cod': 200},
#  {'coord': {'lon': 111.36, 'lat': 35.63},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 68.68,
#    'pressure': 1008.49,
#    'humidity': 73,
#    'temp_min': 68.68,
#    'temp_max': 68.68,
#    'sea_level': 1008.49,
#    'grnd_level': 942.97},
#   'wind': {'speed': 3.47, 'deg': 308.163},
#   'clouds': {'all': 100},
#   'dt': 1562607756,
#   'sys': {'message': 0.0054,
#    'country': 'CN',
#    'sunrise': 1562621160,
#    'sunset': 1562673176},
#   'timezone': 28800,
#   'id': 1784874,
#   'name': 'Houma',
#   'cod': 200},
#  {'coord': {'lon': 57.68, 'lat': 36.21},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 83.08,
#    'pressure': 1005.53,
#    'humidity': 23,
#    'temp_min': 83.08,
#    'temp_max': 83.08,
#    'sea_level': 1005.53,
#    'grnd_level': 849.6},
#   'wind': {'speed': 9.8, 'deg': 146.459},
#   'clouds': {'all': 30},
#   'dt': 1562607980,
#   'sys': {'message': 0.0064,
#    'country': 'IR',
#    'sunrise': 1562547520,
#    'sunset': 1562599768},
#   'timezone': 16200,
#   'id': 118063,
#   'name': 'Sabzevar',
#   'cod': 200},
#  {'coord': {'lon': 9.81, 'lat': 3.63},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1013,
#    'humidity': 100,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 6000,
#   'wind': {'speed': 3.36, 'deg': 120},
#   'clouds': {'all': 75},
#   'dt': 1562607833,
#   'sys': {'type': 1,
#    'id': 2090,
#    'message': 0.0056,
#    'country': 'CM',
#    'sunrise': 1562562956,
#    'sunset': 1562607312},
#   'timezone': 3600,
#   'id': 2225940,
#   'name': 'Yatou',
#   'cod': 200},
#  {'coord': {'lon': 122.52, 'lat': -3.99},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 72.64,
#    'pressure': 1012.87,
#    'humidity': 96,
#    'temp_min': 72.64,
#    'temp_max': 72.64,
#    'sea_level': 1012.87,
#    'grnd_level': 1002.09},
#   'wind': {'speed': 1.23, 'deg': 224.034},
#   'rain': {'3h': 1.063},
#   'clouds': {'all': 82},
#   'dt': 1562607981,
#   'sys': {'message': 0.0083,
#    'country': 'ID',
#    'sunrise': 1562623070,
#    'sunset': 1562665910},
#   'timezone': 28800,
#   'id': 1640344,
#   'name': 'Kendari',
#   'cod': 200},
#  {'coord': {'lon': 132.75, 'lat': -5.67},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 78.22,
#    'pressure': 1012.22,
#    'humidity': 84,
#    'temp_min': 78.22,
#    'temp_max': 78.22,
#    'sea_level': 1012.22,
#    'grnd_level': 1012.03},
#   'wind': {'speed': 19.8, 'deg': 134.226},
#   'clouds': {'all': 26},
#   'dt': 1562607981,
#   'sys': {'message': 0.0068,
#    'country': 'ID',
#    'sunrise': 1562620781,
#    'sunset': 1562663287},
#   'timezone': 32400,
#   'id': 1623197,
#   'name': 'Tual',
#   'cod': 200},
#  {'coord': {'lon': -52.1, 'lat': -32.03},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 60.8,
#    'pressure': 1024,
#    'humidity': 59,
#    'temp_min': 60.8,
#    'temp_max': 60.8},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 90},
#   'clouds': {'all': 0},
#   'dt': 1562607879,
#   'sys': {'type': 1,
#    'id': 8408,
#    'message': 0.008,
#    'country': 'BR',
#    'sunrise': 1562581734,
#    'sunset': 1562618254},
#   'timezone': -10800,
#   'id': 3451138,
#   'name': 'Rio Grande',
#   'cod': 200},
#  {'coord': {'lon': -63.08, 'lat': -15.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.78,
#    'pressure': 1015.86,
#    'humidity': 31,
#    'temp_min': 85.78,
#    'temp_max': 85.78,
#    'sea_level': 1015.86,
#    'grnd_level': 991.98},
#   'wind': {'speed': 4.34, 'deg': 327.613},
#   'clouds': {'all': 1},
#   'dt': 1562607981,
#   'sys': {'message': 0.0082,
#    'country': 'BO',
#    'sunrise': 1562582400,
#    'sunset': 1562622859},
#   'timezone': -14400,
#   'id': 3923644,
#   'name': 'Urubicha',
#   'cod': 200},
#  {'coord': {'lon': -63.14, 'lat': -4.09},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 86.14,
#    'pressure': 1012.88,
#    'humidity': 54,
#    'temp_min': 86.14,
#    'temp_max': 86.14,
#    'sea_level': 1012.88,
#    'grnd_level': 1006.61},
#   'wind': {'speed': 4.81, 'deg': 156.658},
#   'clouds': {'all': 19},
#   'dt': 1562607897,
#   'sys': {'message': 0.0061,
#    'country': 'BR',
#    'sunrise': 1562581235,
#    'sunset': 1562624053},
#   'timezone': -14400,
#   'id': 3664539,
#   'name': 'Coari',
#   'cod': 200},
#  {'coord': {'lon': 117.03, 'lat': 25.1},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 72.28,
#    'pressure': 1003.78,
#    'humidity': 97,
#    'temp_min': 72.28,
#    'temp_max': 72.28,
#    'sea_level': 1003.78,
#    'grnd_level': 931.76},
#   'wind': {'speed': 3.33, 'deg': 175.717},
#   'rain': {'3h': 0.374},
#   'clouds': {'all': 100},
#   'dt': 1562607981,
#   'sys': {'message': 0.0078,
#    'country': 'CN',
#    'sunrise': 1562621289,
#    'sunset': 1562670326},
#   'timezone': 28800,
#   'id': 1802276,
#   'name': 'Longyan',
#   'cod': 200},
#  {'coord': {'lon': 2.41, 'lat': 49.38},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 71.01,
#    'pressure': 1019,
#    'humidity': 43,
#    'temp_min': 68,
#    'temp_max': 73.99},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 30},
#   'clouds': {'all': 0},
#   'dt': 1562607696,
#   'sys': {'type': 1,
#    'id': 6530,
#    'message': 0.0085,
#    'country': 'FR',
#    'sunrise': 1562557996,
#    'sunset': 1562615825},
#   'timezone': 7200,
#   'id': 3024643,
#   'name': 'Clermont',
#   'cod': 200},
#  {'coord': {'lon': -135.01, 'lat': 68.22},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 56.75,
#    'pressure': 1021,
#    'humidity': 81,
#    'temp_min': 53.6,
#    'temp_max': 59},
#   'visibility': 24140,
#   'wind': {'speed': 3.36, 'deg': 90},
#   'clouds': {'all': 75},
#   'dt': 1562607759,
#   'sys': {'type': 1,
#    'id': 821,
#    'message': 0.0074,
#    'country': 'CA',
#    'sunrise': 0,
#    'sunset': 0},
#   'timezone': -21600,
#   'id': 5882953,
#   'name': 'Aklavik',
#   'cod': 200},
#  {'coord': {'lon': 19.88, 'lat': 4.19},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 72.46,
#    'pressure': 1012.29,
#    'humidity': 87,
#    'temp_min': 72.46,
#    'temp_max': 72.46,
#    'sea_level': 1012.29,
#    'grnd_level': 967.52},
#   'wind': {'speed': 1.52, 'deg': 0.929},
#   'clouds': {'all': 92},
#   'dt': 1562607981,
#   'sys': {'message': 0.0068,
#    'country': 'CD',
#    'sunrise': 1562560483,
#    'sunset': 1562604951},
#   'timezone': 3600,
#   'id': 2316473,
#   'name': 'Bosobolo',
#   'cod': 200},
#  {'coord': {'lon': 36.99, 'lat': -16.84},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.38,
#    'pressure': 1020.56,
#    'humidity': 71,
#    'temp_min': 62.38,
#    'temp_max': 62.38,
#    'sea_level': 1020.56,
#    'grnd_level': 994.24},
#   'wind': {'speed': 4.03, 'deg': 91.336},
#   'clouds': {'all': 58},
#   'dt': 1562607752,
#   'sys': {'message': 0.0064,
#    'country': 'MZ',
#    'sunrise': 1562558513,
#    'sunset': 1562598707},
#   'timezone': 7200,
#   'id': 1024312,
#   'name': 'Mocuba',
#   'cod': 200},
#  {'coord': {'lon': -115.69, 'lat': 43.13},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 68.97,
#    'pressure': 1014,
#    'humidity': 43,
#    'temp_min': 66.2,
#    'temp_max': 71.01},
#   'visibility': 16093,
#   'wind': {'speed': 5.82},
#   'clouds': {'all': 75},
#   'dt': 1562607982,
#   'sys': {'type': 1,
#    'id': 5002,
#    'message': 0.0082,
#    'country': 'US',
#    'sunrise': 1562587864,
#    'sunset': 1562642650},
#   'timezone': -21600,
#   'id': 5601615,
#   'name': 'Mountain Home',
#   'cod': 200},
#  {'coord': {'lon': 159.96, 'lat': -9.43},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'pressure': 1009,
#    'humidity': 100,
#    'temp_min': 73.4,
#    'temp_max': 73.4},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1562607982,
#   'sys': {'type': 1,
#    'id': 2,
#    'message': 0.0071,
#    'country': 'SB',
#    'sunrise': 1562614628,
#    'sunset': 1562656378},
#   'timezone': 39600,
#   'id': 2108502,
#   'name': 'Honiara',
#   'cod': 200},
#  {'coord': {'lon': -10.74, 'lat': 10.04},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 77.32,
#    'pressure': 1012.84,
#    'humidity': 88,
#    'temp_min': 77.32,
#    'temp_max': 77.32,
#    'sea_level': 1012.84,
#    'grnd_level': 958.27},
#   'wind': {'speed': 5.64, 'deg': 228.166},
#   'rain': {'3h': 0.874},
#   'clouds': {'all': 100},
#   'dt': 1562607982,
#   'sys': {'message': 0.0088,
#    'country': 'GN',
#    'sunrise': 1562567237,
#    'sunset': 1562612896},
#   'timezone': 0,
#   'id': 2421273,
#   'name': 'Faranah',
#   'cod': 200},
#  {'coord': {'lon': 34.27, 'lat': 62.21},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 55.4,
#    'pressure': 1005,
#    'humidity': 93,
#    'temp_min': 55.4,
#    'temp_max': 55.4},
#   'visibility': 9000,
#   'wind': {'speed': 8.95, 'deg': 20},
#   'rain': {'3h': 0.75},
#   'clouds': {'all': 100},
#   'dt': 1562607758,
#   'sys': {'type': 1,
#    'id': 8929,
#    'message': 0.0055,
#    'country': 'RU',
#    'sunrise': 1562544436,
#    'sunset': 1562614090},
#   'timezone': 10800,
#   'id': 545626,
#   'name': 'Kondopoga',
#   'cod': 200},
#  {'coord': {'lon': 27.34, 'lat': -17.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 62.56,
#    'pressure': 1018.58,
#    'humidity': 12,
#    'temp_min': 62.56,
#    'temp_max': 62.56,
#    'sea_level': 1018.58,
#    'grnd_level': 915.61},
#   'wind': {'speed': 5.44, 'deg': 311.81},
#   'clouds': {'all': 0},
#   'dt': 1562607982,
#   'sys': {'message': 0.0069,
#    'country': 'ZW',
#    'sunrise': 1562560914,
#    'sunset': 1562600939},
#   'timezone': 7200,
#   'id': 895057,
#   'name': 'Binga',
#   'cod': 200},
#  {'coord': {'lon': 74.98, 'lat': 46.84},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 80.2,
#    'pressure': 1003.75,
#    'humidity': 43,
#    'temp_min': 80.2,
#    'temp_max': 80.2,
#    'sea_level': 1003.75,
#    'grnd_level': 954.69},
#   'wind': {'speed': 20.96, 'deg': 59.836},
#   'clouds': {'all': 36},
#   'dt': 1562607982,
#   'sys': {'message': 0.006,
#    'country': 'KZ',
#    'sunrise': 1562541237,
#    'sunset': 1562597746},
#   'timezone': 21600,
#   'id': 1525798,
#   'name': 'Balkhash',
#   'cod': 200},
#  {'coord': {'lon': 29.55, 'lat': 57.77},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 60.8,
#    'pressure': 1000,
#    'humidity': 72,
#    'temp_min': 60.8,
#    'temp_max': 60.8},
#   'wind': {'speed': 6.71, 'deg': 330},
#   'rain': {'1h': 1},
#   'clouds': {'all': 20},
#   'dt': 1562607983,
#   'sys': {'type': 1,
#    'id': 8928,
#    'message': 0.0451,
#    'country': 'RU',
#    'sunrise': 1562548383,
#    'sunset': 1562612409},
#   'timezone': 10800,
#   'id': 506278,
#   'name': 'Porkhov',
#   'cod': 200},
#  {'coord': {'lon': 150.15, 'lat': -5.56},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 72.1,
#    'pressure': 1010.05,
#    'humidity': 88,
#    'temp_min': 72.1,
#    'temp_max': 72.1,
#    'sea_level': 1010.05,
#    'grnd_level': 996.4},
#   'wind': {'speed': 3.33, 'deg': 146.214},
#   'clouds': {'all': 98},
#   'dt': 1562607983,
#   'sys': {'message': 0.0089,
#    'country': 'PG',
#    'sunrise': 1562616594,
#    'sunset': 1562659121},
#   'timezone': 36000,
#   'id': 2093967,
#   'name': 'Kimbe',
#   'cod': 200},
#  {'coord': {'lon': 30.82, 'lat': 69.43},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'pressure': 1019,
#    'humidity': 66,
#    'temp_min': 50,
#    'temp_max': 50},
#   'visibility': 10000,
#   'wind': {'speed': 16.11, 'deg': 60},
#   'clouds': {'all': 0},
#   'dt': 1562607983,
#   'sys': {'type': 1,
#    'id': 1639,
#    'message': 0.0074,
#    'country': 'RU',
#    'sunrise': 0,
#    'sunset': 0},
#   'timezone': 10800,
#   'id': 464790,
#   'name': 'Zapolyarnyy',
#   'cod': 200},
#  {'coord': {'lon': 53.91, 'lat': 65.01},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 55.54,
#    'pressure': 1005.15,
#    'humidity': 68,
#    'temp_min': 55.54,
#    'temp_max': 55.54,
#    'sea_level': 1005.15,
#    'grnd_level': 994.85},
#   'wind': {'speed': 5.37, 'deg': 353.336},
#   'clouds': {'all': 55},
#   'dt': 1562607983,
#   'sys': {'message': 0.0079,
#    'country': 'RU',
#    'sunrise': 1562536642,
#    'sunset': 1562612456},
#   'timezone': 10800,
#   'id': 554830,
#   'name': 'Izhma',
#   'cod': 200},
#  {'coord': {'lon': 20.83, 'lat': 37.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.76,
#    'pressure': 1010,
#    'humidity': 58,
#    'temp_min': 82.99,
#    'temp_max': 86},
#   'visibility': 10000,
#   'wind': {'speed': 15.88, 'deg': 308.93},
#   'clouds': {'all': 0},
#   'dt': 1562607983,
#   'sys': {'type': 1,
#    'id': 6653,
#    'message': 0.007,
#    'country': 'GR',
#    'sunrise': 1562556112,
#    'sunset': 1562608865},
#   'timezone': 10800,
#   'id': 258241,
#   'name': 'Lithakia',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 127.27, 'lat': 53.74},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 60.22,
#    'pressure': 1006.42,
#    'humidity': 83,
#    'temp_min': 60.22,
#    'temp_max': 60.22,
#    'sea_level': 1006.42,
#    'grnd_level': 938.57},
#   'wind': {'speed': 3.31, 'deg': 129.543},
#   'clouds': {'all': 97},
#   'dt': 1562607983,
#   'sys': {'message': 0.01,
#    'country': 'RU',
#    'sunrise': 1562613083,
#    'sunset': 1562673616},
#   'timezone': 32400,
#   'id': 2012593,
#   'name': 'Zeya',
#   'cod': 200}]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(len(city_list))
print(len(cloudiness))
print(len(country))
print(len(date))
print(len(humidity))
print(len(lat))
print(len(lng))
print(len(max_temp))
print(len(wind_speed))
# Out:
# 683
# 683
# 683
# 683
# 683
# 683
# 683
# 683
# 683

# %%
weather_dict = {
    "City": city_list,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Leningradskiy          51      RU  1562607752        64  69.38  178.42
# 1     Bredasdorp          50      ZA  1562607763        59 -34.53   20.04
# 2   Puerto Ayora          40      EC  1562607788        61  -0.74  -90.35
# 3           Ayan         100      IR  1562607817        60  38.23   44.70
# 4   Saint George          20      GR  1562607566        26  39.45   22.34
#
#    Max Temp  Wind Speed
# 0     51.22        8.03
# 1     66.20       12.75
# 2     80.60       18.34
# 3     58.24        2.86
# 4     95.00       12.75

# %%
outfile = "cities.csv"
outdir = '../output_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outfile)    

weather_data.to_csv(fullname, index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({strformat})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Lat_vs_temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({strformat})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/lat_vs_humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({strformat})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/lat_vs_cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({now})")
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/lat_vs_wind.png")

# Show plot
plt.show()
